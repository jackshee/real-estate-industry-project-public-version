# %%
# reload all module before executing code
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import os 

# Import the GeoUtils class from utils/geo.py
from utils.geo import GeoUtils
from dotenv import load_dotenv

load_dotenv()
APIKEY1 = os.getenv('ORS_API_KEY1')
APIKEY2 = os.getenv('ORS_API_KEY2')
APIKEY3 = os.getenv('ORS_API_KEY3')

# Initialize GeoUtils 
geoutils = GeoUtils(ors_api_key=APIKEY3)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# OpenRouteService client initialized successfully.

# %%
df = pd.read_csv('../data/raw/missing_geo/rental_listings_missing_coordinates.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2854 entries, 0 to 2853
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          2854 non-null   float64
#  1   bedrooms             2832 non-null   float64
#  2   bathrooms            2852 non-null   float64
#  3   car_spaces           2523 non-null   float64
#  4   property_type        2854 non-null   object
#  5   land_area            2854 non-null   float64
#  6   property_features    2854 non-null   object
#  7   suburb               2854 non-null   object
#  8   postcode             2854 non-null   int64
#  9   year                 2854 non-null   int64
#  10  quarter              2854 non-null   int64
#  11  age_0_to_19          0 non-null      float64
#  12  age_20_to_39         0 non-null      float64
#  13  age_40_to_59         0 non-null      float64
#  14  age_60_plus          0 non-null      float64
# ...

# %%
# process first 1000 rows of df 
df = df.head(500)

# apply geocoding using geoutils.geocode_ors_with_delay
df['coordinates'] = df['full_address'].apply(geoutils.geocode_ors_with_delay)
# Out:
# Quota exceeded for OpenRouteService. Skipping address: 399 Bourke Street, Melbourne, VIC 3000
# Quota exceeded for OpenRouteService. Skipping address: 220 Spencer Street, Melbourne, VIC 3000
# Quota exceeded for OpenRouteService. Skipping address: 39 Queen Street, Melbourne, VIC 3000
# Quota exceeded for OpenRouteService. Skipping address: 118 Franklin Street, Melbourne, VIC 3000
# Quota exceeded for OpenRouteService. Skipping address: 565 Flinders Street, Melbourne, VIC 3000
# Quota exceeded for OpenRouteService. Skipping address: 650 Elizabeth Street, Melbourne, VIC 3000
# Quota exceeded for OpenRouteService. Skipping address: 555 Flinders Street, Melbourne, VIC 3000
# Quota exceeded for OpenRouteService. Skipping address: 5 Sutherland Street, Melbourne, VIC 3000
# Quota exceeded for OpenRouteService. Skipping address: 199 William Street, Melbourne, VIC 3000
# Quota exceeded for OpenRouteService. Skipping address: 17 Singers Lane, Melbourne, VIC 3000
# ...

# %%
# read in "data/domain/rental_listings_summary_cleaned.csv"
df_tmp = pd.read_csv('../data/processed/domain/rental_listings_summary_cleaned.csv')
print(df_tmp['coordinates'].isnull().sum())
coord_mapping = df.set_index('property_id')['coordinates'].to_dict()

mask = df_tmp['coordinates'].isna()

df_tmp.loc[mask, 'coordinates'] = df_tmp.loc[mask, 'property_id'].map(coord_mapping)

print(df_tmp['coordinates'].isnull().sum())
# Out:
# 15
# 15

# %%
df_tmp.to_csv('../data/processed/domain/rental_listings_summary_cleaned.csv', index=False)
