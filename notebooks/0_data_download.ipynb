# %% [markdown]
# ## Downloading the Data (Refactored)
#
# This notebook demonstrates the use of the `DownloadUtils` class for downloading and processing data from various sources.
#
# The `DownloadUtils` class provides a clean, object-oriented interface for:
# - Creating data directory structures
# - Downloading files from URLs
# - Scraping time series data from web tables
# - Saving processed data to CSV files

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

# Add project root to Python path
# Get the current notebook's directory and go up to project root
current_dir = Path().resolve()
if current_dir.name == 'notebooks':
    project_root = current_dir.parent
elif current_dir.name == 'project2':
    project_root = current_dir
else:
    # If we're in the parent directory, look for project2
    project_root = current_dir / 'project2'

sys.path.insert(0, str(project_root))
print(f"Project root: {project_root}")

from utils.download import DownloadUtils
from utils.preprocess import PreprocessUtils

# Initialize the utilities
downloader = DownloadUtils(base_data_dir="../data/")
# Out:
# Project root: /Users/jackshee/University/MAST30034 Applied Data Science/project2

# %% [markdown]
# ### Option 2: Download Data Sources Individually
#
# You can also download specific data sources individually for more control over the process.

# %% [markdown]
# #### Download Rent Time Series Data from DFFH

# %%
# Download the latest moving annual rent file (March 2025) with verbose output
downloader.download_latest_rent_data(verbose=True)
# Out:
# Downloading latest moving annual rent file: moving_annual_median_weekly_rent_by_suburb
# URL: https://www.dffh.vic.gov.au/moving-annual-rent-suburb-march-quarter-2025-excel
# ⚠️  File already exists: moving_annual_median_weekly_rent_by_suburb.xlsx (1.08 MB)
# ✅ Successfully downloaded latest moving annual rent file!

# %% [markdown]
# #### Download Public Transport Data

# %%
# Download public transport stops and lines data with verbose output
downloader.download_public_transport_data(verbose=True)
# Out:
# Downloading from: https://opendata.transport.vic.gov.au/dataset/6d36dfd9-8693-4552-8a03-05eb29a391fd/resource/afa7b823-0c8b-47a1-bc40-ada565f684c7/download/public_transport_stops.geojson
# ✅ Downloaded public_transport_stops.geojson (7.33 MB) in 1.91s
# Downloading from: https://opendata.transport.vic.gov.au/dataset/6d36dfd9-8693-4552-8a03-05eb29a391fd/resource/52e5173e-b5d5-4b65-9b98-89f225fc529c/download/public_transport_lines.geojson
# ✅ Downloaded public_transport_lines.geojson (362.41 MB) in 122.91s

# %% [markdown]
# #### Download School Locations Data

# %%
# Download school locations for 2023, 2024, and 2025 with verbose output
downloader.download_school_locations(verbose=True)
# Out:
# Downloading from: https://www.education.vic.gov.au/Documents/about/research/datavic/dv346-schoollocations2023.csv
# ✅ Downloaded school_locations_2023.csv (0.40 MB) in 0.57s
# Downloading from: https://www.education.vic.gov.au/Documents/about/research/datavic/dv378_DataVic-SchoolLocations-2024.csv
# ✅ Downloaded school_locations_2024.csv (0.48 MB) in 0.51s
# Downloading from: https://www.education.vic.gov.au/Documents/about/research/datavic/dv402-SchoolLocations2025.csv
# ✅ Downloaded school_locations_2025.csv (0.51 MB) in 0.53s

# %% [markdown]
# #### Scrape Macroeconomic Time Series Data

# %%
# Scrape unemployment rate data with verbose output
downloader.scrape_unemployment_data(verbose=True)
# Out:
# === SCRAPING UNEMPLOYMENT RATE DATA ===
# Scraping unemployment_rate data from: https://djsir-data.github.io/djprecodash/tables/djsir_labour_market
# ✅ Scraped unemployment_rate data (191 records) in 2.77s
# Successfully scraped and saved unemployment_rate data to ../data/landing/unemployment_rate/quarterly_unemployment_rate.csv
# Data contains 191 quarterly records
# Date range: 1978-03-01 00:00:00 to 2025-09-01 00:00:00
#
# First 5 records:
#         date  year  quarter  Unemployment rate (%)
# 0 1978-03-01  1978        1               5.842250
# 1 1978-06-01  1978        2               5.552600
# 2 1978-09-01  1978        3               5.550233
# 3 1978-12-01  1978        4               5.575700
# 4 1979-03-01  1979        1               5.600167
#
# Last 5 records:
#           date  year  quarter  Unemployment rate (%)
# 186 2024-09-01  2024        3               4.473833
# 187 2024-12-01  2024        4               4.378333
# 188 2025-03-01  2025        1               4.544433
# 189 2025-06-01  2025        2               4.381900
# 190 2025-09-01  2025        3               4.472050
#
# ==================================================
# '../data/landing/unemployment_rate/quarterly_unemployment_rate.csv'

# %%
# Scrape interest rates data with verbose output
downloader.scrape_interest_rates_data(verbose=True)
# Out:
# === SCRAPING INTEREST RATES DATA ===
# Scraping interest_rates data from: https://djsir-data.github.io/djprecodash/tables/djsir_interest_rates
# ✅ Scraped interest_rates data (181 records) in 1.11s
# Successfully scraped and saved interest_rates data to ../data/landing/interest_rates/quarterly_interest_rates.csv
# Data contains 181 quarterly records
# Date range: 1990-03-01 00:00:00 to 2035-09-01 00:00:00
#
# First 5 records:
#         date  year  quarter  Mortgage rates (%)  Savings rates (%)  \
# 0 1990-03-01  1990        1                 NaN                NaN
# 1 1990-06-01  1990        2                 NaN                NaN
# 2 1990-09-01  1990        3                 NaN                NaN
# 3 1990-12-01  1990        4                 NaN                NaN
# 4 1991-03-01  1991        1                 NaN                NaN
#
#    Cash rate (%)
# 0      16.666667
# 1      15.000000
# 2      14.333333
# 3      12.666667
# 4      12.000000
#
# Last 5 records:
#           date  year  quarter  Mortgage rates (%)  Savings rates (%)  \
# 176 2034-09-01  2034        3                 NaN                NaN
# 177 2034-12-01  2034        4                 NaN                NaN
# 178 2035-03-01  2035        1                 NaN                NaN
# 179 2035-06-01  2035        2                 NaN                NaN
# 180 2035-09-01  2035        3                 NaN                NaN
#
#      Cash rate (%)
# 176            NaN
# 177            NaN
# 178            NaN
# 179            NaN
# 180            NaN
#
# ==================================================
# '../data/landing/interest_rates/quarterly_interest_rates.csv'

# %%
# Scrape price data with verbose output
downloader.scrape_price_data(verbose=True)
# Out:
# === SCRAPING PRICE DATA ===
# Scraping price_data data from: https://djsir-data.github.io/djprecodash/tables/djsir_prices
# ✅ Scraped price_data data (304 records) in 0.69s
# Successfully scraped and saved price_data data to ../data/landing/price_data/quarterly_price_data.csv
# Data contains 304 quarterly records
# Date range: 1949-09-01 00:00:00 to 2025-06-01 00:00:00
#
# First 5 records:
#         date  year  quarter  CPI (%/y)  WPI (%/y)  PPI, Final Demand (%/y)
# 0 1949-09-01  1949        3        7.9        NaN                      NaN
# 1 1949-12-01  1949        4       10.5        NaN                      NaN
# 2 1950-03-01  1950        1       10.3        NaN                      NaN
# 3 1950-06-01  1950        2       10.0        NaN                      NaN
# 4 1950-09-01  1950        3        9.8        NaN                      NaN
#
# Last 5 records:
#           date  year  quarter  CPI (%/y)  WPI (%/y)  PPI, Final Demand (%/y)
# 299 2024-06-01  2024        2        3.7        3.3                      4.8
# 300 2024-09-01  2024        3        3.0        3.2                      3.9
# 301 2024-12-01  2024        4        2.5        3.2                      3.7
# 302 2025-03-01  2025        1        2.3        3.3                      3.7
# 303 2025-06-01  2025        2        2.0        3.4                      3.4
#
# ==================================================
# '../data/landing/price_data/quarterly_price_data.csv'

# %%
# Scrape economic activity data with verbose output
downloader.scrape_economic_activity_data(verbose=True)
# Out:
# === SCRAPING ECONOMIC ACTIVITY DATA ===
# Scraping economic_activity data from: https://djsir-data.github.io/djprecodash/tables/djsir_economic_activity
# ✅ Scraped economic_activity data (156 records) in 0.65s
# Successfully scraped and saved economic_activity data to ../data/landing/economic_activity/quarterly_economic_activity.csv
# Data contains 156 quarterly records
# Date range: 1986-09-01 00:00:00 to 2025-06-01 00:00:00
#
# First 5 records:
#         date  year  quarter  SFD (%/y)  GSP quarterly components (%/y)
# 0 1986-09-01  1986        3     2.8931                             NaN
# 1 1986-12-01  1986        4     2.5560                             NaN
# 2 1987-03-01  1987        1     1.1749                             NaN
# 3 1987-06-01  1987        2     1.7426                             NaN
# 4 1987-09-01  1987        3     2.3537                             NaN
#
# Last 5 records:
#           date  year  quarter  SFD (%/y)  GSP quarterly components (%/y)
# 151 2024-06-01  2024        2     1.4268                          2.0788
# 152 2024-09-01  2024        3     1.3878                          1.6343
# 153 2024-12-01  2024        4     2.4225                          1.5266
# 154 2025-03-01  2025        1     1.8019                          1.9711
# 155 2025-06-01  2025        2     1.6648                          2.0133
#
# ==================================================
# '../data/landing/economic_activity/quarterly_economic_activity.csv'

# %%
# Scrape population dynamics data with verbose output
downloader.scrape_population_data(verbose=True)
# Out:
# === SCRAPING POPULATION DATA ===
# Scraping population data from: https://djsir-data.github.io/djprecodash/tables/djsir_contribution_to_population_growth
# ✅ Scraped population data (172 records) in 0.52s
# Successfully scraped and saved population_dynamics data to ../data/landing/population/quarterly_population_dynamics.csv
# Data contains 172 quarterly records
# Date range: 1982-06-01 00:00:00 to 2025-03-01 00:00:00
#
# First 5 records:
#         date  year  quarter  Population (%/y)  Natural increase (pp/y)  \
# 0 1982-06-01  1982        2            1.1643                   0.7689
# 1 1982-09-01  1982        3            1.1472                   0.7278
# 2 1982-12-01  1982        4            1.1160                   0.7354
# 3 1983-03-01  1983        1            1.1160                   0.7228
# 4 1983-06-01  1983        2            1.0727                   0.7358
#
#    Net overseas migration (pp/y)  Net interstate migration (pp/y)
# 0                         0.7891                          -0.3656
# 1                         0.7346                          -0.2874
# 2                         0.6290                          -0.2207
# 3                         0.5855                          -0.1648
# 4                         0.4927                          -0.1286
#
# Last 5 records:
#           date  year  quarter  Population (%/y)  Natural increase (pp/y)  \
# 167 2024-03-01  2024        1            2.5348                   0.4418
# 168 2024-06-01  2024        2            2.2606                   0.4436
# 169 2024-09-01  2024        3            2.0041                   0.4740
# 170 2024-12-01  2024        4            1.8396                   0.4552
# 171 2025-03-01  2025        1            1.7982                   0.4868
#
#      Net overseas migration (pp/y)  Net interstate migration (pp/y)
# 167                         2.1545                          -0.0615
# 168                         1.8794                          -0.0624
# 169                         1.5876                          -0.0576
# 170                         1.4310                          -0.0465
# 171                         1.3448                          -0.0335
#
# ==================================================
# '../data/landing/population/quarterly_population_dynamics.csv'

# %%
# Scrape investment data with verbose output
downloader.scrape_investment_data(verbose=True)
# Out:
# === SCRAPING INVESTMENT DATA ===
# Scraping investment data from: https://djsir-data.github.io/djprecodash/tables/djsir_contribution_to_growth
# ✅ Scraped investment data (156 records) in 0.60s
# Successfully scraped and saved investment data to ../data/landing/investment/quarterly_investment.csv
# Data contains 156 quarterly records
# Date range: 1986-09-01 00:00:00 to 2025-06-01 00:00:00
#
# First 5 records:
#         date  year  quarter  State final demand (%/y)  \
# 0 1986-09-01  1986        3                    2.8931
# 1 1986-12-01  1986        4                    2.5560
# 2 1987-03-01  1987        1                    1.1749
# 3 1987-06-01  1987        2                    1.7426
# 4 1987-09-01  1987        3                    2.3537
#
#    Household consumption (pp/y)  Dwelling investment (pp/y)  \
# 0                        2.3367                     -1.6844
# 1                        1.3148                     -0.9639
# 2                        2.2443                     -0.6434
# 3                        0.4657                      0.2023
# 4                        1.1281                      0.1081
#
#    Business investment (pp/y)  Government spending (pp/y)
# 0                     -0.2793                      2.4197
# 1                      0.6174                      0.5069
# 2                      0.0452                     -1.0092
# 3                      1.2074                     -1.5845
# 4                      0.7040                     -0.4495
#
# Last 5 records:
#           date  year  quarter  State final demand (%/y)  \
# 151 2024-06-01  2024        2                    1.4268
# 152 2024-09-01  2024        3                    1.3878
# 153 2024-12-01  2024        4                    2.4225
# 154 2025-03-01  2025        1                    1.8019
# 155 2025-06-01  2025        2                    1.6648
#
#      Household consumption (pp/y)  Dwelling investment (pp/y)  \
# 151                       -0.1077                      0.2630
# 152                        0.0032                      0.1571
# 153                        0.3378                      0.3629
# 154                        0.4481                      0.3969
# 155                        0.8969                      0.3439
#
#      Business investment (pp/y)  Government spending (pp/y)
# 151                      0.2482                      0.9523
# 152                      0.3732                      0.8542
# 153                      0.4259                      1.2965
# 154                     -0.0556                      1.0125
# 155                     -0.1754                      0.6001
#
# ==================================================
# '../data/landing/investment/quarterly_investment.csv'

# %% [markdown]
# #### Download Population Census Data from ABS

# %%
# This downloads Excel files for SAL codes 20001-22944 from ABS
# Note: This will take a very long time and generate a lot of output
no_data_list = downloader.download_population_census_data(verbose=True)
# Out:
# === DOWNLOADING POPULATION CENSUS DATA ===
# ❌ Error for SAL 20001: HTTP Error 404: Not Found
# ❌ Error for SAL 20006: HTTP Error 504: Gateway Time-out
# ❌ Error for SAL 20012: HTTP Error 504: Gateway Time-out
# ❌ Error for SAL 20016: HTTP Error 504: Gateway Time-out
# ❌ Error for SAL 20055: HTTP Error 404: Not Found
# ❌ Error for SAL 20059: HTTP Error 404: Not Found
# ❌ Error for SAL 20060: HTTP Error 404: Not Found
# ✅ Downloaded 50 files...
# ❌ Error for SAL 20083: HTTP Error 404: Not Found
# ❌ Error for SAL 20084: HTTP Error 404: Not Found
# ❌ Error for SAL 20088: HTTP Error 404: Not Found
# ❌ Error for SAL 20098: HTTP Error 404: Not Found
# ✅ Downloaded 100 files...
# ❌ Error for SAL 20155: HTTP Error 404: Not Found
# ❌ Error for SAL 20158: HTTP Error 404: Not Found
# ❌ Error for SAL 20167: HTTP Error 404: Not Found
# ✅ Downloaded 150 files...
# ❌ Error for SAL 20194: HTTP Error 404: Not Found
# ❌ Error for SAL 20199: HTTP Error 404: Not Found
# ✅ Downloaded 200 files...
# ❌ Error for SAL 20234: HTTP Error 404: Not Found
# ❌ Error for SAL 20239: HTTP Error 404: Not Found
# ❌ Error for SAL 20243: HTTP Error 404: Not Found
# ❌ Error for SAL 20265: HTTP Error 404: Not Found
# ❌ Error for SAL 20271: HTTP Error 404: Not Found
# ✅ Downloaded 250 files...
# ❌ Error for SAL 20286: HTTP Error 404: Not Found
# ❌ Error for SAL 20287: HTTP Error 404: Not Found
# ✅ Downloaded 300 files...
# ❌ Error for SAL 20340: HTTP Error 404: Not Found
# ❌ Error for SAL 20360: HTTP Error 404: Not Found
# ❌ Error for SAL 20372: HTTP Error 404: Not Found
# ❌ Error for SAL 20374: HTTP Error 404: Not Found
# ❌ Error for SAL 20378: HTTP Error 404: Not Found
# ❌ Error for SAL 20379: HTTP Error 404: Not Found
# ✅ Downloaded 350 files...
# ❌ Error for SAL 20397: HTTP Error 404: Not Found
# ❌ Error for SAL 20407: HTTP Error 404: Not Found
# ❌ Error for SAL 20413: HTTP Error 404: Not Found
# ✅ Downloaded 400 files...
# ❌ Error for SAL 20442: HTTP Error 404: Not Found
# ❌ Error for SAL 20452: HTTP Error 404: Not Found
# ❌ Error for SAL 20462: HTTP Error 404: Not Found
# ❌ Error for SAL 20479: HTTP Error 404: Not Found
# ✅ Downloaded 450 files...
# ❌ Error for SAL 20529: HTTP Error 404: Not Found
# ❌ Error for SAL 20530: HTTP Error 404: Not Found
# ❌ Error for SAL 20542: HTTP Error 404: Not Found
# ✅ Downloaded 500 files...
# ❌ Error for SAL 20544: HTTP Error 404: Not Found
# ❌ Error for SAL 20550: HTTP Error 404: Not Found
# ❌ Error for SAL 20553: HTTP Error 404: Not Found
# ❌ Error for SAL 20562: HTTP Error 404: Not Found
# ❌ Error for SAL 20588: HTTP Error 404: Not Found
# ❌ Error for SAL 20589: HTTP Error 404: Not Found
# ❌ Error for SAL 20598: HTTP Error 404: Not Found
# ✅ Downloaded 550 files...
# ❌ Error for SAL 20601: HTTP Error 404: Not Found
# ❌ Error for SAL 20606: HTTP Error 404: Not Found
# ❌ Error for SAL 20617: HTTP Error 404: Not Found
# ✅ Downloaded 600 files...
# ❌ Error for SAL 20655: HTTP Error 404: Not Found
# ❌ Error for SAL 20675: HTTP Error 404: Not Found
# ❌ Error for SAL 20676: HTTP Error 404: Not Found
# ❌ Error for SAL 20694: HTTP Error 404: Not Found
# ❌ Error for SAL 20705: HTTP Error 404: Not Found
# ✅ Downloaded 650 files...
# ❌ Error for SAL 20710: HTTP Error 404: Not Found
# ❌ Error for SAL 20739: HTTP Error 404: Not Found
# ✅ Downloaded 700 files...
# ❌ Error for SAL 20781: HTTP Error 404: Not Found
# ✅ Downloaded 750 files...
# ❌ Error for SAL 20819: HTTP Error 404: Not Found
# ❌ Error for SAL 20824: HTTP Error 404: Not Found
# ❌ Error for SAL 20856: HTTP Error 404: Not Found
# ✅ Downloaded 800 files...
# ❌ Error for SAL 20874: HTTP Error 404: Not Found
# ❌ Error for SAL 20882: HTTP Error 404: Not Found
# ❌ Error for SAL 20886: HTTP Error 404: Not Found
# ❌ Error for SAL 20905: HTTP Error 404: Not Found
# ❌ Error for SAL 20911: HTTP Error 404: Not Found
# ❌ Error for SAL 20916: HTTP Error 404: Not Found
# ✅ Downloaded 850 files...
# ❌ Error for SAL 20928: HTTP Error 404: Not Found
# ❌ Error for SAL 20953: HTTP Error 404: Not Found
# ❌ Error for SAL 20961: HTTP Error 404: Not Found
# ❌ Error for SAL 20970: HTTP Error 404: Not Found
# ✅ Downloaded 900 files...
# ❌ Error for SAL 20981: HTTP Error 404: Not Found
# ❌ Error for SAL 20983: HTTP Error 404: Not Found
# ❌ Error for SAL 20987: HTTP Error 404: Not Found
# ❌ Error for SAL 20997: HTTP Error 404: Not Found
# ❌ Error for SAL 21022: HTTP Error 404: Not Found
# ❌ Error for SAL 21023: HTTP Error 404: Not Found
# ✅ Downloaded 950 files...
# ❌ Error for SAL 21061: HTTP Error 404: Not Found
# ❌ Error for SAL 21080: HTTP Error 404: Not Found
# ✅ Downloaded 1000 files...
# ❌ Error for SAL 21085: HTTP Error 404: Not Found
# ❌ Error for SAL 21086: HTTP Error 404: Not Found
# ❌ Error for SAL 21093: HTTP Error 404: Not Found
# ❌ Error for SAL 21095: HTTP Error 404: Not Found
# ❌ Error for SAL 21096: HTTP Error 404: Not Found
# ❌ Error for SAL 21097: HTTP Error 404: Not Found
# ❌ Error for SAL 21099: HTTP Error 404: Not Found
# ❌ Error for SAL 21111: HTTP Error 404: Not Found
# ❌ Error for SAL 21119: HTTP Error 404: Not Found
# ✅ Downloaded 1050 files...
# ❌ Error for SAL 21151: HTTP Error 404: Not Found
# ✅ Downloaded 1100 files...
# ❌ Error for SAL 21210: HTTP Error 404: Not Found
# ❌ Error for SAL 21212: HTTP Error 404: Not Found
# ❌ Error for SAL 21240: HTTP Error 404: Not Found
# ✅ Downloaded 1150 files...
# ❌ Error for SAL 21266: HTTP Error 404: Not Found
# ❌ Error for SAL 21267: HTTP Error 404: Not Found
# ❌ Error for SAL 21278: HTTP Error 404: Not Found
# ❌ Error for SAL 21297: HTTP Error 404: Not Found
# ✅ Downloaded 1200 files...
# ❌ Error for SAL 21320: HTTP Error 404: Not Found
# ❌ Error for SAL 21323: HTTP Error 404: Not Found
# ✅ Downloaded 1250 files...
# ❌ Error for SAL 21372: HTTP Error 404: Not Found
# ❌ Error for SAL 21391: HTTP Error 404: Not Found
# ✅ Downloaded 1300 files...
# ❌ Error for SAL 21408: HTTP Error 404: Not Found
# ❌ Error for SAL 21409: HTTP Error 404: Not Found
# ❌ Error for SAL 21422: HTTP Error 404: Not Found
# ❌ Error for SAL 21423: HTTP Error 404: Not Found
# ❌ Error for SAL 21431: HTTP Error 404: Not Found
# ❌ Error for SAL 21432: HTTP Error 404: Not Found
# ❌ Error for SAL 21433: HTTP Error 404: Not Found
# ❌ Error for SAL 21445: HTTP Error 404: Not Found
# ❌ Error for SAL 21446: HTTP Error 404: Not Found
# ❌ Error for SAL 21448: HTTP Error 404: Not Found
# ✅ Downloaded 1350 files...
# ❌ Error for SAL 21478: HTTP Error 404: Not Found
# ❌ Error for SAL 21494: HTTP Error 404: Not Found
# ❌ Error for SAL 21498: HTTP Error 404: Not Found
# ❌ Error for SAL 21499: HTTP Error 404: Not Found
# ✅ Downloaded 1400 files...
# ❌ Error for SAL 21518: HTTP Error 404: Not Found
# ❌ Error for SAL 21525: HTTP Error 404: Not Found
# ✅ Downloaded 1450 files...
# ❌ Error for SAL 21598: HTTP Error 404: Not Found
# ❌ Error for SAL 21600: HTTP Error 404: Not Found
# ❌ Error for SAL 21607: HTTP Error 404: Not Found
# ❌ Error for SAL 21610: HTTP Error 404: Not Found
# ❌ Error for SAL 21616: HTTP Error 404: Not Found
# ✅ Downloaded 1500 files...
# ❌ Error for SAL 21638: HTTP Error 404: Not Found
# ❌ Error for SAL 21666: HTTP Error 404: Not Found
# ✅ Downloaded 1550 files...
# ❌ Error for SAL 21699: HTTP Error 404: Not Found
# ❌ Error for SAL 21700: HTTP Error 404: Not Found
# ❌ Error for SAL 21704: HTTP Error 404: Not Found
# ❌ Error for SAL 21720: HTTP Error 404: Not Found
# ❌ Error for SAL 21730: HTTP Error 404: Not Found
# ✅ Downloaded 1600 files...
# ❌ Error for SAL 21747: HTTP Error 404: Not Found
# ❌ Error for SAL 21752: HTTP Error 404: Not Found
# ❌ Error for SAL 21764: HTTP Error 404: Not Found
# ❌ Error for SAL 21766: HTTP Error 404: Not Found
# ❌ Error for SAL 21768: HTTP Error 404: Not Found
# ❌ Error for SAL 21773: HTTP Error 404: Not Found
# ❌ Error for SAL 21777: HTTP Error 404: Not Found
# ❌ Error for SAL 21785: HTTP Error 404: Not Found
# ❌ Error for SAL 21789: HTTP Error 404: Not Found
# ✅ Downloaded 1650 files...
# ❌ Error for SAL 21811: HTTP Error 404: Not Found
# ❌ Error for SAL 21812: HTTP Error 404: Not Found
# ✅ Downloaded 1700 files...
# ❌ Error for SAL 21876: HTTP Error 404: Not Found
# ✅ Downloaded 1750 files...
# ❌ Error for SAL 21905: HTTP Error 404: Not Found
# ❌ Error for SAL 21913: HTTP Error 404: Not Found
# ❌ Error for SAL 21945: HTTP Error 404: Not Found
# ✅ Downloaded 1800 files...
# ❌ Error for SAL 21987: HTTP Error 404: Not Found
# ❌ Error for SAL 21990: HTTP Error 404: Not Found
# ❌ Error for SAL 21995: HTTP Error 404: Not Found
# ✅ Downloaded 1850 files...
# ❌ Error for SAL 22003: HTTP Error 404: Not Found
# ❌ Error for SAL 22004: HTTP Error 404: Not Found
# ✅ Downloaded 1900 files...
# ❌ Error for SAL 22063: HTTP Error 404: Not Found
# ❌ Error for SAL 22076: HTTP Error 404: Not Found
# ❌ Error for SAL 22089: HTTP Error 404: Not Found
# ❌ Error for SAL 22090: HTTP Error 404: Not Found
# ✅ Downloaded 1950 files...
# ❌ Error for SAL 22116: HTTP Error 404: Not Found
# ❌ Error for SAL 22132: HTTP Error 404: Not Found
# ❌ Error for SAL 22157: HTTP Error 404: Not Found
# ✅ Downloaded 2000 files...
# ❌ Error for SAL 22162: HTTP Error 404: Not Found
# ❌ Error for SAL 22166: HTTP Error 404: Not Found
# ❌ Error for SAL 22167: HTTP Error 404: Not Found
# ❌ Error for SAL 22168: HTTP Error 404: Not Found
# ❌ Error for SAL 22189: HTTP Error 404: Not Found
# ❌ Error for SAL 22196: HTTP Error 404: Not Found
# ❌ Error for SAL 22200: HTTP Error 404: Not Found
# ❌ Error for SAL 22205: HTTP Error 404: Not Found
# ✅ Downloaded 2050 files...
# ❌ Error for SAL 22218: HTTP Error 404: Not Found
# ❌ Error for SAL 22231: HTTP Error 404: Not Found
# ❌ Error for SAL 22237: HTTP Error 404: Not Found
# ❌ Error for SAL 22259: HTTP Error 404: Not Found
# ❌ Error for SAL 22267: HTTP Error 404: Not Found
# ✅ Downloaded 2100 files...
# ❌ Error for SAL 22273: HTTP Error 404: Not Found
# ❌ Error for SAL 22300: HTTP Error 404: Not Found
# ✅ Downloaded 2150 files...
# ❌ Error for SAL 22324: HTTP Error 404: Not Found
# ❌ Error for SAL 22358: HTTP Error 404: Not Found
# ❌ Error for SAL 22363: HTTP Error 404: Not Found
# ❌ Error for SAL 22368: HTTP Error 404: Not Found
# ✅ Downloaded 2200 files...
# ❌ Error for SAL 22390: HTTP Error 404: Not Found
# ❌ Error for SAL 22402: HTTP Error 404: Not Found
# ❌ Error for SAL 22406: HTTP Error 404: Not Found
# ❌ Error for SAL 22407: HTTP Error 404: Not Found
# ❌ Error for SAL 22411: HTTP Error 404: Not Found
# ❌ Error for SAL 22416: HTTP Error 404: Not Found
# ✅ Downloaded 2250 files...
# ❌ Error for SAL 22434: HTTP Error 404: Not Found
# ❌ Error for SAL 22435: HTTP Error 404: Not Found
# ❌ Error for SAL 22442: HTTP Error 404: Not Found
# ✅ Downloaded 2300 files...
# ❌ Error for SAL 22492: HTTP Error 404: Not Found
# ❌ Error for SAL 22495: HTTP Error 404: Not Found
# ❌ Error for SAL 22505: HTTP Error 404: Not Found
# ❌ Error for SAL 22515: HTTP Error 404: Not Found
# ❌ Error for SAL 22524: HTTP Error 404: Not Found
# ❌ Error for SAL 22527: HTTP Error 404: Not Found
# ❌ Error for SAL 22539: HTTP Error 404: Not Found
# ❌ Error for SAL 22542: HTTP Error 404: Not Found
# ✅ Downloaded 2350 files...
# ❌ Error for SAL 22549: HTTP Error 404: Not Found
# ❌ Error for SAL 22556: HTTP Error 404: Not Found
# ❌ Error for SAL 22557: HTTP Error 404: Not Found
# ❌ Error for SAL 22560: HTTP Error 404: Not Found
# ❌ Error for SAL 22561: HTTP Error 404: Not Found
# ❌ Error for SAL 22590: HTTP Error 404: Not Found
# ❌ Error for SAL 22595: HTTP Error 404: Not Found
# ✅ Downloaded 2400 files...
# ❌ Error for SAL 22609: HTTP Error 404: Not Found
# ❌ Error for SAL 22641: HTTP Error 404: Not Found
# ❌ Error for SAL 22642: HTTP Error 404: Not Found
# ❌ Error for SAL 22652: HTTP Error 404: Not Found
# ❌ Error for SAL 22654: HTTP Error 404: Not Found
# ✅ Downloaded 2450 files...
# ❌ Error for SAL 22658: HTTP Error 404: Not Found
# ❌ Error for SAL 22659: HTTP Error 404: Not Found
# ❌ Error for SAL 22660: HTTP Error 404: Not Found
# ❌ Error for SAL 22677: HTTP Error 404: Not Found
# ❌ Error for SAL 22679: HTTP Error 404: Not Found
# ❌ Error for SAL 22682: HTTP Error 404: Not Found
# ❌ Error for SAL 22694: HTTP Error 404: Not Found
# ✅ Downloaded 2500 files...
# ❌ Error for SAL 22725: HTTP Error 404: Not Found
# ❌ Error for SAL 22731: HTTP Error 404: Not Found
# ❌ Error for SAL 22747: HTTP Error 404: Not Found
# ✅ Downloaded 2550 files...
# ❌ Error for SAL 22790: HTTP Error 404: Not Found
# ❌ Error for SAL 22796: HTTP Error 404: Not Found
# ❌ Error for SAL 22806: HTTP Error 404: Not Found
# ❌ Error for SAL 22809: HTTP Error 404: Not Found
# ❌ Error for SAL 22810: HTTP Error 404: Not Found
# ❌ Error for SAL 22817: HTTP Error 404: Not Found
# ✅ Downloaded 2600 files...
# ❌ Error for SAL 22827: HTTP Error 404: Not Found
# ❌ Error for SAL 22828: HTTP Error 404: Not Found
# ❌ Error for SAL 22849: HTTP Error 404: Not Found
# ❌ Error for SAL 22865: HTTP Error 404: Not Found
# ❌ Error for SAL 22866: HTTP Error 404: Not Found
# ❌ Error for SAL 22867: HTTP Error 404: Not Found
# ❌ Error for SAL 22868: HTTP Error 404: Not Found
# ❌ Error for SAL 22871: HTTP Error 404: Not Found
# ❌ Error for SAL 22872: HTTP Error 404: Not Found
# ❌ Error for SAL 22878: HTTP Error 404: Not Found
# ✅ Downloaded 2650 files...
# ❌ Error for SAL 22895: HTTP Error 404: Not Found
# ❌ Error for SAL 22905: HTTP Error 404: Not Found
# ❌ Error for SAL 22923: HTTP Error 404: Not Found
# ✅ Downloaded 2700 files...
# ❌ Error for SAL 22936: HTTP Error 404: Not Found
# ❌ Error for SAL 22944: HTTP Error 404: Not Found
#
# ✅ Downloaded 2707 files in 1784.51s
# ❌ Failed downloads: 233

# %% [markdown]
# #### Domain Rental Listings Scraping
#
# The project includes a comprehensive Scrapy-based scraper for Domain.com.au rental listings. This scraper can collect both current live listings and historical data from Wayback Machine archives.

# %% [markdown]
# ##### Live Listings Scraping
#
# To scrape current rental listings from Domain.com.au:
#
# ```bash
# # Navigate to the scraper directory
# cd scraping/domain_scraper
#
# # Test the scraper first (recommended)
# python test_spider.py
#
# # Run full live listings scraping
# python run_spider.py
# ```
#
# **Output**: `data/landing/domain/live/rental_listings_2025_09.csv`
#
# **Features**:
# - Scrapes all Victorian suburbs (3,186+ suburbs)
# - Extracts detailed property information including features, amenities, and market insights
# - Uses conservative settings to avoid being blocked
# - Includes property images using Selenium

# %% [markdown]
# ##### Wayback Historical Scraping
#
# To scrape historical rental listings from 2022-2025:
#
# ```bash
# # Navigate to the scraper directory
# cd scraping/domain_scraper
#
# # Run wayback historical scraping
# python run_wayback_spider.py
# ```
#
# **Output**: `data/landing/domain/wayback/rental_listings_YYYY_MM.csv` (multiple files)
#
# **Features**:
# - Scrapes quarterly snapshots from 2022 Q3 to 2025 Q2
# - Uses Wayback Machine archives to access historical data
# - Processes suburbs with available timestamps for each quarter
# - Consolidates results into quarterly CSV files
#
# **Note**: This process can take several hours as it processes thousands of suburbs across multiple quarters.

# %% [markdown]
# ##### Scraper Configuration
#
# The scraper is configured with:
# - **Concurrent requests**: 4 (conservative to avoid blocking)
# - **Delay between requests**: 1 second (with randomization)
# - **Auto-throttling**: Enabled to adapt to server response
# - **Expected duration**: Several hours for full scraping
# - **Memory management**: Processes suburbs sequentially
#
# For detailed configuration and troubleshooting, see `scraping/domain_scraper/SCRAPING_INSTRUCTIONS.md`.
