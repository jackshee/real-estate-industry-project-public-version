# %% [markdown]
# # XGBoost Model for Rental Price
#
# This notebook trains an XGBoost regressor to predict `rental_price` using the dataset:
# `data/curated/rent_features/cleaned_listings_parquet`.
#
# It loads and preprocesses the data, splits into train/validation/test, fits the model,
# evaluates metrics, and inspects feature importances.

# %%
# Imports
import os, sys, inspect
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, TargetEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.base import BaseEstimator, TransformerMixin

# XGBoost
try:
    from xgboost import XGBRegressor
    try:
        # Preferred in newer XGBoost versions (>=2.x/3.x)
        from xgboost.callback import EarlyStopping as XGB_EarlyStopping
    except Exception:
        XGB_EarlyStopping = None
except Exception as e:
    print("xgboost is not installed. Install with: pip install xgboost")
    raise

np.random.seed(42)
sns.set_theme(style="whitegrid")

# %%
# Locate and load the dataset using Spark (supports running from repo root or notebooks/)
from pyspark.sql import SparkSession
from pathlib import Path
import pandas as pd

# Create a spark session
spark = (
    SparkSession.builder.appName("MAST30034 Model Training")
    .config("spark.sql.repl.eagerEval.enabled", True) 
    .config("spark.sql.parquet.cacheMetadata", "true")
    .config("spark.sql.session.timeZone", "Etc/UTC")
    .config("spark.driver.memory", "6g")
    .getOrCreate()
)

# Define possible paths for the parquet directory
PARQUET_PATHS = [
    Path('../data/curated/rent_features/cleaned_listings_parquet'),
]

parquet_path = None
for p in PARQUET_PATHS:
    if p.exists():
        parquet_path = p
        break

if parquet_path is None:
    raise FileNotFoundError(
        "Could not find Parquet directory at expected paths: " + ", ".join(map(str, PARQUET_PATHS))
    )

# Optional sampling to speed up experimentation on large files
USE_SAMPLE = False   # set True to sample a subset for quick runs
SAMPLE_FRAC = 0.2
SAMPLE_RANDOM_STATE = 42

# Load parquet files using Spark
spark_df = spark.read.parquet(str(parquet_path))

# Convert to pandas DataFrame
df = spark_df.toPandas()

# Apply sampling if requested
if USE_SAMPLE:
    df = df.sample(frac=SAMPLE_FRAC, random_state=SAMPLE_RANDOM_STATE).reset_index(drop=True)

print(f"Loaded parquet files from {parquet_path} with shape: {df.shape}")
print(f"Spark DataFrame partitions: {spark_df.rdd.getNumPartitions()}")

# Stop the Spark session
spark.stop()

df.head(3)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/10/22 14:26:44 WARN Utils: Your hostname, Pikachu.local, resolves to a loopback address: 127.0.0.1; using 192.168.1.46 instead (on interface en0)
# 25/10/22 14:26:44 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/22 14:26:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/10/22 14:27:02 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Loaded parquet files from ../data/curated/rent_features/cleaned_listings_parquet with shape: (24027, 133)
# Spark DataFrame partitions: 13
#    bedrooms  property_id  year   source  quarter  bathrooms  rental_price  \
# 0         2     16637685  2023  wayback        3          2         850.0
# 1         2     16410483  2023     live        2          1         620.0
# 2         2     16143495  2023     live        2          1         650.0
#
#       suburb   longitude  car_spaces  ...  \
# 0  melbourne  144.969114           1  ...
# 1    bendigo  144.294778           1  ...
# 2   box hill  145.118664           1  ...
#
#                       geom_driving_15min_imputed_wkt  \
# 0  POLYGON ((144.884321 -37.823826, 144.884545 -3...
# 1  POLYGON ((144.218716 -36.707302, 144.218379 -3...
# 2  POLYGON ((145.003973 -37.796644, 145.005267 -3...
#
#                        geom_walking_5min_imputed_wkt  \
# 0  POLYGON ((144.965033 -37.810567, 144.965772 -3...
# 1  POLYGON ((144.291669 -36.747472, 144.291474 -3...
# 2  POLYGON ((145.114079 -37.817069, 145.114686 -3...
#
#                       geom_walking_10min_imputed_wkt  \
# 0  POLYGON ((144.96053 -37.811191, 144.960505 -37...
# 1  POLYGON ((144.288201 -36.749029, 144.289182 -3...
# 2  POLYGON ((145.109408 -37.816478, 145.109996 -3...
#
#                       geom_walking_15min_imputed_wkt  \
# 0  POLYGON ((144.957043 -37.806301, 144.957237 -3...
# 1  POLYGON ((144.284927 -36.746552, 144.285285 -3...
# 2  POLYGON ((145.104716 -37.815921, 145.106036 -3...
#
#    best_school_coord_driving_5min_wkt  best_school_coord_driving_10min_wkt  \
# 0                                 nan                                  nan
# 1         POINT (144.27273 -36.76261)          POINT (144.27273 -36.76261)
# 2            POINT (145.13721 -37.82)          POINT (145.11777 -37.84722)
#
#    best_school_coord_driving_15min_wkt  best_school_coord_walking_5min_wkt  \
# 0                                  nan                                 nan
# 1          POINT (144.27273 -36.76261)         POINT (144.29798 -36.73893)
# 2          POINT (145.11777 -37.84722)         POINT (145.12992 -37.81835)
#
#    best_school_coord_walking_10min_wkt  best_school_coord_walking_15min_wkt
# 0                                  nan                                  nan
# 1          POINT (144.29798 -36.73893)          POINT (144.29798 -36.73893)
# 2          POINT (145.12992 -37.81835)          POINT (145.12992 -37.81835)
#
# [3 rows x 133 columns]

# %%
# Target: ensure numeric, drop NAs, and filter outliers
if 'rental_price' not in df.columns:
    raise KeyError("Column 'rental_price' not found in data.")

df['rental_price'] = pd.to_numeric(df['rental_price'], errors='coerce')
df = df.dropna(subset=['rental_price']).reset_index(drop=True)

# Target outlier filtering (configure as needed)
FILTER_TARGET_OUTLIERS = False # converted to False because outliers are now filtered in preprocessing_domain
TARGET_FILTER_METHOD = 'quantile'  # 'quantile' or 'fixed'
TARGET_Q_LOW = 0.01
TARGET_Q_HIGH = 0.99
TARGET_FIXED_RANGE = (100, 3000)  # used when method == 'fixed'

if FILTER_TARGET_OUTLIERS:
    if TARGET_FILTER_METHOD == 'quantile':
        low = float(df['rental_price'].quantile(TARGET_Q_LOW))
        high = float(df['rental_price'].quantile(TARGET_Q_HIGH))
    elif TARGET_FILTER_METHOD == 'fixed':
        low, high = TARGET_FIXED_RANGE
    else:
        raise ValueError("Unknown TARGET_FILTER_METHOD; use 'quantile' or 'fixed'")
    before = len(df)
    mask = (df['rental_price'] >= low) & (df['rental_price'] <= high)
    df = df.loc[mask].reset_index(drop=True)
    print(f"Filtered target to [{low:.2f}, {high:.2f}] — kept {len(df)}/{before} rows")

# Keep raw target and allow optional log transform later
y_raw = df['rental_price'].astype(float)
X = df.drop(columns=['rental_price'])

# Drop common identifier/free-text columns if present (avoids huge one-hot)
drop_if_present = [
    'id','ID','listing_id','property_id', 'source', 'address','url','link','description','title',
    'full_address','street_address','listing_url','latlon_str','geometry','geom','wkt'
]
cols_to_drop = [c for c in drop_if_present if c in X.columns]
if cols_to_drop:
    X = X.drop(columns=cols_to_drop)

print('Feature matrix shape:', X.shape, '| Target length:', len(y_raw))
X.head(3)
# Out:
# Feature matrix shape: (24027, 130) | Target length: 24027
#    bedrooms  year  quarter  bathrooms     suburb   longitude  car_spaces  \
# 0         2  2023        3          2  melbourne  144.969114           1
# 1         2  2023        2          1    bendigo  144.294778           1
# 2         2  2023        2          1   box hill  145.118664           1
#
#     latitude            property_type  count_childcare_imputed  ...  \
# 0 -37.809525  Apartment / Unit / Flat                      3.0  ...
# 1 -36.745616                    house                      0.0  ...
# 2 -37.817601  apartment / unit / flat                     10.0  ...
#
#                       geom_driving_15min_imputed_wkt  \
# 0  POLYGON ((144.884321 -37.823826, 144.884545 -3...
# 1  POLYGON ((144.218716 -36.707302, 144.218379 -3...
# 2  POLYGON ((145.003973 -37.796644, 145.005267 -3...
#
#                        geom_walking_5min_imputed_wkt  \
# 0  POLYGON ((144.965033 -37.810567, 144.965772 -3...
# 1  POLYGON ((144.291669 -36.747472, 144.291474 -3...
# 2  POLYGON ((145.114079 -37.817069, 145.114686 -3...
#
#                       geom_walking_10min_imputed_wkt  \
# 0  POLYGON ((144.96053 -37.811191, 144.960505 -37...
# 1  POLYGON ((144.288201 -36.749029, 144.289182 -3...
# 2  POLYGON ((145.109408 -37.816478, 145.109996 -3...
#
#                       geom_walking_15min_imputed_wkt  \
# 0  POLYGON ((144.957043 -37.806301, 144.957237 -3...
# 1  POLYGON ((144.284927 -36.746552, 144.285285 -3...
# 2  POLYGON ((145.104716 -37.815921, 145.106036 -3...
#
#    best_school_coord_driving_5min_wkt  best_school_coord_driving_10min_wkt  \
# 0                                 nan                                  nan
# 1         POINT (144.27273 -36.76261)          POINT (144.27273 -36.76261)
# 2            POINT (145.13721 -37.82)          POINT (145.11777 -37.84722)
#
#    best_school_coord_driving_15min_wkt  best_school_coord_walking_5min_wkt  \
# 0                                  nan                                 nan
# 1          POINT (144.27273 -36.76261)         POINT (144.29798 -36.73893)
# 2          POINT (145.11777 -37.84722)         POINT (145.12992 -37.81835)
#
#    best_school_coord_walking_10min_wkt  best_school_coord_walking_15min_wkt
# 0                                  nan                                  nan
# 1          POINT (144.29798 -36.73893)          POINT (144.29798 -36.73893)
# 2          POINT (145.12992 -37.81835)          POINT (145.12992 -37.81835)
#
# [3 rows x 130 columns]

# %%
# Identify feature types from the updated dataset schema
import numpy as np

# Start from the current feature matrix X (df.drop('rental_price'))
X0 = X.copy()

# 1) Drop non-model features (geometry/text blobs, IDs)
drop_exact = {
    'rental_price',
    'property_id',
    'coordinates',
    'listing_point',
    'closest_ptv_station_id',
    'closest_ptv_station_id_imputed'
}
drop_prefixes = ('geom_', 'best_school_name_', 'best_school_coord_')
to_drop = set(c for c in X0.columns if c in drop_exact or any(c.startswith(p) for p in drop_prefixes))
X1 = X0.drop(columns=list(to_drop), errors='ignore')

# 2) Categorical features: real categories present in schema
cat_allow = ['property_type', 'suburb']
categorical_features = [c for c in cat_allow if c in X1.columns]

# 3) Numeric features: all numeric dtypes, excluding numeric IDs/coords if desired
numeric_candidates = X1.select_dtypes(include=[np.number]).columns.tolist()
numeric_exclude = {
    'latitude', 'longitude',
    'closest_ptv_station_id', 'closest_ptv_station_id_imputed',
}
numeric_features = [c for c in numeric_candidates if c not in numeric_exclude]

# 4) Rebuild X using the derived schema
X = X1[categorical_features + numeric_features]

# 5) Summary
print(f"Categorical: {len(categorical_features)} | Numeric: {len(numeric_features)}")
print('Categorical cols:', categorical_features)
print('Numeric sample:', numeric_features[:10])
obj_skipped = sorted(set(X1.select_dtypes(include=['object', 'string']).columns) - set(categorical_features))
if obj_skipped:
    print(f'Skipped {len(obj_skipped)} object/text columns (e.g.):', obj_skipped[:8], '...' if len(obj_skipped) > 8 else '')
# Out:
# Categorical: 2 | Numeric: 87
# Categorical cols: ['property_type', 'suburb']
# Numeric sample: ['bedrooms', 'year', 'quarter', 'bathrooms', 'car_spaces', 'count_childcare_imputed', 'count_community_centre_imputed', 'count_fast_food_imputed', 'count_fire_station_imputed', 'count_pharmacy_imputed']
# Skipped 13 object/text columns (e.g.): ['coordinates_wkt', 'driving_10min_imputed_wkt', 'driving_10min_wkt', 'driving_15min_imputed_wkt', 'driving_15min_wkt', 'driving_5min_imputed_wkt', 'driving_5min_wkt', 'walking_10min_imputed_wkt'] ...

# %%
# Feature matrix after schema-based selection
print('Reduced feature matrix shape:', X.shape)
X.head(3)
# Out:
# Reduced feature matrix shape: (24027, 89)
#              property_type     suburb  bedrooms  year  quarter  bathrooms  \
# 0  Apartment / Unit / Flat  melbourne         2  2023        3          2
# 1                    house    bendigo         2  2023        2          1
# 2  apartment / unit / flat   box hill         2  2023        2          1
#
#    car_spaces  count_childcare_imputed  count_community_centre_imputed  \
# 0           1                      3.0                            14.0
# 1           1                      0.0                             1.0
# 2           1                     10.0                             8.0
#
#    count_fast_food_imputed  ...  n_schools_driving_15min  \
# 0                    279.0  ...                      0.0
# 1                      5.0  ...                     28.0
# 2                     20.0  ...                    124.0
#
#    best_score_walking_5min  best_dist_km_walking_5min  n_schools_walking_5min  \
# 0             3.000000e-08                  15.674877                     0.0
# 1            -8.627893e-05                   0.795158                     1.0
# 2            -8.340861e-05                   0.994585                     2.0
#
#    best_score_walking_10min  best_dist_km_walking_10min  \
# 0              3.000000e-08                   15.674877
# 1             -8.627893e-05                    0.795158
# 2             -8.340861e-05                    0.994585
#
#    n_schools_walking_10min  best_score_walking_15min  \
# 0                      0.0              3.000000e-08
# 1                      1.0             -8.627893e-05
# 2                      2.0             -8.340861e-05
#
#    best_dist_km_walking_15min  n_schools_walking_15min
# 0                    2.865406                      0.0
# 1                    0.795158                      1.0
# 2                    0.994585                      2.0
#
# [3 rows x 89 columns]

# %%
# quickly clean property_type
# was missed in earlier cleaning steps
if 'property_type' in X.columns:
    X['property_type'] = X['property_type'].str.lower().str.strip()
    common_types = ['house', 'apartment / unit / flat', 'townhouse', 'villa', 'duplex']
    X['property_type'] = X['property_type'].where(
        X['property_type'].isin(common_types), other='other'
    )
    print("Unique property_type values after cleaning:", X['property_type'].unique())
# Out:
# Unique property_type values after cleaning: ['apartment / unit / flat' 'house' 'townhouse' 'other' 'villa' 'duplex']
# /var/folders/xj/ny4zmnqd609bv2rpjzzr11rm0000gn/T/ipykernel_43643/841258739.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['property_type'] = X['property_type'].str.lower().str.strip()
# /var/folders/xj/ny4zmnqd609bv2rpjzzr11rm0000gn/T/ipykernel_43643/841258739.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['property_type'] = X['property_type'].where(

# %%
# fill missing numeric with 0 for n_schools
for col in numeric_features:
    if col.startswith('n_schools_'):
        X[col] = X[col].fillna(0)
# Out:
# /var/folders/xj/ny4zmnqd609bv2rpjzzr11rm0000gn/T/ipykernel_43643/1166042083.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = X[col].fillna(0)

# %%
# Identify feature types with a guard against high-cardinality categoricals
# numeric_features = X.select_dtypes(include=[np.number]).columns.tolist()
# categorical_candidates = X.columns.difference(numeric_features)

# max_unique_cats = 100  # avoid exploding OHE on huge text-like columns
# categorical_features, dropped_high_cardinality = [], []
# for col in categorical_candidates:
#     nunique = X[col].nunique(dropna=True)
#     if nunique <= max_unique_cats:
#         categorical_features.append(col)
#     else:
#         dropped_high_cardinality.append(col)

# print(f"Numeric features: {len(numeric_features)}")
# print(f"Categorical features (<= {max_unique_cats} levels): {len(categorical_features)}")
# if dropped_high_cardinality:
#     print(f"Dropping {len(dropped_high_cardinality)} high-cardinality columns (sample): {dropped_high_cardinality[:10]}")

# %%
# Build preprocessors (impute + one-hot)
# Requires 'numeric_features' and 'categorical_features' to be defined above
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
])

# OneHotEncoder signature differs across sklearn versions
try:
    ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=True)
except TypeError:
    ohe = OneHotEncoder(handle_unknown='ignore', sparse=True)

# Split categorical features into OHE vs TargetEncoder
cat_te_cols = [col for col in ['suburb'] if col in categorical_features]
cat_ohe_cols = [col for col in categorical_features if col not in cat_te_cols]
print('Target-encoded:', cat_te_cols, '| One-hot:', cat_ohe_cols)

ohe_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe', ohe),
])

te_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('te', TargetEncoder(target_type='auto')),
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat_ohe', ohe_transformer, cat_ohe_cols),
        ('cat_te', te_transformer, cat_te_cols),
    ],
    remainder='drop',
    verbose_feature_names_out=True,
)
# Out:
# Target-encoded: ['suburb'] | One-hot: ['property_type']

# %%
# Train/val/test split
USE_LOG_TARGET = True  # if True, train on log1p(target) and evaluate on original scale

# Split using raw target first to preserve original-scale y for metrics
X_train, X_test, y_train_raw, y_test_raw = train_test_split(X, y_raw, test_size=0.4, random_state=42)
X_train, X_val, y_train_raw, y_val_raw = train_test_split(X_train, y_train_raw, test_size=0.25, random_state=42)

# Derive training targets (log or raw)
if USE_LOG_TARGET:
    y_train = np.log1p(y_train_raw)
    y_val = np.log1p(y_val_raw)
    y_test = np.log1p(y_test_raw)
else:
    y_train, y_val, y_test = y_train_raw, y_val_raw, y_test_raw

# Fit preprocessor on training data and transform all splits
preprocessor.fit(X_train, y_train)
X_train_t = preprocessor.transform(X_train)
X_val_t = preprocessor.transform(X_val)
X_test_t = preprocessor.transform(X_test)

print('Transformed shapes:', X_train_t.shape, X_val_t.shape, X_test_t.shape)
# Out:
# Transformed shapes: (10812, 94) (3604, 94) (9611, 94)

# %%
# Define and train the XGBoost regressor (with early stopping on the validation set)
xgb = XGBRegressor(
    n_estimators=1000,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=1.0,
    objective='reg:squarederror',
    random_state=42,
    n_jobs=-1,
    tree_method='hist',
    eval_metric='rmse',
)

# Build fit kwargs only with supported parameters for this xgboost version
fit_sig = inspect.signature(XGBRegressor().fit)
supports_callbacks = 'callbacks' in fit_sig.parameters
supports_esr = 'early_stopping_rounds' in fit_sig.parameters

fit_kwargs = {'eval_set': [(X_val_t, y_val)]}

if supports_callbacks and XGB_EarlyStopping is not None:
    fit_kwargs['callbacks'] = [XGB_EarlyStopping(rounds=50, save_best=True, maximize=False)]
elif supports_esr:
    fit_kwargs['early_stopping_rounds'] = 50

xgb.fit(X_train_t, y_train, **fit_kwargs)

# Robust best-iteration retrieval across xgboost versions
def get_best_iter(est):
    # 1) Try estimator attributes
    for attr in ('best_iteration', 'best_ntree_limit', 'best_score', 'best_iteration_'):
        if hasattr(est, attr):
            val = getattr(est, attr)
            if val is not None:
                return attr, val
    # 2) Try Booster attributes
    try:
        b = est.get_booster()
        for attr in ('best_iteration', 'best_ntree_limit', 'best_score'):
            if hasattr(b, attr):
                val = getattr(b, attr)
                if val is not None:
                    return f'booster.{attr}', val
    except Exception:
        pass
    # 3) Derive from evals_result if available
    try:
        ev = est.evals_result()
        if isinstance(ev, dict) and len(ev)>0:
            ds = next(iter(ev))  # e.g., 'validation_0'
            metric = next(iter(ev[ds]))
            import numpy as np
            idx = int(np.argmin(ev[ds][metric]))
            return 'derived_from_evals_result', idx
    except Exception:
        pass
    return None, None

src, best = get_best_iter(xgb)
if src is None:
    # No early stopping info found. This usually means early stopping didn't trigger
    # or no eval_set/metric was provided. The model likely used all trees.
    print(f"No best iteration attribute found; using all {xgb.get_params().get('n_estimators')} estimators.")
else:
    print(f"Best iteration source: {src}; value: {best}")

# Report parameters used at the selected iteration
try:
    xgb_params = xgb.get_xgb_params()
except Exception:
    xgb_params = xgb.get_params()
wrapper_params = xgb.get_params()
# Determine how many estimators were actually used
used_estimators = wrapper_params.get('n_estimators')
try:
    import numpy as np
    if src is not None and isinstance(best, (int, np.integer)):
        if 'best_ntree_limit' in str(src):
            used_estimators = int(best)
        else:
            used_estimators = int(best) + 1
except Exception:
    pass
# Key booster hyperparameters
keys = ['objective','learning_rate','max_depth','min_child_weight','subsample','colsample_bytree','reg_alpha','reg_lambda']
key_params = {k: xgb_params.get(k) for k in keys if k in xgb_params}
print('Planned n_estimators:', wrapper_params.get('n_estimators'), '| Used (best):', used_estimators)
print('Key booster parameters:', key_params)
# If evals_result is available, print the metric value at the best iteration
try:
    ev = xgb.evals_result()
    if isinstance(ev, dict) and len(ev)>0:
        ds = next(iter(ev))
        metric = next(iter(ev[ds]))
        series = ev[ds][metric]
        idx = None
        try:
            idx = int(np.argmin(series))
        except Exception:
            pass
        # Prefer derived index if earlier found
        if src is not None and isinstance(best, (int, np.integer)):
            if 'best_ntree_limit' in str(src):
                idx = int(best) - 1 if best else None
            else:
                idx = int(best)
        if idx is not None and 0 <= idx < len(series):
            print(f"Validation metric {metric} on {ds}: best={series[idx]:.6f} at iteration={idx}")
except Exception:
    pass
# Out:
# [0]	validation_0-rmse:0.29752
# [1]	validation_0-rmse:0.28968
# [2]	validation_0-rmse:0.28128
# [3]	validation_0-rmse:0.27324
# [4]	validation_0-rmse:0.26595
# [5]	validation_0-rmse:0.26034
# [6]	validation_0-rmse:0.25497
# [7]	validation_0-rmse:0.24951
# [8]	validation_0-rmse:0.24320
# [9]	validation_0-rmse:0.23770
# [10]	validation_0-rmse:0.23212
# [11]	validation_0-rmse:0.22688
# [12]	validation_0-rmse:0.22225
# [13]	validation_0-rmse:0.21768
# [14]	validation_0-rmse:0.21344
# [15]	validation_0-rmse:0.20964
# [16]	validation_0-rmse:0.20609
# [17]	validation_0-rmse:0.20279
# [18]	validation_0-rmse:0.19959
# [19]	validation_0-rmse:0.19669
# [20]	validation_0-rmse:0.19397
# [21]	validation_0-rmse:0.19139
# [22]	validation_0-rmse:0.18914
# [23]	validation_0-rmse:0.18709
# [24]	validation_0-rmse:0.18514
# [25]	validation_0-rmse:0.18353
# [26]	validation_0-rmse:0.18202
# [27]	validation_0-rmse:0.18039
# [28]	validation_0-rmse:0.17869
# [29]	validation_0-rmse:0.17719
# [30]	validation_0-rmse:0.17560
# [31]	validation_0-rmse:0.17431
# [32]	validation_0-rmse:0.17313
# [33]	validation_0-rmse:0.17194
# [34]	validation_0-rmse:0.17082
# [35]	validation_0-rmse:0.16983
# [36]	validation_0-rmse:0.16882
# [37]	validation_0-rmse:0.16784
# [38]	validation_0-rmse:0.16698
# [39]	validation_0-rmse:0.16630
# [40]	validation_0-rmse:0.16542
# [41]	validation_0-rmse:0.16475
# [42]	validation_0-rmse:0.16409
# [43]	validation_0-rmse:0.16345
# [44]	validation_0-rmse:0.16284
# [45]	validation_0-rmse:0.16226
# [46]	validation_0-rmse:0.16169
# [47]	validation_0-rmse:0.16124
# [48]	validation_0-rmse:0.16081
# [49]	validation_0-rmse:0.16016
# [50]	validation_0-rmse:0.15962
# [51]	validation_0-rmse:0.15916
# [52]	validation_0-rmse:0.15874
# [53]	validation_0-rmse:0.15844
# [54]	validation_0-rmse:0.15809
# [55]	validation_0-rmse:0.15778
# [56]	validation_0-rmse:0.15751
# [57]	validation_0-rmse:0.15726
# [58]	validation_0-rmse:0.15692
# [59]	validation_0-rmse:0.15661
# [60]	validation_0-rmse:0.15629
# [61]	validation_0-rmse:0.15615
# [62]	validation_0-rmse:0.15587
# [63]	validation_0-rmse:0.15569
# [64]	validation_0-rmse:0.15541
# [65]	validation_0-rmse:0.15511
# [66]	validation_0-rmse:0.15486
# [67]	validation_0-rmse:0.15468
# [68]	validation_0-rmse:0.15448
# [69]	validation_0-rmse:0.15430
# [70]	validation_0-rmse:0.15417
# [71]	validation_0-rmse:0.15400
# [72]	validation_0-rmse:0.15381
# [73]	validation_0-rmse:0.15368
# [74]	validation_0-rmse:0.15351
# [75]	validation_0-rmse:0.15335
# [76]	validation_0-rmse:0.15322
# [77]	validation_0-rmse:0.15310
# [78]	validation_0-rmse:0.15289
# [79]	validation_0-rmse:0.15273
# [80]	validation_0-rmse:0.15258
# [81]	validation_0-rmse:0.15245
# [82]	validation_0-rmse:0.15229
# [83]	validation_0-rmse:0.15219
# [84]	validation_0-rmse:0.15202
# [85]	validation_0-rmse:0.15191
# [86]	validation_0-rmse:0.15183
# [87]	validation_0-rmse:0.15169
# [88]	validation_0-rmse:0.15162
# [89]	validation_0-rmse:0.15152
# [90]	validation_0-rmse:0.15144
# [91]	validation_0-rmse:0.15129
# [92]	validation_0-rmse:0.15114
# [93]	validation_0-rmse:0.15099
# [94]	validation_0-rmse:0.15093
# [95]	validation_0-rmse:0.15086
# [96]	validation_0-rmse:0.15078
# [97]	validation_0-rmse:0.15066
# [98]	validation_0-rmse:0.15057
# [99]	validation_0-rmse:0.15048
# [100]	validation_0-rmse:0.15037
# [101]	validation_0-rmse:0.15036
# [102]	validation_0-rmse:0.15028
# [103]	validation_0-rmse:0.15022
# [104]	validation_0-rmse:0.15005
# [105]	validation_0-rmse:0.14997
# [106]	validation_0-rmse:0.14990
# [107]	validation_0-rmse:0.14986
# [108]	validation_0-rmse:0.14977
# [109]	validation_0-rmse:0.14972
# [110]	validation_0-rmse:0.14966
# [111]	validation_0-rmse:0.14957
# [112]	validation_0-rmse:0.14941
# [113]	validation_0-rmse:0.14932
# [114]	validation_0-rmse:0.14918
# [115]	validation_0-rmse:0.14906
# [116]	validation_0-rmse:0.14900
# [117]	validation_0-rmse:0.14896
# [118]	validation_0-rmse:0.14892
# [119]	validation_0-rmse:0.14891
# [120]	validation_0-rmse:0.14873
# [121]	validation_0-rmse:0.14862
# [122]	validation_0-rmse:0.14863
# [123]	validation_0-rmse:0.14859
# [124]	validation_0-rmse:0.14853
# [125]	validation_0-rmse:0.14844
# [126]	validation_0-rmse:0.14835
# [127]	validation_0-rmse:0.14833
# [128]	validation_0-rmse:0.14830
# [129]	validation_0-rmse:0.14828
# [130]	validation_0-rmse:0.14824
# [131]	validation_0-rmse:0.14821
# [132]	validation_0-rmse:0.14813
# [133]	validation_0-rmse:0.14806
# [134]	validation_0-rmse:0.14800
# [135]	validation_0-rmse:0.14792
# [136]	validation_0-rmse:0.14789
# [137]	validation_0-rmse:0.14791
# [138]	validation_0-rmse:0.14788
# [139]	validation_0-rmse:0.14786
# [140]	validation_0-rmse:0.14783
# [141]	validation_0-rmse:0.14779
# [142]	validation_0-rmse:0.14772
# [143]	validation_0-rmse:0.14766
# [144]	validation_0-rmse:0.14765
# [145]	validation_0-rmse:0.14759
# [146]	validation_0-rmse:0.14756
# [147]	validation_0-rmse:0.14750
# [148]	validation_0-rmse:0.14743
# [149]	validation_0-rmse:0.14742
# [150]	validation_0-rmse:0.14738
# [151]	validation_0-rmse:0.14733
# [152]	validation_0-rmse:0.14729
# [153]	validation_0-rmse:0.14728
# [154]	validation_0-rmse:0.14723
# [155]	validation_0-rmse:0.14718
# [156]	validation_0-rmse:0.14714
# [157]	validation_0-rmse:0.14710
# [158]	validation_0-rmse:0.14713
# [159]	validation_0-rmse:0.14705
# [160]	validation_0-rmse:0.14702
# [161]	validation_0-rmse:0.14699
# [162]	validation_0-rmse:0.14697
# [163]	validation_0-rmse:0.14694
# [164]	validation_0-rmse:0.14687
# [165]	validation_0-rmse:0.14684
# [166]	validation_0-rmse:0.14678
# [167]	validation_0-rmse:0.14675
# [168]	validation_0-rmse:0.14674
# [169]	validation_0-rmse:0.14673
# [170]	validation_0-rmse:0.14669
# [171]	validation_0-rmse:0.14667
# [172]	validation_0-rmse:0.14664
# [173]	validation_0-rmse:0.14659
# [174]	validation_0-rmse:0.14656
# [175]	validation_0-rmse:0.14650
# [176]	validation_0-rmse:0.14648
# [177]	validation_0-rmse:0.14642
# [178]	validation_0-rmse:0.14642
# [179]	validation_0-rmse:0.14640
# [180]	validation_0-rmse:0.14636
# [181]	validation_0-rmse:0.14631
# [182]	validation_0-rmse:0.14627
# [183]	validation_0-rmse:0.14624
# [184]	validation_0-rmse:0.14618
# [185]	validation_0-rmse:0.14617
# [186]	validation_0-rmse:0.14614
# [187]	validation_0-rmse:0.14612
# [188]	validation_0-rmse:0.14609
# [189]	validation_0-rmse:0.14605
# [190]	validation_0-rmse:0.14598
# [191]	validation_0-rmse:0.14596
# [192]	validation_0-rmse:0.14587
# [193]	validation_0-rmse:0.14580
# [194]	validation_0-rmse:0.14579
# [195]	validation_0-rmse:0.14576
# [196]	validation_0-rmse:0.14567
# [197]	validation_0-rmse:0.14562
# [198]	validation_0-rmse:0.14558
# [199]	validation_0-rmse:0.14555
# [200]	validation_0-rmse:0.14550
# [201]	validation_0-rmse:0.14545
# [202]	validation_0-rmse:0.14538
# [203]	validation_0-rmse:0.14538
# [204]	validation_0-rmse:0.14535
# [205]	validation_0-rmse:0.14533
# [206]	validation_0-rmse:0.14529
# [207]	validation_0-rmse:0.14526
# [208]	validation_0-rmse:0.14524
# [209]	validation_0-rmse:0.14523
# [210]	validation_0-rmse:0.14520
# [211]	validation_0-rmse:0.14521
# [212]	validation_0-rmse:0.14515
# [213]	validation_0-rmse:0.14508
# [214]	validation_0-rmse:0.14505
# [215]	validation_0-rmse:0.14502
# [216]	validation_0-rmse:0.14499
# [217]	validation_0-rmse:0.14497
# [218]	validation_0-rmse:0.14493
# [219]	validation_0-rmse:0.14490
# [220]	validation_0-rmse:0.14488
# [221]	validation_0-rmse:0.14487
# [222]	validation_0-rmse:0.14487
# [223]	validation_0-rmse:0.14481
# [224]	validation_0-rmse:0.14479
# [225]	validation_0-rmse:0.14477
# [226]	validation_0-rmse:0.14471
# [227]	validation_0-rmse:0.14467
# [228]	validation_0-rmse:0.14467
# [229]	validation_0-rmse:0.14465
# [230]	validation_0-rmse:0.14467
# [231]	validation_0-rmse:0.14467
# [232]	validation_0-rmse:0.14466
# [233]	validation_0-rmse:0.14457
# [234]	validation_0-rmse:0.14455
# [235]	validation_0-rmse:0.14451
# [236]	validation_0-rmse:0.14448
# [237]	validation_0-rmse:0.14442
# [238]	validation_0-rmse:0.14442
# [239]	validation_0-rmse:0.14438
# [240]	validation_0-rmse:0.14435
# [241]	validation_0-rmse:0.14434
# [242]	validation_0-rmse:0.14434
# [243]	validation_0-rmse:0.14434
# [244]	validation_0-rmse:0.14435
# [245]	validation_0-rmse:0.14432
# [246]	validation_0-rmse:0.14433
# [247]	validation_0-rmse:0.14432
# [248]	validation_0-rmse:0.14432
# [249]	validation_0-rmse:0.14432
# [250]	validation_0-rmse:0.14430
# [251]	validation_0-rmse:0.14427
# [252]	validation_0-rmse:0.14427
# [253]	validation_0-rmse:0.14424
# [254]	validation_0-rmse:0.14423
# [255]	validation_0-rmse:0.14422
# [256]	validation_0-rmse:0.14422
# [257]	validation_0-rmse:0.14417
# [258]	validation_0-rmse:0.14411
# [259]	validation_0-rmse:0.14410
# [260]	validation_0-rmse:0.14411
# [261]	validation_0-rmse:0.14407
# [262]	validation_0-rmse:0.14408
# [263]	validation_0-rmse:0.14406
# [264]	validation_0-rmse:0.14408
# [265]	validation_0-rmse:0.14409
# [266]	validation_0-rmse:0.14409
# [267]	validation_0-rmse:0.14409
# [268]	validation_0-rmse:0.14408
# [269]	validation_0-rmse:0.14406
# [270]	validation_0-rmse:0.14404
# [271]	validation_0-rmse:0.14403
# [272]	validation_0-rmse:0.14403
# [273]	validation_0-rmse:0.14402
# [274]	validation_0-rmse:0.14399
# [275]	validation_0-rmse:0.14398
# [276]	validation_0-rmse:0.14396
# [277]	validation_0-rmse:0.14392
# [278]	validation_0-rmse:0.14393
# [279]	validation_0-rmse:0.14390
# [280]	validation_0-rmse:0.14389
# [281]	validation_0-rmse:0.14388
# [282]	validation_0-rmse:0.14386
# [283]	validation_0-rmse:0.14382
# [284]	validation_0-rmse:0.14381
# [285]	validation_0-rmse:0.14382
# [286]	validation_0-rmse:0.14378
# [287]	validation_0-rmse:0.14377
# [288]	validation_0-rmse:0.14372
# [289]	validation_0-rmse:0.14373
# [290]	validation_0-rmse:0.14374
# [291]	validation_0-rmse:0.14373
# [292]	validation_0-rmse:0.14369
# [293]	validation_0-rmse:0.14367
# [294]	validation_0-rmse:0.14366
# [295]	validation_0-rmse:0.14366
# [296]	validation_0-rmse:0.14363
# [297]	validation_0-rmse:0.14362
# [298]	validation_0-rmse:0.14363
# [299]	validation_0-rmse:0.14361
# [300]	validation_0-rmse:0.14359
# [301]	validation_0-rmse:0.14360
# [302]	validation_0-rmse:0.14358
# [303]	validation_0-rmse:0.14357
# [304]	validation_0-rmse:0.14353
# [305]	validation_0-rmse:0.14356
# [306]	validation_0-rmse:0.14355
# [307]	validation_0-rmse:0.14354
# [308]	validation_0-rmse:0.14353
# [309]	validation_0-rmse:0.14347
# [310]	validation_0-rmse:0.14343
# [311]	validation_0-rmse:0.14339
# [312]	validation_0-rmse:0.14337
# [313]	validation_0-rmse:0.14337
# [314]	validation_0-rmse:0.14336
# [315]	validation_0-rmse:0.14332
# [316]	validation_0-rmse:0.14329
# [317]	validation_0-rmse:0.14329
# [318]	validation_0-rmse:0.14326
# [319]	validation_0-rmse:0.14324
# [320]	validation_0-rmse:0.14323
# [321]	validation_0-rmse:0.14322
# [322]	validation_0-rmse:0.14321
# [323]	validation_0-rmse:0.14321
# [324]	validation_0-rmse:0.14319
# [325]	validation_0-rmse:0.14317
# [326]	validation_0-rmse:0.14312
# [327]	validation_0-rmse:0.14313
# [328]	validation_0-rmse:0.14311
# [329]	validation_0-rmse:0.14309
# [330]	validation_0-rmse:0.14306
# [331]	validation_0-rmse:0.14305
# [332]	validation_0-rmse:0.14304
# [333]	validation_0-rmse:0.14303
# [334]	validation_0-rmse:0.14302
# [335]	validation_0-rmse:0.14300
# [336]	validation_0-rmse:0.14299
# [337]	validation_0-rmse:0.14300
# [338]	validation_0-rmse:0.14297
# [339]	validation_0-rmse:0.14298
# [340]	validation_0-rmse:0.14296
# [341]	validation_0-rmse:0.14295
# [342]	validation_0-rmse:0.14293
# [343]	validation_0-rmse:0.14294
# [344]	validation_0-rmse:0.14294
# [345]	validation_0-rmse:0.14291
# [346]	validation_0-rmse:0.14290
# [347]	validation_0-rmse:0.14288
# [348]	validation_0-rmse:0.14289
# [349]	validation_0-rmse:0.14289
# [350]	validation_0-rmse:0.14288
# [351]	validation_0-rmse:0.14289
# [352]	validation_0-rmse:0.14288
# [353]	validation_0-rmse:0.14285
# [354]	validation_0-rmse:0.14284
# [355]	validation_0-rmse:0.14281
# [356]	validation_0-rmse:0.14280
# [357]	validation_0-rmse:0.14279
# [358]	validation_0-rmse:0.14282
# [359]	validation_0-rmse:0.14281
# [360]	validation_0-rmse:0.14276
# [361]	validation_0-rmse:0.14275
# [362]	validation_0-rmse:0.14273
# [363]	validation_0-rmse:0.14273
# [364]	validation_0-rmse:0.14272
# [365]	validation_0-rmse:0.14269
# [366]	validation_0-rmse:0.14266
# [367]	validation_0-rmse:0.14265
# [368]	validation_0-rmse:0.14262
# [369]	validation_0-rmse:0.14259
# [370]	validation_0-rmse:0.14257
# [371]	validation_0-rmse:0.14258
# [372]	validation_0-rmse:0.14257
# [373]	validation_0-rmse:0.14256
# [374]	validation_0-rmse:0.14255
# [375]	validation_0-rmse:0.14255
# [376]	validation_0-rmse:0.14255
# [377]	validation_0-rmse:0.14252
# [378]	validation_0-rmse:0.14253
# [379]	validation_0-rmse:0.14253
# [380]	validation_0-rmse:0.14252
# [381]	validation_0-rmse:0.14252
# [382]	validation_0-rmse:0.14252
# [383]	validation_0-rmse:0.14249
# [384]	validation_0-rmse:0.14250
# [385]	validation_0-rmse:0.14250
# [386]	validation_0-rmse:0.14250
# [387]	validation_0-rmse:0.14248
# [388]	validation_0-rmse:0.14248
# [389]	validation_0-rmse:0.14247
# [390]	validation_0-rmse:0.14246
# [391]	validation_0-rmse:0.14247
# [392]	validation_0-rmse:0.14247
# [393]	validation_0-rmse:0.14248
# [394]	validation_0-rmse:0.14248
# [395]	validation_0-rmse:0.14247
# [396]	validation_0-rmse:0.14245
# [397]	validation_0-rmse:0.14244
# [398]	validation_0-rmse:0.14244
# [399]	validation_0-rmse:0.14245
# [400]	validation_0-rmse:0.14245
# [401]	validation_0-rmse:0.14241
# [402]	validation_0-rmse:0.14240
# [403]	validation_0-rmse:0.14239
# [404]	validation_0-rmse:0.14239
# [405]	validation_0-rmse:0.14238
# [406]	validation_0-rmse:0.14241
# [407]	validation_0-rmse:0.14243
# [408]	validation_0-rmse:0.14240
# [409]	validation_0-rmse:0.14239
# [410]	validation_0-rmse:0.14237
# [411]	validation_0-rmse:0.14236
# [412]	validation_0-rmse:0.14234
# [413]	validation_0-rmse:0.14235
# [414]	validation_0-rmse:0.14234
# [415]	validation_0-rmse:0.14232
# [416]	validation_0-rmse:0.14232
# [417]	validation_0-rmse:0.14231
# [418]	validation_0-rmse:0.14232
# [419]	validation_0-rmse:0.14231
# [420]	validation_0-rmse:0.14231
# [421]	validation_0-rmse:0.14229
# [422]	validation_0-rmse:0.14228
# [423]	validation_0-rmse:0.14228
# [424]	validation_0-rmse:0.14229
# [425]	validation_0-rmse:0.14228
# [426]	validation_0-rmse:0.14228
# [427]	validation_0-rmse:0.14224
# [428]	validation_0-rmse:0.14223
# [429]	validation_0-rmse:0.14219
# [430]	validation_0-rmse:0.14218
# [431]	validation_0-rmse:0.14217
# [432]	validation_0-rmse:0.14218
# [433]	validation_0-rmse:0.14215
# [434]	validation_0-rmse:0.14212
# [435]	validation_0-rmse:0.14210
# [436]	validation_0-rmse:0.14207
# [437]	validation_0-rmse:0.14204
# [438]	validation_0-rmse:0.14204
# [439]	validation_0-rmse:0.14203
# [440]	validation_0-rmse:0.14204
# [441]	validation_0-rmse:0.14201
# [442]	validation_0-rmse:0.14200
# [443]	validation_0-rmse:0.14200
# [444]	validation_0-rmse:0.14199
# [445]	validation_0-rmse:0.14199
# [446]	validation_0-rmse:0.14196
# [447]	validation_0-rmse:0.14197
# [448]	validation_0-rmse:0.14198
# [449]	validation_0-rmse:0.14199
# [450]	validation_0-rmse:0.14196
# [451]	validation_0-rmse:0.14194
# [452]	validation_0-rmse:0.14194
# [453]	validation_0-rmse:0.14194
# [454]	validation_0-rmse:0.14191
# [455]	validation_0-rmse:0.14190
# [456]	validation_0-rmse:0.14191
# [457]	validation_0-rmse:0.14189
# [458]	validation_0-rmse:0.14188
# [459]	validation_0-rmse:0.14186
# [460]	validation_0-rmse:0.14184
# [461]	validation_0-rmse:0.14184
# [462]	validation_0-rmse:0.14182
# [463]	validation_0-rmse:0.14182
# [464]	validation_0-rmse:0.14182
# [465]	validation_0-rmse:0.14182
# [466]	validation_0-rmse:0.14180
# [467]	validation_0-rmse:0.14183
# [468]	validation_0-rmse:0.14183
# [469]	validation_0-rmse:0.14183
# [470]	validation_0-rmse:0.14182
# [471]	validation_0-rmse:0.14184
# [472]	validation_0-rmse:0.14183
# [473]	validation_0-rmse:0.14187
# [474]	validation_0-rmse:0.14185
# [475]	validation_0-rmse:0.14185
# [476]	validation_0-rmse:0.14184
# [477]	validation_0-rmse:0.14185
# [478]	validation_0-rmse:0.14184
# [479]	validation_0-rmse:0.14183
# [480]	validation_0-rmse:0.14182
# [481]	validation_0-rmse:0.14183
# [482]	validation_0-rmse:0.14181
# [483]	validation_0-rmse:0.14180
# [484]	validation_0-rmse:0.14179
# [485]	validation_0-rmse:0.14174
# [486]	validation_0-rmse:0.14174
# [487]	validation_0-rmse:0.14175
# [488]	validation_0-rmse:0.14175
# [489]	validation_0-rmse:0.14174
# [490]	validation_0-rmse:0.14172
# [491]	validation_0-rmse:0.14172
# [492]	validation_0-rmse:0.14173
# [493]	validation_0-rmse:0.14174
# [494]	validation_0-rmse:0.14172
# [495]	validation_0-rmse:0.14172
# [496]	validation_0-rmse:0.14171
# [497]	validation_0-rmse:0.14172
# [498]	validation_0-rmse:0.14172
# [499]	validation_0-rmse:0.14173
# [500]	validation_0-rmse:0.14174
# [501]	validation_0-rmse:0.14173
# [502]	validation_0-rmse:0.14174
# [503]	validation_0-rmse:0.14174
# [504]	validation_0-rmse:0.14175
# [505]	validation_0-rmse:0.14174
# [506]	validation_0-rmse:0.14174
# [507]	validation_0-rmse:0.14174
# [508]	validation_0-rmse:0.14173
# [509]	validation_0-rmse:0.14171
# [510]	validation_0-rmse:0.14170
# [511]	validation_0-rmse:0.14169
# [512]	validation_0-rmse:0.14169
# [513]	validation_0-rmse:0.14170
# [514]	validation_0-rmse:0.14169
# [515]	validation_0-rmse:0.14169
# [516]	validation_0-rmse:0.14170
# [517]	validation_0-rmse:0.14172
# [518]	validation_0-rmse:0.14167
# [519]	validation_0-rmse:0.14166
# [520]	validation_0-rmse:0.14164
# [521]	validation_0-rmse:0.14161
# [522]	validation_0-rmse:0.14163
# [523]	validation_0-rmse:0.14163
# [524]	validation_0-rmse:0.14162
# [525]	validation_0-rmse:0.14162
# [526]	validation_0-rmse:0.14162
# [527]	validation_0-rmse:0.14162
# [528]	validation_0-rmse:0.14161
# [529]	validation_0-rmse:0.14159
# [530]	validation_0-rmse:0.14160
# [531]	validation_0-rmse:0.14159
# [532]	validation_0-rmse:0.14158
# [533]	validation_0-rmse:0.14157
# [534]	validation_0-rmse:0.14155
# [535]	validation_0-rmse:0.14155
# [536]	validation_0-rmse:0.14154
# [537]	validation_0-rmse:0.14158
# [538]	validation_0-rmse:0.14159
# [539]	validation_0-rmse:0.14156
# [540]	validation_0-rmse:0.14156
# [541]	validation_0-rmse:0.14152
# [542]	validation_0-rmse:0.14151
# [543]	validation_0-rmse:0.14153
# [544]	validation_0-rmse:0.14154
# [545]	validation_0-rmse:0.14155
# [546]	validation_0-rmse:0.14154
# [547]	validation_0-rmse:0.14155
# [548]	validation_0-rmse:0.14154
# [549]	validation_0-rmse:0.14154
# [550]	validation_0-rmse:0.14153
# [551]	validation_0-rmse:0.14152
# [552]	validation_0-rmse:0.14152
# [553]	validation_0-rmse:0.14151
# [554]	validation_0-rmse:0.14150
# [555]	validation_0-rmse:0.14149
# [556]	validation_0-rmse:0.14149
# [557]	validation_0-rmse:0.14149
# [558]	validation_0-rmse:0.14146
# [559]	validation_0-rmse:0.14146
# [560]	validation_0-rmse:0.14146
# [561]	validation_0-rmse:0.14146
# [562]	validation_0-rmse:0.14145
# [563]	validation_0-rmse:0.14144
# [564]	validation_0-rmse:0.14144
# [565]	validation_0-rmse:0.14144
# [566]	validation_0-rmse:0.14144
# [567]	validation_0-rmse:0.14142
# [568]	validation_0-rmse:0.14139
# [569]	validation_0-rmse:0.14139
# [570]	validation_0-rmse:0.14139
# [571]	validation_0-rmse:0.14140
# [572]	validation_0-rmse:0.14140
# [573]	validation_0-rmse:0.14137
# [574]	validation_0-rmse:0.14135
# [575]	validation_0-rmse:0.14134
# [576]	validation_0-rmse:0.14133
# [577]	validation_0-rmse:0.14132
# [578]	validation_0-rmse:0.14134
# [579]	validation_0-rmse:0.14133
# [580]	validation_0-rmse:0.14135
# [581]	validation_0-rmse:0.14136
# [582]	validation_0-rmse:0.14137
# [583]	validation_0-rmse:0.14137
# [584]	validation_0-rmse:0.14138
# [585]	validation_0-rmse:0.14137
# [586]	validation_0-rmse:0.14137
# [587]	validation_0-rmse:0.14138
# [588]	validation_0-rmse:0.14137
# [589]	validation_0-rmse:0.14138
# [590]	validation_0-rmse:0.14140
# [591]	validation_0-rmse:0.14138
# [592]	validation_0-rmse:0.14138
# [593]	validation_0-rmse:0.14138
# [594]	validation_0-rmse:0.14138
# [595]	validation_0-rmse:0.14138
# [596]	validation_0-rmse:0.14138
# [597]	validation_0-rmse:0.14139
# [598]	validation_0-rmse:0.14139
# [599]	validation_0-rmse:0.14139
# [600]	validation_0-rmse:0.14139
# [601]	validation_0-rmse:0.14137
# [602]	validation_0-rmse:0.14137
# [603]	validation_0-rmse:0.14136
# [604]	validation_0-rmse:0.14137
# [605]	validation_0-rmse:0.14136
# [606]	validation_0-rmse:0.14136
# [607]	validation_0-rmse:0.14136
# [608]	validation_0-rmse:0.14135
# [609]	validation_0-rmse:0.14133
# [610]	validation_0-rmse:0.14133
# [611]	validation_0-rmse:0.14133
# [612]	validation_0-rmse:0.14133
# [613]	validation_0-rmse:0.14133
# [614]	validation_0-rmse:0.14134
# [615]	validation_0-rmse:0.14133
# [616]	validation_0-rmse:0.14133
# [617]	validation_0-rmse:0.14134
# [618]	validation_0-rmse:0.14132
# [619]	validation_0-rmse:0.14129
# [620]	validation_0-rmse:0.14129
# [621]	validation_0-rmse:0.14129
# [622]	validation_0-rmse:0.14125
# [623]	validation_0-rmse:0.14125
# [624]	validation_0-rmse:0.14125
# [625]	validation_0-rmse:0.14123
# [626]	validation_0-rmse:0.14122
# [627]	validation_0-rmse:0.14121
# [628]	validation_0-rmse:0.14121
# [629]	validation_0-rmse:0.14121
# [630]	validation_0-rmse:0.14119
# [631]	validation_0-rmse:0.14118
# [632]	validation_0-rmse:0.14117
# [633]	validation_0-rmse:0.14116
# [634]	validation_0-rmse:0.14114
# [635]	validation_0-rmse:0.14111
# [636]	validation_0-rmse:0.14111
# [637]	validation_0-rmse:0.14111
# [638]	validation_0-rmse:0.14110
# [639]	validation_0-rmse:0.14111
# [640]	validation_0-rmse:0.14113
# [641]	validation_0-rmse:0.14112
# [642]	validation_0-rmse:0.14112
# [643]	validation_0-rmse:0.14112
# [644]	validation_0-rmse:0.14113
# [645]	validation_0-rmse:0.14114
# [646]	validation_0-rmse:0.14114
# [647]	validation_0-rmse:0.14113
# [648]	validation_0-rmse:0.14113
# [649]	validation_0-rmse:0.14115
# [650]	validation_0-rmse:0.14115
# [651]	validation_0-rmse:0.14115
# [652]	validation_0-rmse:0.14115
# [653]	validation_0-rmse:0.14115
# [654]	validation_0-rmse:0.14115
# [655]	validation_0-rmse:0.14115
# [656]	validation_0-rmse:0.14114
# [657]	validation_0-rmse:0.14113
# [658]	validation_0-rmse:0.14113
# [659]	validation_0-rmse:0.14114
# [660]	validation_0-rmse:0.14114
# [661]	validation_0-rmse:0.14113
# [662]	validation_0-rmse:0.14114
# [663]	validation_0-rmse:0.14115
# [664]	validation_0-rmse:0.14116
# [665]	validation_0-rmse:0.14116
# [666]	validation_0-rmse:0.14116
# [667]	validation_0-rmse:0.14117
# [668]	validation_0-rmse:0.14114
# [669]	validation_0-rmse:0.14113
# [670]	validation_0-rmse:0.14113
# [671]	validation_0-rmse:0.14114
# [672]	validation_0-rmse:0.14115
# [673]	validation_0-rmse:0.14114
# [674]	validation_0-rmse:0.14115
# [675]	validation_0-rmse:0.14115
# [676]	validation_0-rmse:0.14117
# [677]	validation_0-rmse:0.14115
# [678]	validation_0-rmse:0.14116
# [679]	validation_0-rmse:0.14117
# [680]	validation_0-rmse:0.14117
# [681]	validation_0-rmse:0.14117
# [682]	validation_0-rmse:0.14116
# [683]	validation_0-rmse:0.14115
# [684]	validation_0-rmse:0.14113
# [685]	validation_0-rmse:0.14115
# [686]	validation_0-rmse:0.14114
# [687]	validation_0-rmse:0.14116
# [688]	validation_0-rmse:0.14116
# [689]	validation_0-rmse:0.14116
# [690]	validation_0-rmse:0.14116
# [691]	validation_0-rmse:0.14115
# [692]	validation_0-rmse:0.14116
# [693]	validation_0-rmse:0.14115
# [694]	validation_0-rmse:0.14114
# [695]	validation_0-rmse:0.14114
# [696]	validation_0-rmse:0.14115
# [697]	validation_0-rmse:0.14115
# [698]	validation_0-rmse:0.14116
# [699]	validation_0-rmse:0.14118
# [700]	validation_0-rmse:0.14118
# [701]	validation_0-rmse:0.14117
# [702]	validation_0-rmse:0.14117
# [703]	validation_0-rmse:0.14117
# [704]	validation_0-rmse:0.14115
# [705]	validation_0-rmse:0.14116
# [706]	validation_0-rmse:0.14117
# [707]	validation_0-rmse:0.14118
# [708]	validation_0-rmse:0.14118
# [709]	validation_0-rmse:0.14119
# [710]	validation_0-rmse:0.14120
# [711]	validation_0-rmse:0.14120
# [712]	validation_0-rmse:0.14118
# [713]	validation_0-rmse:0.14118
# [714]	validation_0-rmse:0.14118
# [715]	validation_0-rmse:0.14118
# [716]	validation_0-rmse:0.14118
# [717]	validation_0-rmse:0.14118
# [718]	validation_0-rmse:0.14118
# [719]	validation_0-rmse:0.14116
# [720]	validation_0-rmse:0.14117
# [721]	validation_0-rmse:0.14117
# [722]	validation_0-rmse:0.14116
# [723]	validation_0-rmse:0.14113
# [724]	validation_0-rmse:0.14115
# [725]	validation_0-rmse:0.14114
# [726]	validation_0-rmse:0.14113
# [727]	validation_0-rmse:0.14113
# [728]	validation_0-rmse:0.14115
# [729]	validation_0-rmse:0.14114
# [730]	validation_0-rmse:0.14114
# [731]	validation_0-rmse:0.14114
# [732]	validation_0-rmse:0.14115
# [733]	validation_0-rmse:0.14114
# [734]	validation_0-rmse:0.14114
# [735]	validation_0-rmse:0.14112
# [736]	validation_0-rmse:0.14113
# [737]	validation_0-rmse:0.14113
# [738]	validation_0-rmse:0.14113
# [739]	validation_0-rmse:0.14114
# [740]	validation_0-rmse:0.14113
# [741]	validation_0-rmse:0.14112
# [742]	validation_0-rmse:0.14112
# [743]	validation_0-rmse:0.14112
# [744]	validation_0-rmse:0.14113
# [745]	validation_0-rmse:0.14112
# [746]	validation_0-rmse:0.14111
# [747]	validation_0-rmse:0.14110
# [748]	validation_0-rmse:0.14109
# [749]	validation_0-rmse:0.14110
# [750]	validation_0-rmse:0.14110
# [751]	validation_0-rmse:0.14111
# [752]	validation_0-rmse:0.14111
# [753]	validation_0-rmse:0.14113
# [754]	validation_0-rmse:0.14112
# [755]	validation_0-rmse:0.14112
# [756]	validation_0-rmse:0.14111
# [757]	validation_0-rmse:0.14111
# [758]	validation_0-rmse:0.14112
# [759]	validation_0-rmse:0.14111
# [760]	validation_0-rmse:0.14112
# [761]	validation_0-rmse:0.14112
# [762]	validation_0-rmse:0.14112
# [763]	validation_0-rmse:0.14112
# [764]	validation_0-rmse:0.14112
# [765]	validation_0-rmse:0.14112
# [766]	validation_0-rmse:0.14112
# [767]	validation_0-rmse:0.14112
# [768]	validation_0-rmse:0.14109
# [769]	validation_0-rmse:0.14110
# [770]	validation_0-rmse:0.14111
# [771]	validation_0-rmse:0.14108
# [772]	validation_0-rmse:0.14107
# [773]	validation_0-rmse:0.14108
# [774]	validation_0-rmse:0.14107
# [775]	validation_0-rmse:0.14107
# [776]	validation_0-rmse:0.14107
# [777]	validation_0-rmse:0.14106
# [778]	validation_0-rmse:0.14107
# [779]	validation_0-rmse:0.14108
# [780]	validation_0-rmse:0.14108
# [781]	validation_0-rmse:0.14108
# [782]	validation_0-rmse:0.14107
# [783]	validation_0-rmse:0.14108
# [784]	validation_0-rmse:0.14108
# [785]	validation_0-rmse:0.14107
# [786]	validation_0-rmse:0.14107
# [787]	validation_0-rmse:0.14108
# [788]	validation_0-rmse:0.14107
# [789]	validation_0-rmse:0.14108
# [790]	validation_0-rmse:0.14108
# [791]	validation_0-rmse:0.14109
# [792]	validation_0-rmse:0.14108
# [793]	validation_0-rmse:0.14107
# [794]	validation_0-rmse:0.14105
# [795]	validation_0-rmse:0.14105
# [796]	validation_0-rmse:0.14105
# [797]	validation_0-rmse:0.14106
# [798]	validation_0-rmse:0.14105
# [799]	validation_0-rmse:0.14105
# [800]	validation_0-rmse:0.14104
# [801]	validation_0-rmse:0.14105
# [802]	validation_0-rmse:0.14108
# [803]	validation_0-rmse:0.14107
# [804]	validation_0-rmse:0.14109
# [805]	validation_0-rmse:0.14109
# [806]	validation_0-rmse:0.14108
# [807]	validation_0-rmse:0.14109
# [808]	validation_0-rmse:0.14109
# [809]	validation_0-rmse:0.14110
# [810]	validation_0-rmse:0.14108
# [811]	validation_0-rmse:0.14109
# [812]	validation_0-rmse:0.14110
# [813]	validation_0-rmse:0.14109
# [814]	validation_0-rmse:0.14108
# [815]	validation_0-rmse:0.14108
# [816]	validation_0-rmse:0.14108
# [817]	validation_0-rmse:0.14106
# [818]	validation_0-rmse:0.14106
# [819]	validation_0-rmse:0.14106
# [820]	validation_0-rmse:0.14106
# [821]	validation_0-rmse:0.14107
# [822]	validation_0-rmse:0.14107
# [823]	validation_0-rmse:0.14108
# [824]	validation_0-rmse:0.14108
# [825]	validation_0-rmse:0.14107
# [826]	validation_0-rmse:0.14108
# [827]	validation_0-rmse:0.14109
# [828]	validation_0-rmse:0.14109
# [829]	validation_0-rmse:0.14110
# [830]	validation_0-rmse:0.14109
# [831]	validation_0-rmse:0.14110
# [832]	validation_0-rmse:0.14110
# [833]	validation_0-rmse:0.14111
# [834]	validation_0-rmse:0.14110
# [835]	validation_0-rmse:0.14110
# [836]	validation_0-rmse:0.14110
# [837]	validation_0-rmse:0.14109
# [838]	validation_0-rmse:0.14111
# [839]	validation_0-rmse:0.14111
# [840]	validation_0-rmse:0.14111
# [841]	validation_0-rmse:0.14113
# [842]	validation_0-rmse:0.14113
# [843]	validation_0-rmse:0.14114
# [844]	validation_0-rmse:0.14113
# [845]	validation_0-rmse:0.14113
# [846]	validation_0-rmse:0.14112
# [847]	validation_0-rmse:0.14112
# [848]	validation_0-rmse:0.14112
# [849]	validation_0-rmse:0.14113
# [850]	validation_0-rmse:0.14112
# [851]	validation_0-rmse:0.14113
# [852]	validation_0-rmse:0.14113
# [853]	validation_0-rmse:0.14113
# [854]	validation_0-rmse:0.14113
# [855]	validation_0-rmse:0.14114
# [856]	validation_0-rmse:0.14113
# [857]	validation_0-rmse:0.14111
# [858]	validation_0-rmse:0.14113
# [859]	validation_0-rmse:0.14112
# [860]	validation_0-rmse:0.14111
# [861]	validation_0-rmse:0.14110
# [862]	validation_0-rmse:0.14109
# [863]	validation_0-rmse:0.14108
# [864]	validation_0-rmse:0.14108
# [865]	validation_0-rmse:0.14109
# [866]	validation_0-rmse:0.14110
# [867]	validation_0-rmse:0.14110
# [868]	validation_0-rmse:0.14110
# [869]	validation_0-rmse:0.14111
# [870]	validation_0-rmse:0.14110
# [871]	validation_0-rmse:0.14110
# [872]	validation_0-rmse:0.14109
# [873]	validation_0-rmse:0.14109
# [874]	validation_0-rmse:0.14109
# [875]	validation_0-rmse:0.14109
# [876]	validation_0-rmse:0.14110
# [877]	validation_0-rmse:0.14109
# [878]	validation_0-rmse:0.14108
# [879]	validation_0-rmse:0.14109
# [880]	validation_0-rmse:0.14107
# [881]	validation_0-rmse:0.14107
# [882]	validation_0-rmse:0.14107
# [883]	validation_0-rmse:0.14107
# [884]	validation_0-rmse:0.14106
# [885]	validation_0-rmse:0.14106
# [886]	validation_0-rmse:0.14107
# [887]	validation_0-rmse:0.14108
# [888]	validation_0-rmse:0.14108
# [889]	validation_0-rmse:0.14108
# [890]	validation_0-rmse:0.14107
# [891]	validation_0-rmse:0.14107
# [892]	validation_0-rmse:0.14108
# [893]	validation_0-rmse:0.14108
# [894]	validation_0-rmse:0.14106
# [895]	validation_0-rmse:0.14106
# [896]	validation_0-rmse:0.14108
# [897]	validation_0-rmse:0.14108
# [898]	validation_0-rmse:0.14107
# [899]	validation_0-rmse:0.14107
# [900]	validation_0-rmse:0.14107
# [901]	validation_0-rmse:0.14107
# [902]	validation_0-rmse:0.14107
# [903]	validation_0-rmse:0.14106
# [904]	validation_0-rmse:0.14105
# [905]	validation_0-rmse:0.14106
# [906]	validation_0-rmse:0.14106
# [907]	validation_0-rmse:0.14107
# [908]	validation_0-rmse:0.14107
# [909]	validation_0-rmse:0.14108
# [910]	validation_0-rmse:0.14107
# [911]	validation_0-rmse:0.14107
# [912]	validation_0-rmse:0.14107
# [913]	validation_0-rmse:0.14108
# [914]	validation_0-rmse:0.14108
# [915]	validation_0-rmse:0.14108
# [916]	validation_0-rmse:0.14109
# [917]	validation_0-rmse:0.14109
# [918]	validation_0-rmse:0.14109
# [919]	validation_0-rmse:0.14110
# [920]	validation_0-rmse:0.14109
# [921]	validation_0-rmse:0.14110
# [922]	validation_0-rmse:0.14110
# [923]	validation_0-rmse:0.14110
# [924]	validation_0-rmse:0.14111
# [925]	validation_0-rmse:0.14110
# [926]	validation_0-rmse:0.14109
# [927]	validation_0-rmse:0.14110
# [928]	validation_0-rmse:0.14109
# [929]	validation_0-rmse:0.14110
# [930]	validation_0-rmse:0.14111
# [931]	validation_0-rmse:0.14110
# [932]	validation_0-rmse:0.14110
# [933]	validation_0-rmse:0.14110
# [934]	validation_0-rmse:0.14110
# [935]	validation_0-rmse:0.14110
# [936]	validation_0-rmse:0.14111
# [937]	validation_0-rmse:0.14110
# [938]	validation_0-rmse:0.14111
# [939]	validation_0-rmse:0.14112
# [940]	validation_0-rmse:0.14111
# [941]	validation_0-rmse:0.14111
# [942]	validation_0-rmse:0.14110
# [943]	validation_0-rmse:0.14110
# [944]	validation_0-rmse:0.14110
# [945]	validation_0-rmse:0.14111
# [946]	validation_0-rmse:0.14111
# [947]	validation_0-rmse:0.14111
# [948]	validation_0-rmse:0.14111
# [949]	validation_0-rmse:0.14111
# [950]	validation_0-rmse:0.14112
# [951]	validation_0-rmse:0.14111
# [952]	validation_0-rmse:0.14112
# [953]	validation_0-rmse:0.14113
# [954]	validation_0-rmse:0.14113
# [955]	validation_0-rmse:0.14113
# [956]	validation_0-rmse:0.14114
# [957]	validation_0-rmse:0.14112
# [958]	validation_0-rmse:0.14112
# [959]	validation_0-rmse:0.14112
# [960]	validation_0-rmse:0.14112
# [961]	validation_0-rmse:0.14113
# [962]	validation_0-rmse:0.14113
# [963]	validation_0-rmse:0.14112
# [964]	validation_0-rmse:0.14113
# [965]	validation_0-rmse:0.14113
# [966]	validation_0-rmse:0.14112
# [967]	validation_0-rmse:0.14111
# [968]	validation_0-rmse:0.14111
# [969]	validation_0-rmse:0.14111
# [970]	validation_0-rmse:0.14112
# [971]	validation_0-rmse:0.14112
# [972]	validation_0-rmse:0.14113
# [973]	validation_0-rmse:0.14114
# [974]	validation_0-rmse:0.14113
# [975]	validation_0-rmse:0.14112
# [976]	validation_0-rmse:0.14111
# [977]	validation_0-rmse:0.14110
# [978]	validation_0-rmse:0.14110
# [979]	validation_0-rmse:0.14110
# [980]	validation_0-rmse:0.14109
# [981]	validation_0-rmse:0.14110
# [982]	validation_0-rmse:0.14109
# [983]	validation_0-rmse:0.14109
# [984]	validation_0-rmse:0.14109
# [985]	validation_0-rmse:0.14110
# [986]	validation_0-rmse:0.14110
# [987]	validation_0-rmse:0.14109
# [988]	validation_0-rmse:0.14109
# [989]	validation_0-rmse:0.14109
# [990]	validation_0-rmse:0.14109
# [991]	validation_0-rmse:0.14109
# [992]	validation_0-rmse:0.14110
# [993]	validation_0-rmse:0.14111
# [994]	validation_0-rmse:0.14110
# [995]	validation_0-rmse:0.14111
# [996]	validation_0-rmse:0.14111
# [997]	validation_0-rmse:0.14112
# [998]	validation_0-rmse:0.14112
# [999]	validation_0-rmse:0.14111
# Best iteration source: derived_from_evals_result; value: 800
# Planned n_estimators: 1000 | Used (best): 801
# Key booster parameters: {'objective': 'reg:squarederror', 'learning_rate': 0.05, 'max_depth': 6, 'min_child_weight': None, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': None, 'reg_lambda': 1.0}
# Validation metric rmse on validation_0: best=0.141036 at iteration=800

# %%
# Evaluate performance
def regression_metrics(y_true, y_pred):
    # Handle sklearn versions without the 'squared' kwarg
    mse_sig = inspect.signature(mean_squared_error)
    if 'squared' in mse_sig.parameters:
        rmse = mean_squared_error(y_true, y_pred, squared=False)
    else:
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return {'RMSE': rmse, 'MAE': mae, 'R2': r2}

# Raw predictions from the model (in log scale if USE_LOG_TARGET)
y_train_pred = xgb.predict(X_train_t)
y_val_pred = xgb.predict(X_val_t)
y_test_pred = xgb.predict(X_test_t)

# Convert predictions back to original scale when needed
if 'USE_LOG_TARGET' in globals() and USE_LOG_TARGET:
    y_train_eval = np.expm1(y_train_pred)
    y_val_eval = np.expm1(y_val_pred)
    y_test_eval = np.expm1(y_test_pred)
    yt_train = y_train_raw
    yt_val = y_val_raw
    yt_test = y_test_raw
else:
    y_train_eval, y_val_eval, y_test_eval = y_train_pred, y_val_pred, y_test_pred
    yt_train, yt_val, yt_test = y_train, y_val, y_test

print('Train metrics:', regression_metrics(yt_train, y_train_eval))
print('Val metrics:  ', regression_metrics(yt_val, y_val_eval))
print('Test metrics: ', regression_metrics(yt_test, y_test_eval))

plt.figure(figsize=(6, 6))
sns.scatterplot(x=yt_test, y=y_test_eval, s=12, alpha=0.5)
lims = [min(yt_test.min(), y_test_eval.min()), max(yt_test.max(), y_test_eval.max())]
plt.plot(lims, lims, 'r--', linewidth=1)
plt.xlabel('Actual rental_price')
plt.ylabel('Predicted rental_price')
plt.title('Predicted vs Actual (Test)')
plt.show()
# Out:
# Train metrics: {'RMSE': np.float64(32.90687437415134), 'MAE': 21.987172444661457, 'R2': 0.9745937578795925}
# Val metrics:   {'RMSE': np.float64(98.88660458731017), 'MAE': 62.23974892619447, 'R2': 0.7605035005873273}
# Test metrics:  {'RMSE': np.float64(104.6367378405216), 'MAE': 65.35459771551335, 'R2': 0.746692713212417}

# %%
# Optional: cross-validation on the full dataset (may be slow on large files)
DO_CV = False
if DO_CV:
    model = Pipeline(steps=[('preprocessor', preprocessor), ('model', xgb)])
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    cv_scores = cross_val_score(model, X, y_raw, cv=kf, scoring='neg_root_mean_squared_error', n_jobs=-1)
    print('CV RMSE: ', (-cv_scores).mean(), '+/-', (-cv_scores).std())

# %%
# Feature importances
importances = xgb.feature_importances_
try:
    feature_names = preprocessor.get_feature_names_out()
except Exception:
    # Fallback: generic names if transformers don't expose names
    feature_names = np.asarray([f'feature_{i}' for i in range(importances.shape[0])], dtype=object)
feat_imp = pd.DataFrame({'feature': feature_names, 'importance': importances}).sort_values('importance', ascending=False)
feat_imp.head(20)

top_n = 20
plt.figure(figsize=(8, max(4, top_n * 0.4)))
sns.barplot(data=feat_imp.head(top_n), x='importance', y='feature', orient='h')
plt.title(f'Top {top_n} Feature Importances (XGBoost)')
plt.tight_layout()
plt.show()

# %%
# Optional: save fitted pipeline (preprocessing + model)
from joblib import dump
save_dir = Path('../models')
save_dir.mkdir(parents=True, exist_ok=True)
fitted_pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', xgb)])
model_path = save_dir / 'xgb_rental_price_pipeline.joblib'
dump(fitted_pipeline, model_path)
print(f'Saved pipeline to {model_path}')
# Out:
# Saved pipeline to models/xgb_rental_price_pipeline.joblib

# %% [markdown]
# # Hyperparameter Tuning

# %%
# Hyperparameter tuning (RandomizedSearchCV)
from sklearn.model_selection import RandomizedSearchCV, KFold
from sklearn.metrics import make_scorer, mean_squared_error, mean_absolute_error, r2_score
from scipy.stats import loguniform, uniform, randint

DO_TUNING = True
TUNE_SAMPLE_FRAC = 1.0
N_ITER = 200
CV_FOLDS = 5
RANDOM_STATE = 42

def rmse_on_original(y_true_in, y_pred_in):
    if 'USE_LOG_TARGET' in globals() and USE_LOG_TARGET:
        yt, yp = np.expm1(y_true_in), np.expm1(y_pred_in)
    else:
        yt, yp = y_true_in, y_pred_in
    return np.sqrt(mean_squared_error(yt, yp))

rmse_orig = make_scorer(rmse_on_original, greater_is_better=False)

if DO_TUNING:
    pipe = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('model', XGBRegressor(
            objective='reg:squarederror',
            tree_method='hist',
            random_state=RANDOM_STATE,
            n_jobs=-1,
            eval_metric='rmse',
        )),
    ])

    param_distributions = {
        'model__n_estimators': randint(400, 2001),
        'model__learning_rate': loguniform(1e-3, 1e-1),
        'model__max_depth': randint(3, 10),
        'model__min_child_weight': randint(1, 16),
        'model__subsample': uniform(0.5, 0.5),
        'model__colsample_bytree': uniform(0.5, 0.5),
        'model__colsample_bylevel': uniform(0.5, 0.5),
        'model__colsample_bynode': uniform(0.5, 0.5),
        'model__reg_alpha': loguniform(1e-4, 1e1),
        'model__reg_lambda': loguniform(1e-2, 1e1),
        'model__gamma': loguniform(1e-3, 1e1),
        'model__max_bin': randint(64, 257),
        'model__grow_policy': ['depthwise', 'lossguide'],
        'model__max_leaves': randint(2, 129),
    }

    # Drop unsupported XGB params based on installed version
    try:
        _xgb_params_supported = set(XGBRegressor().get_params().keys())
        _pd_filtered, _dropped = {}, []
        for _k, _v in param_distributions.items():
            _p = _k.split('__', 1)[1]
            if _p in _xgb_params_supported:
                _pd_filtered[_k] = _v
            else:
                _dropped.append(_k)
        if _dropped:
            print('Dropping unsupported params:', _dropped)
        param_distributions = _pd_filtered
    except Exception as _e:
        print('Param filtering skipped due to:', _e)

    cv = KFold(n_splits=CV_FOLDS, shuffle=True, random_state=RANDOM_STATE)

    X_tune, y_tune = X_train, y_train
    if TUNE_SAMPLE_FRAC and TUNE_SAMPLE_FRAC < 1.0:
        sample_idx = X_train.sample(frac=TUNE_SAMPLE_FRAC, random_state=RANDOM_STATE).index
        X_tune = X_train.loc[sample_idx]
        y_tune = y_train.loc[sample_idx] if hasattr(y_train, 'loc') else y_train[sample_idx]
        print(f'Sampled {len(X_tune)}/{len(X_train)} rows for tuning')

    scoring = {'rmse': rmse_orig, 'mae': 'neg_mean_absolute_error', 'r2': 'r2'}
    search = RandomizedSearchCV(
        estimator=pipe,
        param_distributions=param_distributions,
        n_iter=N_ITER,
        scoring=scoring,
        refit='rmse',
        cv=cv,
        n_jobs=-1,
        verbose=1,
        random_state=RANDOM_STATE,
        return_train_score=True,
    )

    search.fit(X_tune, y_tune)
    best_rmse = -float(search.best_score_)
    print('Best CV RMSE (orig scale):', best_rmse)
    print('Best params:')
    for k,v in sorted(search.best_params_.items()):
        print(' ', k, '=', v)

    best_model_cv = search.best_estimator_

    def to_orig(y):
        return np.expm1(y) if ('USE_LOG_TARGET' in globals() and USE_LOG_TARGET) else y

    def report_metrics(y_true, y_pred):
        yt, yp = to_orig(y_true), to_orig(y_pred)
        rmse = np.sqrt(mean_squared_error(yt, yp))
        mae = mean_absolute_error(yt, yp)
        r2 = r2_score(yt, yp)
        return {'RMSE': rmse, 'MAE': mae, 'R2': r2}

    y_val_pred_cv = best_model_cv.predict(X_val)
    y_test_pred_cv = best_model_cv.predict(X_test)
    print('Val metrics (CV-best pipeline, orig scale):', report_metrics(y_val, y_val_pred_cv))
    print('Test metrics (CV-best pipeline, orig scale):', report_metrics(y_test, y_test_pred_cv))

    tuned = {k.split('__',1)[1]: v for k,v in search.best_params_.items() if k.startswith('model__')}
    xgb_tuned = XGBRegressor(
        **tuned,
        objective='reg:squarederror',
        tree_method='hist',
        random_state=RANDOM_STATE,
        n_jobs=-1,
        eval_metric='rmse',
    )
    fit_sig = inspect.signature(XGBRegressor().fit)
    supports_callbacks = 'callbacks' in fit_sig.parameters
    supports_esr = 'early_stopping_rounds' in fit_sig.parameters
    fit_kwargs = {'eval_set': [(X_val_t, y_val)]}
    if supports_callbacks and 'XGB_EarlyStopping' in globals() and XGB_EarlyStopping is not None:
        fit_kwargs['callbacks'] = [XGB_EarlyStopping(rounds=100, save_best=True, maximize=False)]
    elif supports_esr:
        fit_kwargs['early_stopping_rounds'] = 100
    xgb_tuned.fit(X_train_t, y_train, **fit_kwargs)

    xgb = xgb_tuned
    print('Refit tuned model; best_iteration (if any):', getattr(xgb, 'best_iteration', None))
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits

# %%
# Evaluate performance
# Raw predictions from the model (in log scale if USE_LOG_TARGET)
y_train_pred = xgb.predict(X_train_t)
y_val_pred = xgb.predict(X_val_t)
y_test_pred = xgb.predict(X_test_t)

# Convert predictions back to original scale when needed
if 'USE_LOG_TARGET' in globals() and USE_LOG_TARGET:
    y_train_eval = np.expm1(y_train_pred)
    y_val_eval = np.expm1(y_val_pred)
    y_test_eval = np.expm1(y_test_pred)
    yt_train = y_train_raw
    yt_val = y_val_raw
    yt_test = y_test_raw
else:
    y_train_eval, y_val_eval, y_test_eval = y_train_pred, y_val_pred, y_test_pred
    yt_train, yt_val, yt_test = y_train, y_val, y_test

print('Train metrics:', regression_metrics(yt_train, y_train_eval))
print('Val metrics:  ', regression_metrics(yt_val, y_val_eval))
print('Test metrics: ', regression_metrics(yt_test, y_test_eval))

plt.figure(figsize=(6, 6))
sns.scatterplot(x=yt_test, y=y_test_eval, s=12, alpha=0.5)
lims = [min(yt_test.min(), y_test_eval.min()), max(yt_test.max(), y_test_eval.max())]
plt.plot(lims, lims, 'r--', linewidth=1)
plt.xlabel('Actual rental_price')
plt.ylabel('Predicted rental_price')
plt.title('Tuned Predicted vs Actual (Test)')
plt.show()
# Out:
# Train metrics: {'RMSE': np.float64(43.28188457408893), 'MAE': 27.401659301700555, 'R2': 0.9575907503953246}
# Val metrics:   {'RMSE': np.float64(103.03296287800617), 'MAE': 64.65455261001443, 'R2': 0.7607395044197085}
# Test metrics:  {'RMSE': np.float64(107.77684011222122), 'MAE': 64.94856763498237, 'R2': 0.7474109627565934}

# %%
if DO_CV:
    model = Pipeline(steps=[('preprocessor', preprocessor), ('model', xgb)])
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    cv_scores = cross_val_score(model, X, y_raw, cv=kf, scoring='neg_root_mean_squared_error', n_jobs=-1)
    print('CV RMSE: ', (-cv_scores).mean(), '+/-', (-cv_scores).std())

# %%
# Feature importances
importances = xgb.feature_importances_
try:
    feature_names = preprocessor.get_feature_names_out()
except Exception:
    # Fallback: generic names if transformers don't expose names
    feature_names = np.asarray([f'feature_{i}' for i in range(importances.shape[0])], dtype=object)
feat_imp = pd.DataFrame({'feature': feature_names, 'importance': importances}).sort_values('importance', ascending=False)
feat_imp.head(10)

top_n = 10
plt.figure(figsize=(8, max(4, top_n * 0.4)))
sns.barplot(data=feat_imp.head(top_n), x='importance', y='feature', orient='h')
plt.title(f'Top {top_n} Feature Importances (XGBoost)')
plt.tight_layout()
plt.show()

# %%
# Optional: save top features to csv
top_features_path = save_dir / 'xgb_rental_price_top_features.csv'
feat_imp.head(10).to_csv(top_features_path, index=False)
print(f'Saved feature importances to {top_features_path}')
# Out:
# Saved feature importances to models/xgb_rental_price_top_features.csv

# %% [markdown]
# ## Diagnostics for Overfitting

# %%
# Residual diagnostics by data split
residuals = pd.DataFrame({
    'split': (['Train'] * len(yt_train)) + (['Validation'] * len(yt_val)) + (['Test'] * len(yt_test)),
    'actual': np.concatenate([np.asarray(yt_train), np.asarray(yt_val), np.asarray(yt_test)]),
    'predicted': np.concatenate([np.asarray(y_train_eval), np.asarray(y_val_eval), np.asarray(y_test_eval)]),
})
residuals['residual'] = residuals['actual'] - residuals['predicted']

summary = residuals.groupby('split')['residual'].agg(
    mean='mean',
    std='std',
    median='median',
    mean_abs=lambda s: s.abs().mean(),
)
print('Residual summary (original scale):')
print(summary.round(4))

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.scatterplot(data=residuals, x='predicted', y='residual', hue='split', alpha=0.5, s=15, ax=axes[0])
axes[0].axhline(0, color='k', linestyle='--', linewidth=1)
axes[0].set_title('Residuals vs Predicted')
axes[0].set_xlabel('Predicted rental_price')
axes[0].set_ylabel('Residual (actual - predicted)')

sns.histplot(
    data=residuals,
    x='residual',
    hue='split',
    element='step',
    stat='density',
    common_norm=False,
    ax=axes[1],
    alpha=0.5,
)
axes[1].axvline(0, color='k', linestyle='--', linewidth=1)
axes[1].set_title('Residual Distribution')
axes[1].set_xlabel('Residual (actual - predicted)')

plt.tight_layout()
# Out:
# Residual summary (original scale):
#                mean       std  median  mean_abs
# split
# Test        12.0622  107.1091 -1.0917   64.9486
# Train        3.7759   43.1202 -1.2344   27.4017
# Validation   8.8030  102.6803 -2.4840   64.6546
