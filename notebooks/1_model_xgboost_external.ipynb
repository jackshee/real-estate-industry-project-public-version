# %% [markdown]
# # XGBoost Model for Rental Price
#
# This notebook trains an XGBoost regressor to predict `rental_price` using the dataset:
# `data/curated/rent_features/cleaned_listings_parquet`.
#
# It loads and preprocesses the data, splits into train/validation/test, fits the model,
# evaluates metrics, and inspects feature importances.

# %%
# Imports
import os, sys, inspect
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, TargetEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.base import BaseEstimator, TransformerMixin

# XGBoost
try:
    from xgboost import XGBRegressor
    try:
        # Preferred in newer XGBoost versions (>=2.x/3.x)
        from xgboost.callback import EarlyStopping as XGB_EarlyStopping
    except Exception:
        XGB_EarlyStopping = None
except Exception as e:
    print("xgboost is not installed. Install with: pip install xgboost")
    raise

np.random.seed(42)
sns.set_theme(style="whitegrid")

# %%
# Locate and load the dataset using Spark (supports running from repo root or notebooks/)
from pyspark.sql import SparkSession
from pathlib import Path
import pandas as pd

# Create a spark session
spark = (
    SparkSession.builder.appName("MAST30034 Model Training")
    .config("spark.sql.repl.eagerEval.enabled", True) 
    .config("spark.sql.parquet.cacheMetadata", "true")
    .config("spark.sql.session.timeZone", "Etc/UTC")
    .config("spark.driver.memory", "6g")
    .getOrCreate()
)

# Define possible paths for the parquet directory
PARQUET_PATHS = [
    Path('../data/curated/rent_features/cleaned_listings_parquet'),
]

parquet_path = None
for p in PARQUET_PATHS:
    if p.exists():
        parquet_path = p
        break

if parquet_path is None:
    raise FileNotFoundError(
        "Could not find Parquet directory at expected paths: " + ", ".join(map(str, PARQUET_PATHS))
    )

# Optional sampling to speed up experimentation on large files
USE_SAMPLE = False   # set True to sample a subset for quick runs
SAMPLE_FRAC = 0.2
SAMPLE_RANDOM_STATE = 42

# Load parquet files using Spark
spark_df = spark.read.parquet(str(parquet_path))

# Convert to pandas DataFrame
df = spark_df.toPandas()

# Apply sampling if requested
if USE_SAMPLE:
    df = df.sample(frac=SAMPLE_FRAC, random_state=SAMPLE_RANDOM_STATE).reset_index(drop=True)

print(f"Loaded parquet files from {parquet_path} with shape: {df.shape}")
print(f"Spark DataFrame partitions: {spark_df.rdd.getNumPartitions()}")

# Stop the Spark session
spark.stop()

df.head(3)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/10/22 14:26:44 WARN Utils: Your hostname, Pikachu.local, resolves to a loopback address: 127.0.0.1; using 192.168.1.46 instead (on interface en0)
# 25/10/22 14:26:44 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/22 14:26:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/10/22 14:27:02 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Loaded parquet files from ../data/curated/rent_features/cleaned_listings_parquet with shape: (24027, 133)
# Spark DataFrame partitions: 13
#    bedrooms  property_id  year   source  quarter  bathrooms  rental_price  \
# 0         2     16637685  2023  wayback        3          2         850.0
# 1         2     16410483  2023     live        2          1         620.0
# 2         2     16143495  2023     live        2          1         650.0
#
#       suburb   longitude  car_spaces  ...  \
# 0  melbourne  144.969114           1  ...
# 1    bendigo  144.294778           1  ...
# 2   box hill  145.118664           1  ...
#
#                       geom_driving_15min_imputed_wkt  \
# 0  POLYGON ((144.884321 -37.823826, 144.884545 -3...
# 1  POLYGON ((144.218716 -36.707302, 144.218379 -3...
# 2  POLYGON ((145.003973 -37.796644, 145.005267 -3...
#
#                        geom_walking_5min_imputed_wkt  \
# 0  POLYGON ((144.965033 -37.810567, 144.965772 -3...
# 1  POLYGON ((144.291669 -36.747472, 144.291474 -3...
# 2  POLYGON ((145.114079 -37.817069, 145.114686 -3...
#
#                       geom_walking_10min_imputed_wkt  \
# 0  POLYGON ((144.96053 -37.811191, 144.960505 -37...
# 1  POLYGON ((144.288201 -36.749029, 144.289182 -3...
# 2  POLYGON ((145.109408 -37.816478, 145.109996 -3...
#
#                       geom_walking_15min_imputed_wkt  \
# 0  POLYGON ((144.957043 -37.806301, 144.957237 -3...
# 1  POLYGON ((144.284927 -36.746552, 144.285285 -3...
# 2  POLYGON ((145.104716 -37.815921, 145.106036 -3...
#
#    best_school_coord_driving_5min_wkt  best_school_coord_driving_10min_wkt  \
# 0                                 nan                                  nan
# 1         POINT (144.27273 -36.76261)          POINT (144.27273 -36.76261)
# 2            POINT (145.13721 -37.82)          POINT (145.11777 -37.84722)
#
#    best_school_coord_driving_15min_wkt  best_school_coord_walking_5min_wkt  \
# 0                                  nan                                 nan
# 1          POINT (144.27273 -36.76261)         POINT (144.29798 -36.73893)
# 2          POINT (145.11777 -37.84722)         POINT (145.12992 -37.81835)
#
#    best_school_coord_walking_10min_wkt  best_school_coord_walking_15min_wkt
# 0                                  nan                                  nan
# 1          POINT (144.29798 -36.73893)          POINT (144.29798 -36.73893)
# 2          POINT (145.12992 -37.81835)          POINT (145.12992 -37.81835)
#
# [3 rows x 133 columns]

# %%
# Target: ensure numeric, drop NAs, and filter outliers
if 'rental_price' not in df.columns:
    raise KeyError("Column 'rental_price' not found in data.")

df['rental_price'] = pd.to_numeric(df['rental_price'], errors='coerce')
df = df.dropna(subset=['rental_price']).reset_index(drop=True)

# Target outlier filtering (configure as needed)
FILTER_TARGET_OUTLIERS = False # converted to False because outliers are now filtered in preprocessing_domain
TARGET_FILTER_METHOD = 'quantile'  # 'quantile' or 'fixed'
TARGET_Q_LOW = 0.01
TARGET_Q_HIGH = 0.99
TARGET_FIXED_RANGE = (100, 3000)  # used when method == 'fixed'

if FILTER_TARGET_OUTLIERS:
    if TARGET_FILTER_METHOD == 'quantile':
        low = float(df['rental_price'].quantile(TARGET_Q_LOW))
        high = float(df['rental_price'].quantile(TARGET_Q_HIGH))
    elif TARGET_FILTER_METHOD == 'fixed':
        low, high = TARGET_FIXED_RANGE
    else:
        raise ValueError("Unknown TARGET_FILTER_METHOD; use 'quantile' or 'fixed'")
    before = len(df)
    mask = (df['rental_price'] >= low) & (df['rental_price'] <= high)
    df = df.loc[mask].reset_index(drop=True)
    print(f"Filtered target to [{low:.2f}, {high:.2f}] — kept {len(df)}/{before} rows")

# Keep raw target and allow optional log transform later
y_raw = df['rental_price'].astype(float)
X = df.drop(columns=['rental_price'])

# Drop common identifier/free-text columns if present (avoids huge one-hot)
drop_if_present = [
    'id','ID','listing_id','property_id', 'source', 'address','url','link','description','title',
    'full_address','street_address','listing_url','latlon_str','geometry','geom','wkt'
]
cols_to_drop = [c for c in drop_if_present if c in X.columns]
if cols_to_drop:
    X = X.drop(columns=cols_to_drop)

print('Feature matrix shape:', X.shape, '| Target length:', len(y_raw))
X.head(3)
# Out:
# Feature matrix shape: (24027, 130) | Target length: 24027
#    bedrooms  year  quarter  bathrooms     suburb   longitude  car_spaces  \
# 0         2  2023        3          2  melbourne  144.969114           1
# 1         2  2023        2          1    bendigo  144.294778           1
# 2         2  2023        2          1   box hill  145.118664           1
#
#     latitude            property_type  count_childcare_imputed  ...  \
# 0 -37.809525  Apartment / Unit / Flat                      3.0  ...
# 1 -36.745616                    house                      0.0  ...
# 2 -37.817601  apartment / unit / flat                     10.0  ...
#
#                       geom_driving_15min_imputed_wkt  \
# 0  POLYGON ((144.884321 -37.823826, 144.884545 -3...
# 1  POLYGON ((144.218716 -36.707302, 144.218379 -3...
# 2  POLYGON ((145.003973 -37.796644, 145.005267 -3...
#
#                        geom_walking_5min_imputed_wkt  \
# 0  POLYGON ((144.965033 -37.810567, 144.965772 -3...
# 1  POLYGON ((144.291669 -36.747472, 144.291474 -3...
# 2  POLYGON ((145.114079 -37.817069, 145.114686 -3...
#
#                       geom_walking_10min_imputed_wkt  \
# 0  POLYGON ((144.96053 -37.811191, 144.960505 -37...
# 1  POLYGON ((144.288201 -36.749029, 144.289182 -3...
# 2  POLYGON ((145.109408 -37.816478, 145.109996 -3...
#
#                       geom_walking_15min_imputed_wkt  \
# 0  POLYGON ((144.957043 -37.806301, 144.957237 -3...
# 1  POLYGON ((144.284927 -36.746552, 144.285285 -3...
# 2  POLYGON ((145.104716 -37.815921, 145.106036 -3...
#
#    best_school_coord_driving_5min_wkt  best_school_coord_driving_10min_wkt  \
# 0                                 nan                                  nan
# 1         POINT (144.27273 -36.76261)          POINT (144.27273 -36.76261)
# 2            POINT (145.13721 -37.82)          POINT (145.11777 -37.84722)
#
#    best_school_coord_driving_15min_wkt  best_school_coord_walking_5min_wkt  \
# 0                                  nan                                 nan
# 1          POINT (144.27273 -36.76261)         POINT (144.29798 -36.73893)
# 2          POINT (145.11777 -37.84722)         POINT (145.12992 -37.81835)
#
#    best_school_coord_walking_10min_wkt  best_school_coord_walking_15min_wkt
# 0                                  nan                                  nan
# 1          POINT (144.29798 -36.73893)          POINT (144.29798 -36.73893)
# 2          POINT (145.12992 -37.81835)          POINT (145.12992 -37.81835)
#
# [3 rows x 130 columns]

# %%
# Identify feature types from the updated dataset schema
import numpy as np

# Start from the current feature matrix X (df.drop('rental_price'))
X0 = X.copy()

# 1) Drop non-model features (geometry/text blobs, IDs)
drop_exact = {
    'rental_price',
    'property_id',
    'coordinates',
    'listing_point',
    'closest_ptv_station_id',
    'closest_ptv_station_id_imputed'
}
drop_prefixes = ('geom_', 'best_school_name_', 'best_school_coord_')
to_drop = set(c for c in X0.columns if c in drop_exact or any(c.startswith(p) for p in drop_prefixes))
X1 = X0.drop(columns=list(to_drop), errors='ignore')

# 2) Categorical features: real categories present in schema
cat_allow = ['property_type', 'suburb']
categorical_features = [c for c in cat_allow if c in X1.columns]

# 3) Numeric features: all numeric dtypes, excluding numeric IDs/coords if desired
numeric_candidates = X1.select_dtypes(include=[np.number]).columns.tolist()
numeric_exclude = {
    'latitude', 'longitude',
    'closest_ptv_station_id', 'closest_ptv_station_id_imputed',
}
numeric_features = [c for c in numeric_candidates if c not in numeric_exclude]

# 4) Rebuild X using the derived schema
X = X1[categorical_features + numeric_features]

# 5) Summary
print(f"Categorical: {len(categorical_features)} | Numeric: {len(numeric_features)}")
print('Categorical cols:', categorical_features)
print('Numeric sample:', numeric_features[:10])
obj_skipped = sorted(set(X1.select_dtypes(include=['object', 'string']).columns) - set(categorical_features))
if obj_skipped:
    print(f'Skipped {len(obj_skipped)} object/text columns (e.g.):', obj_skipped[:8], '...' if len(obj_skipped) > 8 else '')
# Out:
# Categorical: 2 | Numeric: 87
# Categorical cols: ['property_type', 'suburb']
# Numeric sample: ['bedrooms', 'year', 'quarter', 'bathrooms', 'car_spaces', 'count_childcare_imputed', 'count_community_centre_imputed', 'count_fast_food_imputed', 'count_fire_station_imputed', 'count_pharmacy_imputed']
# Skipped 13 object/text columns (e.g.): ['coordinates_wkt', 'driving_10min_imputed_wkt', 'driving_10min_wkt', 'driving_15min_imputed_wkt', 'driving_15min_wkt', 'driving_5min_imputed_wkt', 'driving_5min_wkt', 'walking_10min_imputed_wkt'] ...

# %%
# Feature matrix after schema-based selection
print('Reduced feature matrix shape:', X.shape)
X.head(3)
# Out:
# Reduced feature matrix shape: (24027, 89)
#              property_type     suburb  bedrooms  year  quarter  bathrooms  \
# 0  Apartment / Unit / Flat  melbourne         2  2023        3          2
# 1                    house    bendigo         2  2023        2          1
# 2  apartment / unit / flat   box hill         2  2023        2          1
#
#    car_spaces  count_childcare_imputed  count_community_centre_imputed  \
# 0           1                      3.0                            14.0
# 1           1                      0.0                             1.0
# 2           1                     10.0                             8.0
#
#    count_fast_food_imputed  ...  n_schools_driving_15min  \
# 0                    279.0  ...                      0.0
# 1                      5.0  ...                     28.0
# 2                     20.0  ...                    124.0
#
#    best_score_walking_5min  best_dist_km_walking_5min  n_schools_walking_5min  \
# 0             3.000000e-08                  15.674877                     0.0
# 1            -8.627893e-05                   0.795158                     1.0
# 2            -8.340861e-05                   0.994585                     2.0
#
#    best_score_walking_10min  best_dist_km_walking_10min  \
# 0              3.000000e-08                   15.674877
# 1             -8.627893e-05                    0.795158
# 2             -8.340861e-05                    0.994585
#
#    n_schools_walking_10min  best_score_walking_15min  \
# 0                      0.0              3.000000e-08
# 1                      1.0             -8.627893e-05
# 2                      2.0             -8.340861e-05
#
#    best_dist_km_walking_15min  n_schools_walking_15min
# 0                    2.865406                      0.0
# 1                    0.795158                      1.0
# 2                    0.994585                      2.0
#
# [3 rows x 89 columns]

# %%
# quickly clean property_type
# was missed in earlier cleaning steps
if 'property_type' in X.columns:
    X['property_type'] = X['property_type'].str.lower().str.strip()
    common_types = ['house', 'apartment / unit / flat', 'townhouse', 'villa', 'duplex']
    X['property_type'] = X['property_type'].where(
        X['property_type'].isin(common_types), other='other'
    )
    print("Unique property_type values after cleaning:", X['property_type'].unique())
# Out:
# Unique property_type values after cleaning: ['apartment / unit / flat' 'house' 'townhouse' 'other' 'villa' 'duplex']
# /var/folders/xj/ny4zmnqd609bv2rpjzzr11rm0000gn/T/ipykernel_43643/841258739.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['property_type'] = X['property_type'].str.lower().str.strip()
# /var/folders/xj/ny4zmnqd609bv2rpjzzr11rm0000gn/T/ipykernel_43643/841258739.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['property_type'] = X['property_type'].where(

# %%
# fill missing numeric with 0 for n_schools
for col in numeric_features:
    if col.startswith('n_schools_'):
        X[col] = X[col].fillna(0)
# Out:
# /var/folders/xj/ny4zmnqd609bv2rpjzzr11rm0000gn/T/ipykernel_43643/1166042083.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = X[col].fillna(0)

# %%
# Identify feature types with a guard against high-cardinality categoricals
# numeric_features = X.select_dtypes(include=[np.number]).columns.tolist()
# categorical_candidates = X.columns.difference(numeric_features)

# max_unique_cats = 100  # avoid exploding OHE on huge text-like columns
# categorical_features, dropped_high_cardinality = [], []
# for col in categorical_candidates:
#     nunique = X[col].nunique(dropna=True)
#     if nunique <= max_unique_cats:
#         categorical_features.append(col)
#     else:
#         dropped_high_cardinality.append(col)

# print(f"Numeric features: {len(numeric_features)}")
# print(f"Categorical features (<= {max_unique_cats} levels): {len(categorical_features)}")
# if dropped_high_cardinality:
#     print(f"Dropping {len(dropped_high_cardinality)} high-cardinality columns (sample): {dropped_high_cardinality[:10]}")

# %%
# Build preprocessors (impute + one-hot)
# Requires 'numeric_features' and 'categorical_features' to be defined above
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
])

# OneHotEncoder signature differs across sklearn versions
try:
    ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=True)
except TypeError:
    ohe = OneHotEncoder(handle_unknown='ignore', sparse=True)

# Split categorical features into OHE vs TargetEncoder
cat_te_cols = [col for col in ['suburb'] if col in categorical_features]
cat_ohe_cols = [col for col in categorical_features if col not in cat_te_cols]
print('Target-encoded:', cat_te_cols, '| One-hot:', cat_ohe_cols)

ohe_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe', ohe),
])

te_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('te', TargetEncoder(target_type='auto')),
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat_ohe', ohe_transformer, cat_ohe_cols),
        ('cat_te', te_transformer, cat_te_cols),
    ],
    remainder='drop',
    verbose_feature_names_out=True,
)
# Out:
# Target-encoded: ['suburb'] | One-hot: ['property_type']

# %%
# Train/val/test split
USE_LOG_TARGET = True  # if True, train on log1p(target) and evaluate on original scale

# Split using raw target first to preserve original-scale y for metrics
X_train, X_test, y_train_raw, y_test_raw = train_test_split(X, y_raw, test_size=0.4, random_state=42)
X_train, X_val, y_train_raw, y_val_raw = train_test_split(X_train, y_train_raw, test_size=0.25, random_state=42)

# Derive training targets (log or raw)
if USE_LOG_TARGET:
    y_train = np.log1p(y_train_raw)
    y_val = np.log1p(y_val_raw)
    y_test = np.log1p(y_test_raw)
else:
    y_train, y_val, y_test = y_train_raw, y_val_raw, y_test_raw

# Fit preprocessor on training data and transform all splits
preprocessor.fit(X_train, y_train)
X_train_t = preprocessor.transform(X_train)
X_val_t = preprocessor.transform(X_val)
X_test_t = preprocessor.transform(X_test)

print('Transformed shapes:', X_train_t.shape, X_val_t.shape, X_test_t.shape)
# Out:
# Transformed shapes: (10812, 94) (3604, 94) (9611, 94)

# %%
# Define and train the XGBoost regressor (with early stopping on the validation set)
xgb = XGBRegressor(
    n_estimators=1000,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=1.0,
    objective='reg:squarederror',
    random_state=42,
    n_jobs=-1,
    tree_method='hist',
    eval_metric='rmse',
)

# Build fit kwargs only with supported parameters for this xgboost version
fit_sig = inspect.signature(XGBRegressor().fit)
supports_callbacks = 'callbacks' in fit_sig.parameters
supports_esr = 'early_stopping_rounds' in fit_sig.parameters

fit_kwargs = {'eval_set': [(X_val_t, y_val)]}

if supports_callbacks and XGB_EarlyStopping is not None:
    fit_kwargs['callbacks'] = [XGB_EarlyStopping(rounds=50, save_best=True, maximize=False)]
elif supports_esr:
    fit_kwargs['early_stopping_rounds'] = 50

xgb.fit(X_train_t, y_train, **fit_kwargs)

# Robust best-iteration retrieval across xgboost versions
def get_best_iter(est):
    # 1) Try estimator attributes
    for attr in ('best_iteration', 'best_ntree_limit', 'best_score', 'best_iteration_'):
        if hasattr(est, attr):
            val = getattr(est, attr)
            if val is not None:
                return attr, val
    # 2) Try Booster attributes
    try:
        b = est.get_booster()
        for attr in ('best_iteration', 'best_ntree_limit', 'best_score'):
            if hasattr(b, attr):
                val = getattr(b, attr)
                if val is not None:
                    return f'booster.{attr}', val
    except Exception:
        pass
    # 3) Derive from evals_result if available
    try:
        ev = est.evals_result()
        if isinstance(ev, dict) and len(ev)>0:
            ds = next(iter(ev))  # e.g., 'validation_0'
            metric = next(iter(ev[ds]))
            import numpy as np
            idx = int(np.argmin(ev[ds][metric]))
            return 'derived_from_evals_result', idx
    except Exception:
        pass
    return None, None

src, best = get_best_iter(xgb)
if src is None:
    # No early stopping info found. This usually means early stopping didn't trigger
    # or no eval_set/metric was provided. The model likely used all trees.
    print(f"No best iteration attribute found; using all {xgb.get_params().get('n_estimators')} estimators.")
else:
    print(f"Best iteration source: {src}; value: {best}")

# Report parameters used at the selected iteration
try:
    xgb_params = xgb.get_xgb_params()
except Exception:
    xgb_params = xgb.get_params()
wrapper_params = xgb.get_params()
# Determine how many estimators were actually used
used_estimators = wrapper_params.get('n_estimators')
try:
    import numpy as np
    if src is not None and isinstance(best, (int, np.integer)):
        if 'best_ntree_limit' in str(src):
            used_estimators = int(best)
        else:
            used_estimators = int(best) + 1
except Exception:
    pass
# Key booster hyperparameters
keys = ['objective','learning_rate','max_depth','min_child_weight','subsample','colsample_bytree','reg_alpha','reg_lambda']
key_params = {k: xgb_params.get(k) for k in keys if k in xgb_params}
print('Planned n_estimators:', wrapper_params.get('n_estimators'), '| Used (best):', used_estimators)
print('Key booster parameters:', key_params)
# If evals_result is available, print the metric value at the best iteration
try:
    ev = xgb.evals_result()
    if isinstance(ev, dict) and len(ev)>0:
        ds = next(iter(ev))
        metric = next(iter(ev[ds]))
        series = ev[ds][metric]
        idx = None
        try:
            idx = int(np.argmin(series))
        except Exception:
            pass
        # Prefer derived index if earlier found
        if src is not None and isinstance(best, (int, np.integer)):
            if 'best_ntree_limit' in str(src):
                idx = int(best) - 1 if best else None
            else:
                idx = int(best)
        if idx is not None and 0 <= idx < len(series):
            print(f"Validation metric {metric} on {ds}: best={series[idx]:.6f} at iteration={idx}")
except Exception:
    pass
# Out:
# [0]	validation_0-rmse:0.29752
# [1]	validation_0-rmse:0.28968
# [2]	validation_0-rmse:0.28128
# [3]	validation_0-rmse:0.27324
# [4]	validation_0-rmse:0.26595
# [5]	validation_0-rmse:0.26034
# [6]	validation_0-rmse:0.25497
# [7]	validation_0-rmse:0.24951
# [8]	validation_0-rmse:0.24320
# [9]	validation_0-rmse:0.23770
# [10]	validation_0-rmse:0.23212
# [11]	validation_0-rmse:0.22688
# [12]	validation_0-rmse:0.22225
# [13]	validation_0-rmse:0.21768
# [14]	validation_0-rmse:0.21344
# [15]	validation_0-rmse:0.20964
# [16]	validation_0-rmse:0.20609
# [17]	validation_0-rmse:0.20279
# [18]	validation_0-rmse:0.19959
# [19]	validation_0-rmse:0.19669
# [20]	validation_0-rmse:0.19397
# [21]	validation_0-rmse:0.19139
# [22]	validation_0-rmse:0.18914
# [23]	validation_0-rmse:0.18709
# [24]	validation_0-rmse:0.18514
# [25]	validation_0-rmse:0.18353
# [26]	validation_0-rmse:0.18202
# [27]	validation_0-rmse:0.18039
# [28]	validation_0-rmse:0.17869
# [29]	validation_0-rmse:0.17719
# [30]	validation_0-rmse:0.17560
# [31]	validation_0-rmse:0.17431
# [32]	validation_0-rmse:0.17313
# [33]	validation_0-rmse:0.17194
# [34]	validation_0-rmse:0.17082
# [35]	validation_0-rmse:0.16983
# [36]	validation_0-rmse:0.16882
# [37]	validation_0-rmse:0.16784
# [38]	validation_0-rmse:0.16698
# [39]	validation_0-rmse:0.16630
# [40]	validation_0-rmse:0.16542
# [41]	validation_0-rmse:0.16475
# [42]	validation_0-rmse:0.16409
# [43]	validation_0-rmse:0.16345
# [44]	validation_0-rmse:0.16284
# [45]	validation_0-rmse:0.16226
# [46]	validation_0-rmse:0.16169
# [47]	validation_0-rmse:0.16124
# [48]	validation_0-rmse:0.16081
# [49]	validation_0-rmse:0.16016
# [50]	validation_0-rmse:0.15962
# [51]	validation_0-rmse:0.15916
# [52]	validation_0-rmse:0.15874
# [53]	validation_0-rmse:0.15844
# [54]	validation_0-rmse:0.15809
# [55]	validation_0-rmse:0.15778
# [56]	validation_0-rmse:0.15751
# [57]	validation_0-rmse:0.15726
# [58]	validation_0-rmse:0.15692
# [59]	validation_0-rmse:0.15661
# [60]	validation_0-rmse:0.15629
# [61]	validation_0-rmse:0.15615
# [62]	validation_0-rmse:0.15587
# [63]	validation_0-rmse:0.15569
# [64]	validation_0-rmse:0.15541
# [65]	validation_0-rmse:0.15511
# [66]	validation_0-rmse:0.15486
# [67]	validation_0-rmse:0.15468
# [68]	validation_0-rmse:0.15448
# [69]	validation_0-rmse:0.15430
# [70]	validation_0-rmse:0.15417
# [71]	validation_0-rmse:0.15400
# [72]	validation_0-rmse:0.15381
# [73]	validation_0-rmse:0.15368
# [74]	validation_0-rmse:0.15351
# [75]	validation_0-rmse:0.15335
# [76]	validation_0-rmse:0.15322
# [77]	validation_0-rmse:0.15310
# [78]	validation_0-rmse:0.15289
# [79]	validation_0-rmse:0.15273
# [80]	validation_0-rmse:0.15258
# [81]	validation_0-rmse:0.15245
# [82]	validation_0-rmse:0.15229
# [83]	validation_0-rmse:0.15219
# [84]	validation_0-rmse:0.15202
# [85]	validation_0-rmse:0.15191
# [86]	validation_0-rmse:0.15183
# [87]	validation_0-rmse:0.15169
# [88]	validation_0-rmse:0.15162
# [89]	validation_0-rmse:0.15152
# [90]	validation_0-rmse:0.15144
# [91]	validation_0-rmse:0.15129
# [92]	validation_0-rmse:0.15114
# [93]	validation_0-rmse:0.15099
# [94]	validation_0-rmse:0.15093
# [95]	validation_0-rmse:0.15086
# [96]	validation_0-rmse:0.15078
# [97]	validation_0-rmse:0.15066
# [98]	validation_0-rmse:0.15057
# [99]	validation_0-rmse:0.15048
# [100]	validation_0-rmse:0.15037
# [101]	validation_0-rmse:0.15036
# [102]	validation_0-rmse:0.15028
# [103]	validation_0-rmse:0.15022
# [104]	validation_0-rmse:0.15005
# [105]	validation_0-rmse:0.14997
# [106]	validation_0-rmse:0.14990
# [107]	validation_0-rmse:0.14986
# [108]	validation_0-rmse:0.14977
# [109]	validation_0-rmse:0.14972
# [110]	validation_0-rmse:0.14966
# [111]	validation_0-rmse:0.14957
# [112]	validation_0-rmse:0.14941
# [113]	validation_0-rmse:0.14932
# [114]	validation_0-rmse:0.14918
# [115]	validation_0-rmse:0.14906
# [116]	validation_0-rmse:0.14900
# [117]	validation_0-rmse:0.14896
# [118]	validation_0-rmse:0.14892
# [119]	validation_0-rmse:0.14891
# [120]	validation_0-rmse:0.14873
# [121]	validation_0-rmse:0.14862
# [122]	validation_0-rmse:0.14863
# [123]	validation_0-rmse:0.14859
# [124]	validation_0-rmse:0.14853
# [125]	validation_0-rmse:0.14844
# [126]	validation_0-rmse:0.14835
# [127]	validation_0-rmse:0.14833
# [128]	validation_0-rmse:0.14830
# [129]	validation_0-rmse:0.14828
# [130]	validation_0-rmse:0.14824
# [131]	validation_0-rmse:0.14821
# [132]	validation_0-rmse:0.14813
# [133]	validation_0-rmse:0.14806
# [134]	validation_0-rmse:0.14800
# [135]	validation_0-rmse:0.14792
# [136]	validation_0-rmse:0.14789
# [137]	validation_0-rmse:0.14791
# [138]	validation_0-rmse:0.14788
# [139]	validation_0-rmse:0.14786
# [140]	validation_0-rmse:0.14783
# [141]	validation_0-rmse:0.14779
# [142]	validation_0-rmse:0.14772
# [143]	validation_0-rmse:0.14766
# [144]	validation_0-rmse:0.14765
# [145]	validation_0-rmse:0.14759
# [146]	validation_0-rmse:0.14756
# [147]	validation_0-rmse:0.14750
# [148]	validation_0-rmse:0.14743
# [149]	validation_0-rmse:0.14742
# [150]	validation_0-rmse:0.14738
# [151]	validation_0-rmse:0.14733
# [152]	validation_0-rmse:0.14729
# [153]	validation_0-rmse:0.14728
# [154]	validation_0-rmse:0.14723
# [155]	validation_0-rmse:0.14718
# [156]	validation_0-rmse:0.14714
# [157]	validation_0-rmse:0.14710
# [158]	validation_0-rmse:0.14713
# [159]	validation_0-rmse:0.14705
# [160]	validation_0-rmse:0.14702
# [161]	validation_0-rmse:0.14699
# [162]	validation_0-rmse:0.14697
# [163]	validation_0-rmse:0.14694
# [164]	validation_0-rmse:0.14687
# [165]	validation_0-rmse:0.14684
# [166]	validation_0-rmse:0.14678
# [167]	validation_0-rmse:0.14675
# [168]	validation_0-rmse:0.14674
# [169]	validation_0-rmse:0.14673
# [170]	validation_0-rmse:0.14669
# [171]	validation_0-rmse:0.14667
# [172]	validation_0-rmse:0.14664
# [173]	validation_0-rmse:0.14659
# [174]	validation_0-rmse:0.14656
# [175]	validation_0-rmse:0.14650
# [176]	validation_0-rmse:0.14648
# [177]	validation_0-rmse:0.14642
# [178]	validation_0-rmse:0.14642
# [179]	validation_0-rmse:0.14640
# [180]	validation_0-rmse:0.14636
# [181]	validation_0-rmse:0.14631
# [182]	validation_0-rmse:0.14627
# [183]	validation_0-rmse:0.14624
# [184]	validation_0-rmse:0.14618
# [185]	validation_0-rmse:0.14617
# [186]	validation_0-rmse:0.14614
# [187]	validation_0-rmse:0.14612
# [188]	validation_0-rmse:0.14609
# [189]	validation_0-rmse:0.14605
# [190]	validation_0-rmse:0.14598
# [191]	validation_0-rmse:0.14596
# [192]	validation_0-rmse:0.14587
# [193]	validation_0-rmse:0.14580
# [194]	validation_0-rmse:0.14579
# [195]	validation_0-rmse:0.14576
# [196]	validation_0-rmse:0.14567
# [197]	validation_0-rmse:0.14562
# [198]	validation_0-rmse:0.14558
# [199]	validation_0-rmse:0.14555
# [200]	validation_0-rmse:0.14550
# [201]	validation_0-rmse:0.14545
# [202]	validation_0-rmse:0.14538
# [203]	validation_0-rmse:0.14538
# [204]	validation_0-rmse:0.14535
# [205]	validation_0-rmse:0.14533
# [206]	validation_0-rmse:0.14529
# [207]	validation_0-rmse:0.14526
# [208]	validation_0-rmse:0.14524
# [209]	validation_0-rmse:0.14523
# [210]	validation_0-rmse:0.14520
# [211]	validation_0-rmse:0.14521
# [212]	validation_0-rmse:0.14515
# [213]	validation_0-rmse:0.14508
# [214]	validation_0-rmse:0.14505
# [215]	validation_0-rmse:0.14502
# [216]	validation_0-rmse:0.14499
# [217]	validation_0-rmse:0.14497
# [218]	validation_0-rmse:0.14493
# [219]	validation_0-rmse:0.14490
# [220]	validation_0-rmse:0.14488
# [221]	validation_0-rmse:0.14487
# [222]	validation_0-rmse:0.14487
# [223]	validation_0-rmse:0.14481
# [224]	validation_0-rmse:0.14479
# [225]	validation_0-rmse:0.14477
# [226]	validation_0-rmse:0.14471
# [227]	validation_0-rmse:0.14467
# [228]	validation_0-rmse:0.14467
# [229]	validation_0-rmse:0.14465
# [230]	validation_0-rmse:0.14467
# [231]	validation_0-rmse:0.14467
# [232]	validation_0-rmse:0.14466
# [233]	validation_0-rmse:0.14457
# [234]	validation_0-rmse:0.14455
# [235]	validation_0-rmse:0.14451
# [236]	validation_0-rmse:0.14448
# [237]	validation_0-rmse:0.14442
# [238]	validation_0-rmse:0.14442
# [239]	validation_0-rmse:0.14438
# [240]	validation_0-rmse:0.14435
# [241]	validation_0-rmse:0.14434
# [242]	validation_0-rmse:0.14434
# [243]	validation_0-rmse:0.14434
# [244]	validation_0-rmse:0.14435
# [245]	validation_0-rmse:0.14432
# [246]	validation_0-rmse:0.14433
# [247]	validation_0-rmse:0.14432
# [248]	validation_0-rmse:0.14432
# [249]	validation_0-rmse:0.14432
# [250]	validation_0-rmse:0.14430
# [251]	validation_0-rmse:0.14427
# [252]	validation_0-rmse:0.14427
# [253]	validation_0-rmse:0.14424
# [254]	validation_0-rmse:0.14423
# [255]	validation_0-rmse:0.14422
# [256]	validation_0-rmse:0.14422
# [257]	validation_0-rmse:0.14417
# [258]	validation_0-rmse:0.14411
# [259]	validation_0-rmse:0.14410
# [260]	validation_0-rmse:0.14411
# [261]	validation_0-rmse:0.14407
# [262]	validation_0-rmse:0.14408
# [263]	validation_0-rmse:0.14406
# [264]	validation_0-rmse:0.14408
# [265]	validation_0-rmse:0.14409
# [266]	validation_0-rmse:0.14409
# [267]	validation_0-rmse:0.14409
# [268]	validation_0-rmse:0.14408
# [269]	validation_0-rmse:0.14406
# [270]	validation_0-rmse:0.14404
# [271]	validation_0-rmse:0.14403
# [272]	validation_0-rmse:0.14403
# [273]	validation_0-rmse:0.14402
# [274]	validation_0-rmse:0.14399
# [275]	validation_0-rmse:0.14398
# [276]	validation_0-rmse:0.14396
# [277]	validation_0-rmse:0.14392
# [278]	validation_0-rmse:0.14393
# [279]	validation_0-rmse:0.14390
# [280]	validation_0-rmse:0.14389
# [281]	validation_0-rmse:0.14388
# [282]	validation_0-rmse:0.14386
# [283]	validation_0-rmse:0.14382
# [284]	validation_0-rmse:0.14381
# [285]	validation_0-rmse:0.14382
# [286]	validation_0-rmse:0.14378
# [287]	validation_0-rmse:0.14377
# [288]	validation_0-rmse:0.14372
# [289]	validation_0-rmse:0.14373
# [290]	validation_0-rmse:0.14374
# [291]	validation_0-rmse:0.14373
# [292]	validation_0-rmse:0.14369
# [293]	validation_0-rmse:0.14367
# [294]	validation_0-rmse:0.14366
# [295]	validation_0-rmse:0.14366
# [296]	validation_0-rmse:0.14363
# [297]	validation_0-rmse:0.14362
# [298]	validation_0-rmse:0.14363
# [299]	validation_0-rmse:0.14361
# [300]	validation_0-rmse:0.14359
# [301]	validation_0-rmse:0.14360
# [302]	validation_0-rmse:0.14358
# [303]	validation_0-rmse:0.14357
# [304]	validation_0-rmse:0.14353
# [305]	validation_0-rmse:0.14356
# [306]	validation_0-rmse:0.14355
# [307]	validation_0-rmse:0.14354
# [308]	validation_0-rmse:0.14353
# [309]	validation_0-rmse:0.14347
# [310]	validation_0-rmse:0.14343
# [311]	validation_0-rmse:0.14339
# [312]	validation_0-rmse:0.14337
# [313]	validation_0-rmse:0.14337
# [314]	validation_0-rmse:0.14336
# [315]	validation_0-rmse:0.14332
# [316]	validation_0-rmse:0.14329
# [317]	validation_0-rmse:0.14329
# [318]	validation_0-rmse:0.14326
# [319]	validation_0-rmse:0.14324
# [320]	validation_0-rmse:0.14323
# [321]	validation_0-rmse:0.14322
# [322]	validation_0-rmse:0.14321
# [323]	validation_0-rmse:0.14321
# [324]	validation_0-rmse:0.14319
# [325]	validation_0-rmse:0.14317
# [326]	validation_0-rmse:0.14312
# [327]	validation_0-rmse:0.14313
# [328]	validation_0-rmse:0.14311
# [329]	validation_0-rmse:0.14309
# [330]	validation_0-rmse:0.14306
# [331]	validation_0-rmse:0.14305
# [332]	validation_0-rmse:0.14304
# [333]	validation_0-rmse:0.14303
# [334]	validation_0-rmse:0.14302
# [335]	validation_0-rmse:0.14300
# [336]	validation_0-rmse:0.14299
# [337]	validation_0-rmse:0.14300
# [338]	validation_0-rmse:0.14297
# [339]	validation_0-rmse:0.14298
# [340]	validation_0-rmse:0.14296
# [341]	validation_0-rmse:0.14295
# [342]	validation_0-rmse:0.14293
# [343]	validation_0-rmse:0.14294
# [344]	validation_0-rmse:0.14294
# [345]	validation_0-rmse:0.14291
# [346]	validation_0-rmse:0.14290
# [347]	validation_0-rmse:0.14288
# [348]	validation_0-rmse:0.14289
# [349]	validation_0-rmse:0.14289
# [350]	validation_0-rmse:0.14288
# [351]	validation_0-rmse:0.14289
# [352]	validation_0-rmse:0.14288
# [353]	validation_0-rmse:0.14285
# [354]	validation_0-rmse:0.14284
# [355]	validation_0-rmse:0.14281
# [356]	validation_0-rmse:0.14280
# [357]	validation_0-rmse:0.14279
# [358]	validation_0-rmse:0.14282
# [359]	validation_0-rmse:0.14281
# [360]	validation_0-rmse:0.14276
# [361]	validation_0-rmse:0.14275
# [362]	validation_0-rmse:0.14273
# [363]	validation_0-rmse:0.14273
# [364]	validation_0-rmse:0.14272
# [365]	validation_0-rmse:0.14269
# [366]	validation_0-rmse:0.14266
# [367]	validation_0-rmse:0.14265
# [368]	validation_0-rmse:0.14262
# [369]	validation_0-rmse:0.14259
# [370]	validation_0-rmse:0.14257
# [371]	validation_0-rmse:0.14258
# [372]	validation_0-rmse:0.14257
# [373]	validation_0-rmse:0.14256
# [374]	validation_0-rmse:0.14255
# [375]	validation_0-rmse:0.14255
# [376]	validation_0-rmse:0.14255
# [377]	validation_0-rmse:0.14252
# [378]	validation_0-rmse:0.14253
# [379]	validation_0-rmse:0.14253
# [380]	validation_0-rmse:0.14252
# [381]	validation_0-rmse:0.14252
# [382]	validation_0-rmse:0.14252
# [383]	validation_0-rmse:0.14249
# [384]	validation_0-rmse:0.14250
# [385]	validation_0-rmse:0.14250
# [386]	validation_0-rmse:0.14250
# [387]	validation_0-rmse:0.14248
# [388]	validation_0-rmse:0.14248
# [389]	validation_0-rmse:0.14247
# [390]	validation_0-rmse:0.14246
# [391]	validation_0-rmse:0.14247
# [392]	validation_0-rmse:0.14247
# [393]	validation_0-rmse:0.14248
# [394]	validation_0-rmse:0.14248
# [395]	validation_0-rmse:0.14247
# [396]	validation_0-rmse:0.14245
# [397]	validation_0-rmse:0.14244
# [398]	validation_0-rmse:0.14244
# [399]	validation_0-rmse:0.14245
# [400]	validation_0-rmse:0.14245
# [401]	validation_0-rmse:0.14241
# [402]	validation_0-rmse:0.14240
# [403]	validation_0-rmse:0.14239
# [404]	validation_0-rmse:0.14239
# [405]	validation_0-rmse:0.14238
# [406]	validation_0-rmse:0.14241
# [407]	validation_0-rmse:0.14243
# [408]	validation_0-rmse:0.14240
# [409]	validation_0-rmse:0.14239
# [410]	validation_0-rmse:0.14237
# [411]	validation_0-rmse:0.14236
# [412]	validation_0-rmse:0.14234
# [413]	validation_0-rmse:0.14235
# [414]	validation_0-rmse:0.14234
# [415]	validation_0-rmse:0.14232
# [416]	validation_0-rmse:0.14232
# [417]	validation_0-rmse:0.14231
# [418]	validation_0-rmse:0.14232
# [419]	validation_0-rmse:0.14231
# [420]	validation_0-rmse:0.14231
# [421]	validation_0-rmse:0.14229
# [422]	validation_0-rmse:0.14228
# [423]	validation_0-rmse:0.14228
# [424]	validation_0-rmse:0.14229
# [425]	validation_0-rmse:0.14228
# [426]	validation_0-rmse:0.14228
# [427]	validation_0-rmse:0.14224
# [428]	validation_0-rmse:0.14223
# [429]	validation_0-rmse:0.14219
# [430]	validation_0-rmse:0.14218
# [431]	validation_0-rmse:0.14217
# [432]	validation_0-rmse:0.14218
# [433]	validation_0-rmse:0.14215
# [434]	validation_0-rmse:0.14212
# [435]	validation_0-rmse:0.14210
# [436]	validation_0-rmse:0.14207
# [437]	validation_0-rmse:0.14204
# [438]	validation_0-rmse:0.14204
# [439]	validation_0-rmse:0.14203
# [440]	validation_0-rmse:0.14204
# [441]	validation_0-rmse:0.14201
# [442]	validation_0-rmse:0.14200
# [443]	validation_0-rmse:0.14200
# [444]	validation_0-rmse:0.14199
# [445]	validation_0-rmse:0.14199
# [446]	validation_0-rmse:0.14196
# [447]	validation_0-rmse:0.14197
# [448]	validation_0-rmse:0.14198
# [449]	validation_0-rmse:0.14199
# [450]	validation_0-rmse:0.14196
# [451]	validation_0-rmse:0.14194
# [452]	validation_0-rmse:0.14194
# [453]	validation_0-rmse:0.14194
# [454]	validation_0-rmse:0.14191
# [455]	validation_0-rmse:0.14190
# [456]	validation_0-rmse:0.14191
# [457]	validation_0-rmse:0.14189
# [458]	validation_0-rmse:0.14188
# [459]	validation_0-rmse:0.14186
# [460]	validation_0-rmse:0.14184
# [461]	validation_0-rmse:0.14184
# [462]	validation_0-rmse:0.14182
# [463]	validation_0-rmse:0.14182
# [464]	validation_0-rmse:0.14182
# [465]	validation_0-rmse:0.14182
# [466]	validation_0-rmse:0.14180
# [467]	validation_0-rmse:0.14183
# [468]	validation_0-rmse:0.14183
# [469]	validation_0-rmse:0.14183
# [470]	validation_0-rmse:0.14182
# [471]	validation_0-rmse:0.14184
# [472]	validation_0-rmse:0.14183
# [473]	validation_0-rmse:0.14187
# [474]	validation_0-rmse:0.14185
# [475]	validation_0-rmse:0.14185
# [476]	validation_0-rmse:0.14184
# [477]	validation_0-rmse:0.14185
# [478]	validation_0-rmse:0.14184
# [479]	validation_0-rmse:0.14183
# [480]	validation_0-rmse:0.14182
# [481]	validation_0-rmse:0.14183
# [482]	validation_0-rmse:0.14181
# [483]	validation_0-rmse:0.14180
# [484]	validation_0-rmse:0.14179
# [485]	validation_0-rmse:0.14174
# [486]	validation_0-rmse:0.14174
# [487]	validation_0-rmse:0.14175
# [488]	validation_0-rmse:0.14175
# [489]	validation_0-rmse:0.14174
# [490]	validation_0-rmse:0.14172
# [491]	validation_0-rmse:0.14172
# [492]	validation_0-rmse:0.14173
# [493]	validation_0-rmse:0.14174
# [494]	validation_0-rmse:0.14172
# [495]	validation_0-rmse:0.14172
# [496]	validation_0-rmse:0.14171
# [497]	validation_0-rmse:0.14172
# [498]	validation_0-rmse:0.14172
# [499]	validation_0-rmse:0.14173
# [500]	validation_0-rmse:0.14174
# [501]	validation_0-rmse:0.14173
# [502]	validation_0-rmse:0.14174
# [503]	validation_0-rmse:0.14174
# [504]	validation_0-rmse:0.14175
# [505]	validation_0-rmse:0.14174
# [506]	validation_0-rmse:0.14174
# [507]	validation_0-rmse:0.14174
# [508]	validation_0-rmse:0.14173
# [509]	validation_0-rmse:0.14171
# [510]	validation_0-rmse:0.14170
# [511]	validation_0-rmse:0.14169
# [512]	validation_0-rmse:0.14169
# [513]	validation_0-rmse:0.14170
# [514]	validation_0-rmse:0.14169
# [515]	validation_0-rmse:0.14169
# [516]	validation_0-rmse:0.14170
# [517]	validation_0-rmse:0.14172
# [518]	validation_0-rmse:0.14167
# [519]	validation_0-rmse:0.14166
# [520]	validation_0-rmse:0.14164
# [521]	validation_0-rmse:0.14161
# [522]	validation_0-rmse:0.14163
# [523]	validation_0-rmse:0.14163
# [524]	validation_0-rmse:0.14162
# [525]	validation_0-rmse:0.14162
# [526]	validation_0-rmse:0.14162
# [527]	validation_0-rmse:0.14162
# [528]	validation_0-rmse:0.14161
# [529]	validation_0-rmse:0.14159
# [530]	validation_0-rmse:0.14160
# [531]	validation_0-rmse:0.14159
# [532]	validation_0-rmse:0.14158
# [533]	validation_0-rmse:0.14157
# [534]	validation_0-rmse:0.14155
# [535]	validation_0-rmse:0.14155
# [536]	validation_0-rmse:0.14154
# [537]	validation_0-rmse:0.14158
# [538]	validation_0-rmse:0.14159
# [539]	validation_0-rmse:0.14156
# [540]	validation_0-rmse:0.14156
# [541]	validation_0-rmse:0.14152
# [542]	validation_0-rmse:0.14151
# [543]	validation_0-rmse:0.14153
# [544]	validation_0-rmse:0.14154
# [545]	validation_0-rmse:0.14155
# [546]	validation_0-rmse:0.14154
# [547]	validation_0-rmse:0.14155
# [548]	validation_0-rmse:0.14154
# [549]	validation_0-rmse:0.14154
# [550]	validation_0-rmse:0.14153
# [551]	validation_0-rmse:0.14152
# [552]	validation_0-rmse:0.14152
# [553]	validation_0-rmse:0.14151
# [554]	validation_0-rmse:0.14150
# [555]	validation_0-rmse:0.14149
# [556]	validation_0-rmse:0.14149
# [557]	validation_0-rmse:0.14149
# [558]	validation_0-rmse:0.14146
# [559]	validation_0-rmse:0.14146
# [560]	validation_0-rmse:0.14146
# [561]	validation_0-rmse:0.14146
# [562]	validation_0-rmse:0.14145
# [563]	validation_0-rmse:0.14144
# [564]	validation_0-rmse:0.14144
# [565]	validation_0-rmse:0.14144
# [566]	validation_0-rmse:0.14144
# [567]	validation_0-rmse:0.14142
# [568]	validation_0-rmse:0.14139
# [569]	validation_0-rmse:0.14139
# [570]	validation_0-rmse:0.14139
# [571]	validation_0-rmse:0.14140
# [572]	validation_0-rmse:0.14140
# [573]	validation_0-rmse:0.14137
# [574]	validation_0-rmse:0.14135
# [575]	validation_0-rmse:0.14134
# [576]	validation_0-rmse:0.14133
# [577]	validation_0-rmse:0.14132
# [578]	validation_0-rmse:0.14134
# [579]	validation_0-rmse:0.14133
# [580]	validation_0-rmse:0.14135
# [581]	validation_0-rmse:0.14136
# [582]	validation_0-rmse:0.14137
# [583]	validation_0-rmse:0.14137
# [584]	validation_0-rmse:0.14138
# [585]	validation_0-rmse:0.14137
# [586]	validation_0-rmse:0.14137
# [587]	validation_0-rmse:0.14138
# [588]	validation_0-rmse:0.14137
# [589]	validation_0-rmse:0.14138
# [590]	validation_0-rmse:0.14140
# [591]	validation_0-rmse:0.14138
# [592]	validation_0-rmse:0.14138
# [593]	validation_0-rmse:0.14138
# [594]	validation_0-rmse:0.14138
# [595]	validation_0-rmse:0.14138
# [596]	validation_0-rmse:0.14138
# [597]	validation_0-rmse:0.14139
# [598]	validation_0-rmse:0.14139
# [599]	validation_0-rmse:0.14139
# [600]	validation_0-rmse:0.14139
# [601]	validation_0-rmse:0.14137
# [602]	validation_0-rmse:0.14137
# [603]	validation_0-rmse:0.14136
# [604]	validation_0-rmse:0.14137
# [605]	validation_0-rmse:0.14136
# [606]	validation_0-rmse:0.14136
# [607]	validation_0-rmse:0.14136
# [608]	validation_0-rmse:0.14135
# [609]	validation_0-rmse:0.14133
# [610]	validation_0-rmse:0.14133
# [611]	validation_0-rmse:0.14133
# [612]	validation_0-rmse:0.14133
# [613]	validation_0-rmse:0.14133
# [614]	validation_0-rmse:0.14134
# [615]	validation_0-rmse:0.14133
# [616]	validation_0-rmse:0.14133
# [617]	validation_0-rmse:0.14134
# [618]	validation_0-rmse:0.14132
# [619]	validation_0-rmse:0.14129
# [620]	validation_0-rmse:0.14129
# [621]	validation_0-rmse:0.14129
# [622]	validation_0-rmse:0.14125
# [623]	validation_0-rmse:0.14125
# [624]	validation_0-rmse:0.14125
# [625]	validation_0-rmse:0.14123
# [626]	validation_0-rmse:0.14122
# [627]	validation_0-rmse:0.14121
# [628]	validation_0-rmse:0.14121
# [629]	validation_0-rmse:0.14121
# [630]	validation_0-rmse:0.14119
# [631]	validation_0-rmse:0.14118
# [632]	validation_0-rmse:0.14117
# [633]	validation_0-rmse:0.14116
# [634]	validation_0-rmse:0.14114
# [635]	validation_0-rmse:0.14111
# [636]	validation_0-rmse:0.14111
# [637]	validation_0-rmse:0.14111
# [638]	validation_0-rmse:0.14110
# [639]	validation_0-rmse:0.14111
# [640]	validation_0-rmse:0.14113
# [641]	validation_0-rmse:0.14112
# [642]	validation_0-rmse:0.14112
# [643]	validation_0-rmse:0.14112
# [644]	validation_0-rmse:0.14113
# [645]	validation_0-rmse:0.14114
# [646]	validation_0-rmse:0.14114
# [647]	validation_0-rmse:0.14113
# [648]	validation_0-rmse:0.14113
# [649]	validation_0-rmse:0.14115
# [650]	validation_0-rmse:0.14115
# [651]	validation_0-rmse:0.14115
# [652]	validation_0-rmse:0.14115
# [653]	validation_0-rmse:0.14115
# [654]	validation_0-rmse:0.14115
# [655]	validation_0-rmse:0.14115
# [656]	validation_0-rmse:0.14114
# [657]	validation_0-rmse:0.14113
# [658]	validation_0-rmse:0.14113
# [659]	validation_0-rmse:0.14114
# [660]	validation_0-rmse:0.14114
# [661]	validation_0-rmse:0.14113
# [662]	validation_0-rmse:0.14114
# [663]	validation_0-rmse:0.14115
# [664]	validation_0-rmse:0.14116
# [665]	validation_0-rmse:0.14116
# [666]	validation_0-rmse:0.14116
# [667]	validation_0-rmse:0.14117
# [668]	validation_0-rmse:0.14114
# [669]	validation_0-rmse:0.14113
# [670]	validation_0-rmse:0.14113
# [671]	validation_0-rmse:0.14114
# [672]	validation_0-rmse:0.14115
# [673]	validation_0-rmse:0.14114
# [674]	validation_0-rmse:0.14115
# [675]	validation_0-rmse:0.14115
# [676]	validation_0-rmse:0.14117
# [677]	validation_0-rmse:0.14115
# [678]	validation_0-rmse:0.14116
# [679]	validation_0-rmse:0.14117
# [680]	validation_0-rmse:0.14117
# [681]	validation_0-rmse:0.14117
# [682]	validation_0-rmse:0.14116
# [683]	validation_0-rmse:0.14115
# [684]	validation_0-rmse:0.14113
# [685]	validation_0-rmse:0.14115
# [686]	validation_0-rmse:0.14114
# [687]	validation_0-rmse:0.14116
# [688]	validation_0-rmse:0.14116
# [689]	validation_0-rmse:0.14116
# [690]	validation_0-rmse:0.14116
# [691]	validation_0-rmse:0.14115
# [692]	validation_0-rmse:0.14116
# [693]	validation_0-rmse:0.14115
# [694]	validation_0-rmse:0.14114
# [695]	validation_0-rmse:0.14114
# [696]	validation_0-rmse:0.14115
# [697]	validation_0-rmse:0.14115
# [698]	validation_0-rmse:0.14116
# [699]	validation_0-rmse:0.14118
# [700]	validation_0-rmse:0.14118
# [701]	validation_0-rmse:0.14117
# [702]	validation_0-rmse:0.14117
# [703]	validation_0-rmse:0.14117
# [704]	validation_0-rmse:0.14115
# [705]	validation_0-rmse:0.14116
# [706]	validation_0-rmse:0.14117
# [707]	validation_0-rmse:0.14118
# [708]	validation_0-rmse:0.14118
# [709]	validation_0-rmse:0.14119
# [710]	validation_0-rmse:0.14120
# [711]	validation_0-rmse:0.14120
# [712]	validation_0-rmse:0.14118
# [713]	validation_0-rmse:0.14118
# [714]	validation_0-rmse:0.14118
# [715]	validation_0-rmse:0.14118
# [716]	validation_0-rmse:0.14118
# [717]	validation_0-rmse:0.14118
# [718]	validation_0-rmse:0.14118
# [719]	validation_0-rmse:0.14116
# [720]	validation_0-rmse:0.14117
# [721]	validation_0-rmse:0.14117
# [722]	validation_0-rmse:0.14116
# [723]	validation_0-rmse:0.14113
# [724]	validation_0-rmse:0.14115
# [725]	validation_0-rmse:0.14114
# [726]	validation_0-rmse:0.14113
# [727]	validation_0-rmse:0.14113
# [728]	validation_0-rmse:0.14115
# [729]	validation_0-rmse:0.14114
# [730]	validation_0-rmse:0.14114
# [731]	validation_0-rmse:0.14114
# [732]	validation_0-rmse:0.14115
# [733]	validation_0-rmse:0.14114
# [734]	validation_0-rmse:0.14114
# [735]	validation_0-rmse:0.14112
# [736]	validation_0-rmse:0.14113
# [737]	validation_0-rmse:0.14113
# [738]	validation_0-rmse:0.14113
# [739]	validation_0-rmse:0.14114
# [740]	validation_0-rmse:0.14113
# [741]	validation_0-rmse:0.14112
# [742]	validation_0-rmse:0.14112
# [743]	validation_0-rmse:0.14112
# [744]	validation_0-rmse:0.14113
# [745]	validation_0-rmse:0.14112
# [746]	validation_0-rmse:0.14111
# [747]	validation_0-rmse:0.14110
# [748]	validation_0-rmse:0.14109
# [749]	validation_0-rmse:0.14110
# [750]	validation_0-rmse:0.14110
# [751]	validation_0-rmse:0.14111
# [752]	validation_0-rmse:0.14111
# [753]	validation_0-rmse:0.14113
# [754]	validation_0-rmse:0.14112
# [755]	validation_0-rmse:0.14112
# [756]	validation_0-rmse:0.14111
# [757]	validation_0-rmse:0.14111
# [758]	validation_0-rmse:0.14112
# [759]	validation_0-rmse:0.14111
# [760]	validation_0-rmse:0.14112
# [761]	validation_0-rmse:0.14112
# [762]	validation_0-rmse:0.14112
# [763]	validation_0-rmse:0.14112
# [764]	validation_0-rmse:0.14112
# [765]	validation_0-rmse:0.14112
# [766]	validation_0-rmse:0.14112
# [767]	validation_0-rmse:0.14112
# [768]	validation_0-rmse:0.14109
# [769]	validation_0-rmse:0.14110
# [770]	validation_0-rmse:0.14111
# [771]	validation_0-rmse:0.14108
# [772]	validation_0-rmse:0.14107
# [773]	validation_0-rmse:0.14108
# [774]	validation_0-rmse:0.14107
# [775]	validation_0-rmse:0.14107
# [776]	validation_0-rmse:0.14107
# [777]	validation_0-rmse:0.14106
# [778]	validation_0-rmse:0.14107
# [779]	validation_0-rmse:0.14108
# [780]	validation_0-rmse:0.14108
# [781]	validation_0-rmse:0.14108
# [782]	validation_0-rmse:0.14107
# [783]	validation_0-rmse:0.14108
# [784]	validation_0-rmse:0.14108
# [785]	validation_0-rmse:0.14107
# [786]	validation_0-rmse:0.14107
# [787]	validation_0-rmse:0.14108
# [788]	validation_0-rmse:0.14107
# [789]	validation_0-rmse:0.14108
# [790]	validation_0-rmse:0.14108
# [791]	validation_0-rmse:0.14109
# [792]	validation_0-rmse:0.14108
# [793]	validation_0-rmse:0.14107
# [794]	validation_0-rmse:0.14105
# [795]	validation_0-rmse:0.14105
# [796]	validation_0-rmse:0.14105
# [797]	validation_0-rmse:0.14106
# [798]	validation_0-rmse:0.14105
# [799]	validation_0-rmse:0.14105
# [800]	validation_0-rmse:0.14104
# [801]	validation_0-rmse:0.14105
# [802]	validation_0-rmse:0.14108
# [803]	validation_0-rmse:0.14107
# [804]	validation_0-rmse:0.14109
# [805]	validation_0-rmse:0.14109
# [806]	validation_0-rmse:0.14108
# [807]	validation_0-rmse:0.14109
# [808]	validation_0-rmse:0.14109
# [809]	validation_0-rmse:0.14110
# [810]	validation_0-rmse:0.14108
# [811]	validation_0-rmse:0.14109
# [812]	validation_0-rmse:0.14110
# [813]	validation_0-rmse:0.14109
# [814]	validation_0-rmse:0.14108
# [815]	validation_0-rmse:0.14108
# [816]	validation_0-rmse:0.14108
# [817]	validation_0-rmse:0.14106
# [818]	validation_0-rmse:0.14106
# [819]	validation_0-rmse:0.14106
# [820]	validation_0-rmse:0.14106
# [821]	validation_0-rmse:0.14107
# [822]	validation_0-rmse:0.14107
# [823]	validation_0-rmse:0.14108
# [824]	validation_0-rmse:0.14108
# [825]	validation_0-rmse:0.14107
# [826]	validation_0-rmse:0.14108
# [827]	validation_0-rmse:0.14109
# [828]	validation_0-rmse:0.14109
# [829]	validation_0-rmse:0.14110
# [830]	validation_0-rmse:0.14109
# [831]	validation_0-rmse:0.14110
# [832]	validation_0-rmse:0.14110
# [833]	validation_0-rmse:0.14111
# [834]	validation_0-rmse:0.14110
# [835]	validation_0-rmse:0.14110
# [836]	validation_0-rmse:0.14110
# [837]	validation_0-rmse:0.14109
# [838]	validation_0-rmse:0.14111
# [839]	validation_0-rmse:0.14111
# [840]	validation_0-rmse:0.14111
# [841]	validation_0-rmse:0.14113
# [842]	validation_0-rmse:0.14113
# [843]	validation_0-rmse:0.14114
# [844]	validation_0-rmse:0.14113
# [845]	validation_0-rmse:0.14113
# [846]	validation_0-rmse:0.14112
# [847]	validation_0-rmse:0.14112
# [848]	validation_0-rmse:0.14112
# [849]	validation_0-rmse:0.14113
# [850]	validation_0-rmse:0.14112
# [851]	validation_0-rmse:0.14113
# [852]	validation_0-rmse:0.14113
# [853]	validation_0-rmse:0.14113
# [854]	validation_0-rmse:0.14113
# [855]	validation_0-rmse:0.14114
# [856]	validation_0-rmse:0.14113
# [857]	validation_0-rmse:0.14111
# [858]	validation_0-rmse:0.14113
# [859]	validation_0-rmse:0.14112
# [860]	validation_0-rmse:0.14111
# [861]	validation_0-rmse:0.14110
# [862]	validation_0-rmse:0.14109
# [863]	validation_0-rmse:0.14108
# [864]	validation_0-rmse:0.14108
# [865]	validation_0-rmse:0.14109
# [866]	validation_0-rmse:0.14110
# [867]	validation_0-rmse:0.14110
# [868]	validation_0-rmse:0.14110
# [869]	validation_0-rmse:0.14111
# [870]	validation_0-rmse:0.14110
# [871]	validation_0-rmse:0.14110
# [872]	validation_0-rmse:0.14109
# [873]	validation_0-rmse:0.14109
# [874]	validation_0-rmse:0.14109
# [875]	validation_0-rmse:0.14109
# [876]	validation_0-rmse:0.14110
# [877]	validation_0-rmse:0.14109
# [878]	validation_0-rmse:0.14108
# [879]	validation_0-rmse:0.14109
# [880]	validation_0-rmse:0.14107
# [881]	validation_0-rmse:0.14107
# [882]	validation_0-rmse:0.14107
# [883]	validation_0-rmse:0.14107
# [884]	validation_0-rmse:0.14106
# [885]	validation_0-rmse:0.14106
# [886]	validation_0-rmse:0.14107
# [887]	validation_0-rmse:0.14108
# [888]	validation_0-rmse:0.14108
# [889]	validation_0-rmse:0.14108
# [890]	validation_0-rmse:0.14107
# [891]	validation_0-rmse:0.14107
# [892]	validation_0-rmse:0.14108
# [893]	validation_0-rmse:0.14108
# [894]	validation_0-rmse:0.14106
# [895]	validation_0-rmse:0.14106
# [896]	validation_0-rmse:0.14108
# [897]	validation_0-rmse:0.14108
# [898]	validation_0-rmse:0.14107
# [899]	validation_0-rmse:0.14107
# [900]	validation_0-rmse:0.14107
# [901]	validation_0-rmse:0.14107
# [902]	validation_0-rmse:0.14107
# [903]	validation_0-rmse:0.14106
# [904]	validation_0-rmse:0.14105
# [905]	validation_0-rmse:0.14106
# [906]	validation_0-rmse:0.14106
# [907]	validation_0-rmse:0.14107
# [908]	validation_0-rmse:0.14107
# [909]	validation_0-rmse:0.14108
# [910]	validation_0-rmse:0.14107
# [911]	validation_0-rmse:0.14107
# [912]	validation_0-rmse:0.14107
# [913]	validation_0-rmse:0.14108
# [914]	validation_0-rmse:0.14108
# [915]	validation_0-rmse:0.14108
# [916]	validation_0-rmse:0.14109
# [917]	validation_0-rmse:0.14109
# [918]	validation_0-rmse:0.14109
# [919]	validation_0-rmse:0.14110
# [920]	validation_0-rmse:0.14109
# [921]	validation_0-rmse:0.14110
# [922]	validation_0-rmse:0.14110
# [923]	validation_0-rmse:0.14110
# [924]	validation_0-rmse:0.14111
# [925]	validation_0-rmse:0.14110
# [926]	validation_0-rmse:0.14109
# [927]	validation_0-rmse:0.14110
# [928]	validation_0-rmse:0.14109
# [929]	validation_0-rmse:0.14110
# [930]	validation_0-rmse:0.14111
# [931]	validation_0-rmse:0.14110
# [932]	validation_0-rmse:0.14110
# [933]	validation_0-rmse:0.14110
# [934]	validation_0-rmse:0.14110
# [935]	validation_0-rmse:0.14110
# [936]	validation_0-rmse:0.14111
# [937]	validation_0-rmse:0.14110
# [938]	validation_0-rmse:0.14111
# [939]	validation_0-rmse:0.14112
# [940]	validation_0-rmse:0.14111
# [941]	validation_0-rmse:0.14111
# [942]	validation_0-rmse:0.14110
# [943]	validation_0-rmse:0.14110
# [944]	validation_0-rmse:0.14110
# [945]	validation_0-rmse:0.14111
# [946]	validation_0-rmse:0.14111
# [947]	validation_0-rmse:0.14111
# [948]	validation_0-rmse:0.14111
# [949]	validation_0-rmse:0.14111
# [950]	validation_0-rmse:0.14112
# [951]	validation_0-rmse:0.14111
# [952]	validation_0-rmse:0.14112
# [953]	validation_0-rmse:0.14113
# [954]	validation_0-rmse:0.14113
# [955]	validation_0-rmse:0.14113
# [956]	validation_0-rmse:0.14114
# [957]	validation_0-rmse:0.14112
# [958]	validation_0-rmse:0.14112
# [959]	validation_0-rmse:0.14112
# [960]	validation_0-rmse:0.14112
# [961]	validation_0-rmse:0.14113
# [962]	validation_0-rmse:0.14113
# [963]	validation_0-rmse:0.14112
# [964]	validation_0-rmse:0.14113
# [965]	validation_0-rmse:0.14113
# [966]	validation_0-rmse:0.14112
# [967]	validation_0-rmse:0.14111
# [968]	validation_0-rmse:0.14111
# [969]	validation_0-rmse:0.14111
# [970]	validation_0-rmse:0.14112
# [971]	validation_0-rmse:0.14112
# [972]	validation_0-rmse:0.14113
# [973]	validation_0-rmse:0.14114
# [974]	validation_0-rmse:0.14113
# [975]	validation_0-rmse:0.14112
# [976]	validation_0-rmse:0.14111
# [977]	validation_0-rmse:0.14110
# [978]	validation_0-rmse:0.14110
# [979]	validation_0-rmse:0.14110
# [980]	validation_0-rmse:0.14109
# [981]	validation_0-rmse:0.14110
# [982]	validation_0-rmse:0.14109
# [983]	validation_0-rmse:0.14109
# [984]	validation_0-rmse:0.14109
# [985]	validation_0-rmse:0.14110
# [986]	validation_0-rmse:0.14110
# [987]	validation_0-rmse:0.14109
# [988]	validation_0-rmse:0.14109
# [989]	validation_0-rmse:0.14109
# [990]	validation_0-rmse:0.14109
# [991]	validation_0-rmse:0.14109
# [992]	validation_0-rmse:0.14110
# [993]	validation_0-rmse:0.14111
# [994]	validation_0-rmse:0.14110
# [995]	validation_0-rmse:0.14111
# [996]	validation_0-rmse:0.14111
# [997]	validation_0-rmse:0.14112
# [998]	validation_0-rmse:0.14112
# [999]	validation_0-rmse:0.14111
# Best iteration source: derived_from_evals_result; value: 800
# Planned n_estimators: 1000 | Used (best): 801
# Key booster parameters: {'objective': 'reg:squarederror', 'learning_rate': 0.05, 'max_depth': 6, 'min_child_weight': None, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': None, 'reg_lambda': 1.0}
# Validation metric rmse on validation_0: best=0.141036 at iteration=800

# %%
# Evaluate performance
def regression_metrics(y_true, y_pred):
    # Handle sklearn versions without the 'squared' kwarg
    mse_sig = inspect.signature(mean_squared_error)
    if 'squared' in mse_sig.parameters:
        rmse = mean_squared_error(y_true, y_pred, squared=False)
    else:
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return {'RMSE': rmse, 'MAE': mae, 'R2': r2}

# Raw predictions from the model (in log scale if USE_LOG_TARGET)
y_train_pred = xgb.predict(X_train_t)
y_val_pred = xgb.predict(X_val_t)
y_test_pred = xgb.predict(X_test_t)

# Convert predictions back to original scale when needed
if 'USE_LOG_TARGET' in globals() and USE_LOG_TARGET:
    y_train_eval = np.expm1(y_train_pred)
    y_val_eval = np.expm1(y_val_pred)
    y_test_eval = np.expm1(y_test_pred)
    yt_train = y_train_raw
    yt_val = y_val_raw
    yt_test = y_test_raw
else:
    y_train_eval, y_val_eval, y_test_eval = y_train_pred, y_val_pred, y_test_pred
    yt_train, yt_val, yt_test = y_train, y_val, y_test

print('Train metrics:', regression_metrics(yt_train, y_train_eval))
print('Val metrics:  ', regression_metrics(yt_val, y_val_eval))
print('Test metrics: ', regression_metrics(yt_test, y_test_eval))

plt.figure(figsize=(6, 6))
sns.scatterplot(x=yt_test, y=y_test_eval, s=12, alpha=0.5)
lims = [min(yt_test.min(), y_test_eval.min()), max(yt_test.max(), y_test_eval.max())]
plt.plot(lims, lims, 'r--', linewidth=1)
plt.xlabel('Actual rental_price')
plt.ylabel('Predicted rental_price')
plt.title('Predicted vs Actual (Test)')
plt.show()
# Out:
# Train metrics: {'RMSE': np.float64(32.90687437415134), 'MAE': 21.987172444661457, 'R2': 0.9745937578795925}
# Val metrics:   {'RMSE': np.float64(98.88660458731017), 'MAE': 62.23974892619447, 'R2': 0.7605035005873273}
# Test metrics:  {'RMSE': np.float64(104.6367378405216), 'MAE': 65.35459771551335, 'R2': 0.746692713212417}

# %%
# Optional: cross-validation on the full dataset (may be slow on large files)
DO_CV = False
if DO_CV:
    model = Pipeline(steps=[('preprocessor', preprocessor), ('model', xgb)])
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    cv_scores = cross_val_score(model, X, y_raw, cv=kf, scoring='neg_root_mean_squared_error', n_jobs=-1)
    print('CV RMSE: ', (-cv_scores).mean(), '+/-', (-cv_scores).std())

# %%
# Feature importances
importances = xgb.feature_importances_
try:
    feature_names = preprocessor.get_feature_names_out()
except Exception:
    # Fallback: generic names if transformers don't expose names
    feature_names = np.asarray([f'feature_{i}' for i in range(importances.shape[0])], dtype=object)
feat_imp = pd.DataFrame({'feature': feature_names, 'importance': importances}).sort_values('importance', ascending=False)
feat_imp.head(20)

top_n = 20
plt.figure(figsize=(8, max(4, top_n * 0.4)))
sns.barplot(data=feat_imp.head(top_n), x='importance', y='feature', orient='h')
plt.title(f'Top {top_n} Feature Importances (XGBoost)')
plt.tight_layout()
plt.show()

# %%
# Optional: save fitted pipeline (preprocessing + model)
from joblib import dump
save_dir = Path('../models')
save_dir.mkdir(parents=True, exist_ok=True)
fitted_pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', xgb)])
model_path = save_dir / 'xgb_rental_price_pipeline.joblib'
dump(fitted_pipeline, model_path)
print(f'Saved pipeline to {model_path}')
# Out:
# Saved pipeline to ../models/xgb_rental_price_pipeline.joblib

# %% [markdown]
# # Hyperparameter Tuning

# %%
# Hyperparameter tuning (RandomizedSearchCV)
from sklearn.model_selection import RandomizedSearchCV, KFold
from sklearn.metrics import make_scorer, mean_squared_error, mean_absolute_error, r2_score
from scipy.stats import loguniform, uniform, randint

DO_TUNING = True
TUNE_SAMPLE_FRAC = 1.0
N_ITER = 200
CV_FOLDS = 5
RANDOM_STATE = 42

def rmse_on_original(y_true_in, y_pred_in):
    if 'USE_LOG_TARGET' in globals() and USE_LOG_TARGET:
        yt, yp = np.expm1(y_true_in), np.expm1(y_pred_in)
    else:
        yt, yp = y_true_in, y_pred_in
    return np.sqrt(mean_squared_error(yt, yp))

rmse_orig = make_scorer(rmse_on_original, greater_is_better=False)

if DO_TUNING:
    pipe = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('model', XGBRegressor(
            objective='reg:squarederror',
            tree_method='hist',
            random_state=RANDOM_STATE,
            n_jobs=-1,
            eval_metric='rmse',
        )),
    ])

    param_distributions = {
        'model__n_estimators': randint(400, 2001),
        'model__learning_rate': loguniform(1e-3, 1e-1),
        'model__max_depth': randint(3, 10),
        'model__min_child_weight': randint(1, 16),
        'model__subsample': uniform(0.5, 0.5),
        'model__colsample_bytree': uniform(0.5, 0.5),
        'model__colsample_bylevel': uniform(0.5, 0.5),
        'model__colsample_bynode': uniform(0.5, 0.5),
        'model__reg_alpha': loguniform(1e-4, 1e1),
        'model__reg_lambda': loguniform(1e-2, 1e1),
        'model__gamma': loguniform(1e-3, 1e1),
        'model__max_bin': randint(64, 257),
        'model__grow_policy': ['depthwise', 'lossguide'],
        'model__max_leaves': randint(2, 129),
    }

    # Drop unsupported XGB params based on installed version
    try:
        _xgb_params_supported = set(XGBRegressor().get_params().keys())
        _pd_filtered, _dropped = {}, []
        for _k, _v in param_distributions.items():
            _p = _k.split('__', 1)[1]
            if _p in _xgb_params_supported:
                _pd_filtered[_k] = _v
            else:
                _dropped.append(_k)
        if _dropped:
            print('Dropping unsupported params:', _dropped)
        param_distributions = _pd_filtered
    except Exception as _e:
        print('Param filtering skipped due to:', _e)

    cv = KFold(n_splits=CV_FOLDS, shuffle=True, random_state=RANDOM_STATE)

    X_tune, y_tune = X_train, y_train
    if TUNE_SAMPLE_FRAC and TUNE_SAMPLE_FRAC < 1.0:
        sample_idx = X_train.sample(frac=TUNE_SAMPLE_FRAC, random_state=RANDOM_STATE).index
        X_tune = X_train.loc[sample_idx]
        y_tune = y_train.loc[sample_idx] if hasattr(y_train, 'loc') else y_train[sample_idx]
        print(f'Sampled {len(X_tune)}/{len(X_train)} rows for tuning')

    scoring = {'rmse': rmse_orig, 'mae': 'neg_mean_absolute_error', 'r2': 'r2'}
    search = RandomizedSearchCV(
        estimator=pipe,
        param_distributions=param_distributions,
        n_iter=N_ITER,
        scoring=scoring,
        refit='rmse',
        cv=cv,
        n_jobs=-1,
        verbose=1,
        random_state=RANDOM_STATE,
        return_train_score=True,
    )

    search.fit(X_tune, y_tune)
    best_rmse = -float(search.best_score_)
    print('Best CV RMSE (orig scale):', best_rmse)
    print('Best params:')
    for k,v in sorted(search.best_params_.items()):
        print(' ', k, '=', v)

    best_model_cv = search.best_estimator_

    def to_orig(y):
        return np.expm1(y) if ('USE_LOG_TARGET' in globals() and USE_LOG_TARGET) else y

    def report_metrics(y_true, y_pred):
        yt, yp = to_orig(y_true), to_orig(y_pred)
        rmse = np.sqrt(mean_squared_error(yt, yp))
        mae = mean_absolute_error(yt, yp)
        r2 = r2_score(yt, yp)
        return {'RMSE': rmse, 'MAE': mae, 'R2': r2}

    y_val_pred_cv = best_model_cv.predict(X_val)
    y_test_pred_cv = best_model_cv.predict(X_test)
    print('Val metrics (CV-best pipeline, orig scale):', report_metrics(y_val, y_val_pred_cv))
    print('Test metrics (CV-best pipeline, orig scale):', report_metrics(y_test, y_test_pred_cv))

    tuned = {k.split('__',1)[1]: v for k,v in search.best_params_.items() if k.startswith('model__')}
    xgb_tuned = XGBRegressor(
        **tuned,
        objective='reg:squarederror',
        tree_method='hist',
        random_state=RANDOM_STATE,
        n_jobs=-1,
        eval_metric='rmse',
    )
    fit_sig = inspect.signature(XGBRegressor().fit)
    supports_callbacks = 'callbacks' in fit_sig.parameters
    supports_esr = 'early_stopping_rounds' in fit_sig.parameters
    fit_kwargs = {'eval_set': [(X_val_t, y_val)]}
    if supports_callbacks and 'XGB_EarlyStopping' in globals() and XGB_EarlyStopping is not None:
        fit_kwargs['callbacks'] = [XGB_EarlyStopping(rounds=100, save_best=True, maximize=False)]
    elif supports_esr:
        fit_kwargs['early_stopping_rounds'] = 100
    xgb_tuned.fit(X_train_t, y_train, **fit_kwargs)

    xgb = xgb_tuned
    print('Refit tuned model; best_iteration (if any):', getattr(xgb, 'best_iteration', None))
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best CV RMSE (orig scale): 105.12671468058625
# Best params:
#   model__colsample_bylevel = 0.6472328797709588
#   model__colsample_bynode = 0.9742266534810784
#   model__colsample_bytree = 0.8818028970798804
#   model__gamma = 0.0036345672005817925
#   model__grow_policy = lossguide
#   model__learning_rate = 0.013537960416471642
#   model__max_bin = 122
#   model__max_depth = 8
#   model__max_leaves = 88
#   model__min_child_weight = 1
#   model__n_estimators = 1538
#   model__reg_alpha = 0.03649961465472347
#   model__reg_lambda = 1.6790391887609275
#   model__subsample = 0.8494229265804523
# Val metrics (CV-best pipeline, orig scale): {'RMSE': np.float64(97.816744954836), 'MAE': 61.691339304391605, 'R2': 0.7656577187432058}
# Test metrics (CV-best pipeline, orig scale): {'RMSE': np.float64(103.45009409204232), 'MAE': 64.16408502947266, 'R2': 0.752405450515875}
# [0]	validation_0-rmse:0.30363
# [1]	validation_0-rmse:0.30101
# [2]	validation_0-rmse:0.29892
# [3]	validation_0-rmse:0.29643
# [4]	validation_0-rmse:0.29384
# [5]	validation_0-rmse:0.29163
# [6]	validation_0-rmse:0.28914
# [7]	validation_0-rmse:0.28701
# [8]	validation_0-rmse:0.28476
# [9]	validation_0-rmse:0.28243
# [10]	validation_0-rmse:0.28012
# [11]	validation_0-rmse:0.27778
# [12]	validation_0-rmse:0.27569
# [13]	validation_0-rmse:0.27347
# [14]	validation_0-rmse:0.27128
# [15]	validation_0-rmse:0.26936
# [16]	validation_0-rmse:0.26736
# [17]	validation_0-rmse:0.26527
# [18]	validation_0-rmse:0.26330
# [19]	validation_0-rmse:0.26135
# [20]	validation_0-rmse:0.25939
# [21]	validation_0-rmse:0.25761
# [22]	validation_0-rmse:0.25591
# [23]	validation_0-rmse:0.25425
# [24]	validation_0-rmse:0.25240
# [25]	validation_0-rmse:0.25064
# [26]	validation_0-rmse:0.24901
# [27]	validation_0-rmse:0.24724
# [28]	validation_0-rmse:0.24549
# [29]	validation_0-rmse:0.24393
# [30]	validation_0-rmse:0.24231
# [31]	validation_0-rmse:0.24060
# [32]	validation_0-rmse:0.23901
# [33]	validation_0-rmse:0.23741
# [34]	validation_0-rmse:0.23588
# [35]	validation_0-rmse:0.23437
# [36]	validation_0-rmse:0.23290
# [37]	validation_0-rmse:0.23142
# [38]	validation_0-rmse:0.23048
# [39]	validation_0-rmse:0.22904
# [40]	validation_0-rmse:0.22764
# [41]	validation_0-rmse:0.22635
# [42]	validation_0-rmse:0.22498
# [43]	validation_0-rmse:0.22362
# [44]	validation_0-rmse:0.22230
# [45]	validation_0-rmse:0.22103
# [46]	validation_0-rmse:0.21976
# [47]	validation_0-rmse:0.21870
# [48]	validation_0-rmse:0.21780
# [49]	validation_0-rmse:0.21667
# [50]	validation_0-rmse:0.21547
# [51]	validation_0-rmse:0.21462
# [52]	validation_0-rmse:0.21355
# [53]	validation_0-rmse:0.21241
# [54]	validation_0-rmse:0.21126
# [55]	validation_0-rmse:0.21021
# [56]	validation_0-rmse:0.20916
# [57]	validation_0-rmse:0.20808
# [58]	validation_0-rmse:0.20703
# [59]	validation_0-rmse:0.20610
# [60]	validation_0-rmse:0.20512
# [61]	validation_0-rmse:0.20418
# [62]	validation_0-rmse:0.20320
# [63]	validation_0-rmse:0.20239
# [64]	validation_0-rmse:0.20144
# [65]	validation_0-rmse:0.20051
# [66]	validation_0-rmse:0.19967
# [67]	validation_0-rmse:0.19875
# [68]	validation_0-rmse:0.19787
# [69]	validation_0-rmse:0.19703
# [70]	validation_0-rmse:0.19624
# [71]	validation_0-rmse:0.19539
# [72]	validation_0-rmse:0.19465
# [73]	validation_0-rmse:0.19393
# [74]	validation_0-rmse:0.19314
# [75]	validation_0-rmse:0.19235
# [76]	validation_0-rmse:0.19166
# [77]	validation_0-rmse:0.19091
# [78]	validation_0-rmse:0.19019
# [79]	validation_0-rmse:0.18947
# [80]	validation_0-rmse:0.18876
# [81]	validation_0-rmse:0.18809
# [82]	validation_0-rmse:0.18747
# [83]	validation_0-rmse:0.18685
# [84]	validation_0-rmse:0.18625
# [85]	validation_0-rmse:0.18562
# [86]	validation_0-rmse:0.18497
# [87]	validation_0-rmse:0.18441
# [88]	validation_0-rmse:0.18380
# [89]	validation_0-rmse:0.18319
# [90]	validation_0-rmse:0.18263
# [91]	validation_0-rmse:0.18208
# [92]	validation_0-rmse:0.18157
# [93]	validation_0-rmse:0.18105
# [94]	validation_0-rmse:0.18052
# [95]	validation_0-rmse:0.17996
# [96]	validation_0-rmse:0.17945
# [97]	validation_0-rmse:0.17898
# [98]	validation_0-rmse:0.17847
# [99]	validation_0-rmse:0.17795
# [100]	validation_0-rmse:0.17744
# [101]	validation_0-rmse:0.17693
# [102]	validation_0-rmse:0.17642
# [103]	validation_0-rmse:0.17593
# [104]	validation_0-rmse:0.17551
# [105]	validation_0-rmse:0.17506
# [106]	validation_0-rmse:0.17465
# [107]	validation_0-rmse:0.17419
# [108]	validation_0-rmse:0.17375
# [109]	validation_0-rmse:0.17333
# [110]	validation_0-rmse:0.17294
# [111]	validation_0-rmse:0.17257
# [112]	validation_0-rmse:0.17220
# [113]	validation_0-rmse:0.17184
# [114]	validation_0-rmse:0.17145
# [115]	validation_0-rmse:0.17108
# [116]	validation_0-rmse:0.17070
# [117]	validation_0-rmse:0.17034
# [118]	validation_0-rmse:0.16999
# [119]	validation_0-rmse:0.16964
# [120]	validation_0-rmse:0.16932
# [121]	validation_0-rmse:0.16896
# [122]	validation_0-rmse:0.16860
# [123]	validation_0-rmse:0.16827
# [124]	validation_0-rmse:0.16795
# [125]	validation_0-rmse:0.16768
# [126]	validation_0-rmse:0.16733
# [127]	validation_0-rmse:0.16703
# [128]	validation_0-rmse:0.16674
# [129]	validation_0-rmse:0.16645
# [130]	validation_0-rmse:0.16615
# [131]	validation_0-rmse:0.16586
# [132]	validation_0-rmse:0.16564
# [133]	validation_0-rmse:0.16540
# [134]	validation_0-rmse:0.16513
# [135]	validation_0-rmse:0.16486
# [136]	validation_0-rmse:0.16459
# [137]	validation_0-rmse:0.16434
# [138]	validation_0-rmse:0.16406
# [139]	validation_0-rmse:0.16386
# [140]	validation_0-rmse:0.16360
# [141]	validation_0-rmse:0.16336
# [142]	validation_0-rmse:0.16310
# [143]	validation_0-rmse:0.16289
# [144]	validation_0-rmse:0.16264
# [145]	validation_0-rmse:0.16243
# [146]	validation_0-rmse:0.16223
# [147]	validation_0-rmse:0.16202
# [148]	validation_0-rmse:0.16184
# [149]	validation_0-rmse:0.16163
# [150]	validation_0-rmse:0.16138
# [151]	validation_0-rmse:0.16117
# [152]	validation_0-rmse:0.16097
# [153]	validation_0-rmse:0.16075
# [154]	validation_0-rmse:0.16056
# [155]	validation_0-rmse:0.16037
# [156]	validation_0-rmse:0.16020
# [157]	validation_0-rmse:0.16001
# [158]	validation_0-rmse:0.15982
# [159]	validation_0-rmse:0.15963
# [160]	validation_0-rmse:0.15947
# [161]	validation_0-rmse:0.15930
# [162]	validation_0-rmse:0.15913
# [163]	validation_0-rmse:0.15899
# [164]	validation_0-rmse:0.15883
# [165]	validation_0-rmse:0.15867
# [166]	validation_0-rmse:0.15851
# [167]	validation_0-rmse:0.15835
# [168]	validation_0-rmse:0.15823
# [169]	validation_0-rmse:0.15808
# [170]	validation_0-rmse:0.15791
# [171]	validation_0-rmse:0.15772
# [172]	validation_0-rmse:0.15755
# [173]	validation_0-rmse:0.15744
# [174]	validation_0-rmse:0.15729
# [175]	validation_0-rmse:0.15714
# [176]	validation_0-rmse:0.15698
# [177]	validation_0-rmse:0.15683
# [178]	validation_0-rmse:0.15668
# [179]	validation_0-rmse:0.15654
# [180]	validation_0-rmse:0.15639
# [181]	validation_0-rmse:0.15628
# [182]	validation_0-rmse:0.15617
# [183]	validation_0-rmse:0.15607
# [184]	validation_0-rmse:0.15596
# [185]	validation_0-rmse:0.15587
# [186]	validation_0-rmse:0.15575
# [187]	validation_0-rmse:0.15566
# [188]	validation_0-rmse:0.15554
# [189]	validation_0-rmse:0.15543
# [190]	validation_0-rmse:0.15532
# [191]	validation_0-rmse:0.15525
# [192]	validation_0-rmse:0.15516
# [193]	validation_0-rmse:0.15505
# [194]	validation_0-rmse:0.15494
# [195]	validation_0-rmse:0.15485
# [196]	validation_0-rmse:0.15475
# [197]	validation_0-rmse:0.15465
# [198]	validation_0-rmse:0.15455
# [199]	validation_0-rmse:0.15445
# [200]	validation_0-rmse:0.15437
# [201]	validation_0-rmse:0.15427
# [202]	validation_0-rmse:0.15418
# [203]	validation_0-rmse:0.15409
# [204]	validation_0-rmse:0.15401
# [205]	validation_0-rmse:0.15392
# [206]	validation_0-rmse:0.15383
# [207]	validation_0-rmse:0.15373
# [208]	validation_0-rmse:0.15364
# [209]	validation_0-rmse:0.15355
# [210]	validation_0-rmse:0.15345
# [211]	validation_0-rmse:0.15333
# [212]	validation_0-rmse:0.15324
# [213]	validation_0-rmse:0.15315
# [214]	validation_0-rmse:0.15308
# [215]	validation_0-rmse:0.15299
# [216]	validation_0-rmse:0.15292
# [217]	validation_0-rmse:0.15284
# [218]	validation_0-rmse:0.15276
# [219]	validation_0-rmse:0.15267
# [220]	validation_0-rmse:0.15260
# [221]	validation_0-rmse:0.15252
# [222]	validation_0-rmse:0.15245
# [223]	validation_0-rmse:0.15237
# [224]	validation_0-rmse:0.15229
# [225]	validation_0-rmse:0.15221
# [226]	validation_0-rmse:0.15215
# [227]	validation_0-rmse:0.15208
# [228]	validation_0-rmse:0.15201
# [229]	validation_0-rmse:0.15193
# [230]	validation_0-rmse:0.15187
# [231]	validation_0-rmse:0.15179
# [232]	validation_0-rmse:0.15172
# [233]	validation_0-rmse:0.15164
# [234]	validation_0-rmse:0.15159
# [235]	validation_0-rmse:0.15149
# [236]	validation_0-rmse:0.15143
# [237]	validation_0-rmse:0.15137
# [238]	validation_0-rmse:0.15131
# [239]	validation_0-rmse:0.15125
# [240]	validation_0-rmse:0.15120
# [241]	validation_0-rmse:0.15114
# [242]	validation_0-rmse:0.15108
# [243]	validation_0-rmse:0.15100
# [244]	validation_0-rmse:0.15094
# [245]	validation_0-rmse:0.15087
# [246]	validation_0-rmse:0.15082
# [247]	validation_0-rmse:0.15077
# [248]	validation_0-rmse:0.15073
# [249]	validation_0-rmse:0.15067
# [250]	validation_0-rmse:0.15062
# [251]	validation_0-rmse:0.15057
# [252]	validation_0-rmse:0.15052
# [253]	validation_0-rmse:0.15046
# [254]	validation_0-rmse:0.15040
# [255]	validation_0-rmse:0.15035
# [256]	validation_0-rmse:0.15028
# [257]	validation_0-rmse:0.15022
# [258]	validation_0-rmse:0.15018
# [259]	validation_0-rmse:0.15011
# [260]	validation_0-rmse:0.15004
# [261]	validation_0-rmse:0.14998
# [262]	validation_0-rmse:0.14994
# [263]	validation_0-rmse:0.14988
# [264]	validation_0-rmse:0.14983
# [265]	validation_0-rmse:0.14978
# [266]	validation_0-rmse:0.14973
# [267]	validation_0-rmse:0.14968
# [268]	validation_0-rmse:0.14961
# [269]	validation_0-rmse:0.14955
# [270]	validation_0-rmse:0.14951
# [271]	validation_0-rmse:0.14943
# [272]	validation_0-rmse:0.14939
# [273]	validation_0-rmse:0.14934
# [274]	validation_0-rmse:0.14930
# [275]	validation_0-rmse:0.14925
# [276]	validation_0-rmse:0.14923
# [277]	validation_0-rmse:0.14921
# [278]	validation_0-rmse:0.14916
# [279]	validation_0-rmse:0.14911
# [280]	validation_0-rmse:0.14908
# [281]	validation_0-rmse:0.14903
# [282]	validation_0-rmse:0.14898
# [283]	validation_0-rmse:0.14894
# [284]	validation_0-rmse:0.14889
# [285]	validation_0-rmse:0.14885
# [286]	validation_0-rmse:0.14879
# [287]	validation_0-rmse:0.14874
# [288]	validation_0-rmse:0.14871
# [289]	validation_0-rmse:0.14867
# [290]	validation_0-rmse:0.14863
# [291]	validation_0-rmse:0.14859
# [292]	validation_0-rmse:0.14855
# [293]	validation_0-rmse:0.14851
# [294]	validation_0-rmse:0.14849
# [295]	validation_0-rmse:0.14841
# [296]	validation_0-rmse:0.14836
# [297]	validation_0-rmse:0.14832
# [298]	validation_0-rmse:0.14830
# [299]	validation_0-rmse:0.14826
# [300]	validation_0-rmse:0.14823
# [301]	validation_0-rmse:0.14820
# [302]	validation_0-rmse:0.14817
# [303]	validation_0-rmse:0.14812
# [304]	validation_0-rmse:0.14810
# [305]	validation_0-rmse:0.14806
# [306]	validation_0-rmse:0.14802
# [307]	validation_0-rmse:0.14800
# [308]	validation_0-rmse:0.14796
# [309]	validation_0-rmse:0.14791
# [310]	validation_0-rmse:0.14787
# [311]	validation_0-rmse:0.14785
# [312]	validation_0-rmse:0.14781
# [313]	validation_0-rmse:0.14777
# [314]	validation_0-rmse:0.14774
# [315]	validation_0-rmse:0.14771
# [316]	validation_0-rmse:0.14766
# [317]	validation_0-rmse:0.14764
# [318]	validation_0-rmse:0.14760
# [319]	validation_0-rmse:0.14756
# [320]	validation_0-rmse:0.14753
# [321]	validation_0-rmse:0.14750
# [322]	validation_0-rmse:0.14747
# [323]	validation_0-rmse:0.14744
# [324]	validation_0-rmse:0.14740
# [325]	validation_0-rmse:0.14737
# [326]	validation_0-rmse:0.14734
# [327]	validation_0-rmse:0.14730
# [328]	validation_0-rmse:0.14723
# [329]	validation_0-rmse:0.14718
# [330]	validation_0-rmse:0.14715
# [331]	validation_0-rmse:0.14711
# [332]	validation_0-rmse:0.14708
# [333]	validation_0-rmse:0.14707
# [334]	validation_0-rmse:0.14705
# [335]	validation_0-rmse:0.14702
# [336]	validation_0-rmse:0.14699
# [337]	validation_0-rmse:0.14696
# [338]	validation_0-rmse:0.14693
# [339]	validation_0-rmse:0.14691
# [340]	validation_0-rmse:0.14688
# [341]	validation_0-rmse:0.14684
# [342]	validation_0-rmse:0.14680
# [343]	validation_0-rmse:0.14677
# [344]	validation_0-rmse:0.14676
# [345]	validation_0-rmse:0.14673
# [346]	validation_0-rmse:0.14670
# [347]	validation_0-rmse:0.14668
# [348]	validation_0-rmse:0.14666
# [349]	validation_0-rmse:0.14663
# [350]	validation_0-rmse:0.14658
# [351]	validation_0-rmse:0.14656
# [352]	validation_0-rmse:0.14653
# [353]	validation_0-rmse:0.14650
# [354]	validation_0-rmse:0.14646
# [355]	validation_0-rmse:0.14644
# [356]	validation_0-rmse:0.14642
# [357]	validation_0-rmse:0.14641
# [358]	validation_0-rmse:0.14641
# [359]	validation_0-rmse:0.14638
# [360]	validation_0-rmse:0.14635
# [361]	validation_0-rmse:0.14634
# [362]	validation_0-rmse:0.14631
# [363]	validation_0-rmse:0.14629
# [364]	validation_0-rmse:0.14626
# [365]	validation_0-rmse:0.14623
# [366]	validation_0-rmse:0.14623
# [367]	validation_0-rmse:0.14621
# [368]	validation_0-rmse:0.14619
# [369]	validation_0-rmse:0.14616
# [370]	validation_0-rmse:0.14614
# [371]	validation_0-rmse:0.14611
# [372]	validation_0-rmse:0.14609
# [373]	validation_0-rmse:0.14605
# [374]	validation_0-rmse:0.14602
# [375]	validation_0-rmse:0.14601
# [376]	validation_0-rmse:0.14599
# [377]	validation_0-rmse:0.14596
# [378]	validation_0-rmse:0.14595
# [379]	validation_0-rmse:0.14594
# [380]	validation_0-rmse:0.14592
# [381]	validation_0-rmse:0.14591
# [382]	validation_0-rmse:0.14590
# [383]	validation_0-rmse:0.14586
# [384]	validation_0-rmse:0.14585
# [385]	validation_0-rmse:0.14583
# [386]	validation_0-rmse:0.14582
# [387]	validation_0-rmse:0.14579
# [388]	validation_0-rmse:0.14578
# [389]	validation_0-rmse:0.14575
# [390]	validation_0-rmse:0.14573
# [391]	validation_0-rmse:0.14571
# [392]	validation_0-rmse:0.14569
# [393]	validation_0-rmse:0.14568
# [394]	validation_0-rmse:0.14565
# [395]	validation_0-rmse:0.14563
# [396]	validation_0-rmse:0.14562
# [397]	validation_0-rmse:0.14560
# [398]	validation_0-rmse:0.14559
# [399]	validation_0-rmse:0.14558
# [400]	validation_0-rmse:0.14558
# [401]	validation_0-rmse:0.14556
# [402]	validation_0-rmse:0.14553
# [403]	validation_0-rmse:0.14549
# [404]	validation_0-rmse:0.14546
# [405]	validation_0-rmse:0.14545
# [406]	validation_0-rmse:0.14541
# [407]	validation_0-rmse:0.14538
# [408]	validation_0-rmse:0.14536
# [409]	validation_0-rmse:0.14534
# [410]	validation_0-rmse:0.14532
# [411]	validation_0-rmse:0.14531
# [412]	validation_0-rmse:0.14528
# [413]	validation_0-rmse:0.14526
# [414]	validation_0-rmse:0.14525
# [415]	validation_0-rmse:0.14524
# [416]	validation_0-rmse:0.14522
# [417]	validation_0-rmse:0.14521
# [418]	validation_0-rmse:0.14519
# [419]	validation_0-rmse:0.14518
# [420]	validation_0-rmse:0.14515
# [421]	validation_0-rmse:0.14513
# [422]	validation_0-rmse:0.14512
# [423]	validation_0-rmse:0.14509
# [424]	validation_0-rmse:0.14507
# [425]	validation_0-rmse:0.14504
# [426]	validation_0-rmse:0.14502
# [427]	validation_0-rmse:0.14499
# [428]	validation_0-rmse:0.14496
# [429]	validation_0-rmse:0.14493
# [430]	validation_0-rmse:0.14491
# [431]	validation_0-rmse:0.14490
# [432]	validation_0-rmse:0.14487
# [433]	validation_0-rmse:0.14486
# [434]	validation_0-rmse:0.14484
# [435]	validation_0-rmse:0.14482
# [436]	validation_0-rmse:0.14481
# [437]	validation_0-rmse:0.14480
# [438]	validation_0-rmse:0.14479
# [439]	validation_0-rmse:0.14478
# [440]	validation_0-rmse:0.14476
# [441]	validation_0-rmse:0.14475
# [442]	validation_0-rmse:0.14473
# [443]	validation_0-rmse:0.14473
# [444]	validation_0-rmse:0.14471
# [445]	validation_0-rmse:0.14468
# [446]	validation_0-rmse:0.14467
# [447]	validation_0-rmse:0.14465
# [448]	validation_0-rmse:0.14462
# [449]	validation_0-rmse:0.14460
# [450]	validation_0-rmse:0.14459
# [451]	validation_0-rmse:0.14456
# [452]	validation_0-rmse:0.14453
# [453]	validation_0-rmse:0.14452
# [454]	validation_0-rmse:0.14451
# [455]	validation_0-rmse:0.14450
# [456]	validation_0-rmse:0.14449
# [457]	validation_0-rmse:0.14449
# [458]	validation_0-rmse:0.14447
# [459]	validation_0-rmse:0.14446
# [460]	validation_0-rmse:0.14445
# [461]	validation_0-rmse:0.14444
# [462]	validation_0-rmse:0.14442
# [463]	validation_0-rmse:0.14440
# [464]	validation_0-rmse:0.14438
# [465]	validation_0-rmse:0.14435
# [466]	validation_0-rmse:0.14434
# [467]	validation_0-rmse:0.14433
# [468]	validation_0-rmse:0.14433
# [469]	validation_0-rmse:0.14432
# [470]	validation_0-rmse:0.14430
# [471]	validation_0-rmse:0.14429
# [472]	validation_0-rmse:0.14428
# [473]	validation_0-rmse:0.14425
# [474]	validation_0-rmse:0.14423
# [475]	validation_0-rmse:0.14423
# [476]	validation_0-rmse:0.14420
# [477]	validation_0-rmse:0.14418
# [478]	validation_0-rmse:0.14416
# [479]	validation_0-rmse:0.14415
# [480]	validation_0-rmse:0.14414
# [481]	validation_0-rmse:0.14413
# [482]	validation_0-rmse:0.14412
# [483]	validation_0-rmse:0.14410
# [484]	validation_0-rmse:0.14408
# [485]	validation_0-rmse:0.14407
# [486]	validation_0-rmse:0.14406
# [487]	validation_0-rmse:0.14405
# [488]	validation_0-rmse:0.14405
# [489]	validation_0-rmse:0.14404
# [490]	validation_0-rmse:0.14402
# [491]	validation_0-rmse:0.14401
# [492]	validation_0-rmse:0.14400
# [493]	validation_0-rmse:0.14399
# [494]	validation_0-rmse:0.14398
# [495]	validation_0-rmse:0.14397
# [496]	validation_0-rmse:0.14397
# [497]	validation_0-rmse:0.14396
# [498]	validation_0-rmse:0.14395
# [499]	validation_0-rmse:0.14393
# [500]	validation_0-rmse:0.14391
# [501]	validation_0-rmse:0.14390
# [502]	validation_0-rmse:0.14388
# [503]	validation_0-rmse:0.14388
# [504]	validation_0-rmse:0.14387
# [505]	validation_0-rmse:0.14385
# [506]	validation_0-rmse:0.14384
# [507]	validation_0-rmse:0.14383
# [508]	validation_0-rmse:0.14381
# [509]	validation_0-rmse:0.14380
# [510]	validation_0-rmse:0.14378
# [511]	validation_0-rmse:0.14377
# [512]	validation_0-rmse:0.14376
# [513]	validation_0-rmse:0.14375
# [514]	validation_0-rmse:0.14374
# [515]	validation_0-rmse:0.14373
# [516]	validation_0-rmse:0.14372
# [517]	validation_0-rmse:0.14371
# [518]	validation_0-rmse:0.14369
# [519]	validation_0-rmse:0.14368
# [520]	validation_0-rmse:0.14367
# [521]	validation_0-rmse:0.14366
# [522]	validation_0-rmse:0.14365
# [523]	validation_0-rmse:0.14363
# [524]	validation_0-rmse:0.14363
# [525]	validation_0-rmse:0.14362
# [526]	validation_0-rmse:0.14361
# [527]	validation_0-rmse:0.14361
# [528]	validation_0-rmse:0.14359
# [529]	validation_0-rmse:0.14358
# [530]	validation_0-rmse:0.14358
# [531]	validation_0-rmse:0.14357
# [532]	validation_0-rmse:0.14355
# [533]	validation_0-rmse:0.14354
# [534]	validation_0-rmse:0.14352
# [535]	validation_0-rmse:0.14350
# [536]	validation_0-rmse:0.14348
# [537]	validation_0-rmse:0.14347
# [538]	validation_0-rmse:0.14346
# [539]	validation_0-rmse:0.14345
# [540]	validation_0-rmse:0.14344
# [541]	validation_0-rmse:0.14343
# [542]	validation_0-rmse:0.14341
# [543]	validation_0-rmse:0.14340
# [544]	validation_0-rmse:0.14338
# [545]	validation_0-rmse:0.14337
# [546]	validation_0-rmse:0.14337
# [547]	validation_0-rmse:0.14334
# [548]	validation_0-rmse:0.14334
# [549]	validation_0-rmse:0.14331
# [550]	validation_0-rmse:0.14331
# [551]	validation_0-rmse:0.14329
# [552]	validation_0-rmse:0.14328
# [553]	validation_0-rmse:0.14327
# [554]	validation_0-rmse:0.14326
# [555]	validation_0-rmse:0.14326
# [556]	validation_0-rmse:0.14325
# [557]	validation_0-rmse:0.14324
# [558]	validation_0-rmse:0.14322
# [559]	validation_0-rmse:0.14320
# [560]	validation_0-rmse:0.14319
# [561]	validation_0-rmse:0.14319
# [562]	validation_0-rmse:0.14318
# [563]	validation_0-rmse:0.14316
# [564]	validation_0-rmse:0.14315
# [565]	validation_0-rmse:0.14313
# [566]	validation_0-rmse:0.14313
# [567]	validation_0-rmse:0.14311
# [568]	validation_0-rmse:0.14310
# [569]	validation_0-rmse:0.14309
# [570]	validation_0-rmse:0.14307
# [571]	validation_0-rmse:0.14306
# [572]	validation_0-rmse:0.14305
# [573]	validation_0-rmse:0.14304
# [574]	validation_0-rmse:0.14302
# [575]	validation_0-rmse:0.14301
# [576]	validation_0-rmse:0.14300
# [577]	validation_0-rmse:0.14300
# [578]	validation_0-rmse:0.14300
# [579]	validation_0-rmse:0.14298
# [580]	validation_0-rmse:0.14296
# [581]	validation_0-rmse:0.14295
# [582]	validation_0-rmse:0.14294
# [583]	validation_0-rmse:0.14293
# [584]	validation_0-rmse:0.14292
# [585]	validation_0-rmse:0.14292
# [586]	validation_0-rmse:0.14290
# [587]	validation_0-rmse:0.14288
# [588]	validation_0-rmse:0.14287
# [589]	validation_0-rmse:0.14286
# [590]	validation_0-rmse:0.14285
# [591]	validation_0-rmse:0.14285
# [592]	validation_0-rmse:0.14284
# [593]	validation_0-rmse:0.14282
# [594]	validation_0-rmse:0.14283
# [595]	validation_0-rmse:0.14280
# [596]	validation_0-rmse:0.14279
# [597]	validation_0-rmse:0.14277
# [598]	validation_0-rmse:0.14276
# [599]	validation_0-rmse:0.14276
# [600]	validation_0-rmse:0.14274
# [601]	validation_0-rmse:0.14272
# [602]	validation_0-rmse:0.14271
# [603]	validation_0-rmse:0.14271
# [604]	validation_0-rmse:0.14269
# [605]	validation_0-rmse:0.14268
# [606]	validation_0-rmse:0.14268
# [607]	validation_0-rmse:0.14268
# [608]	validation_0-rmse:0.14267
# [609]	validation_0-rmse:0.14266
# [610]	validation_0-rmse:0.14266
# [611]	validation_0-rmse:0.14265
# [612]	validation_0-rmse:0.14263
# [613]	validation_0-rmse:0.14261
# [614]	validation_0-rmse:0.14260
# [615]	validation_0-rmse:0.14260
# [616]	validation_0-rmse:0.14259
# [617]	validation_0-rmse:0.14258
# [618]	validation_0-rmse:0.14257
# [619]	validation_0-rmse:0.14256
# [620]	validation_0-rmse:0.14255
# [621]	validation_0-rmse:0.14254
# [622]	validation_0-rmse:0.14254
# [623]	validation_0-rmse:0.14253
# [624]	validation_0-rmse:0.14252
# [625]	validation_0-rmse:0.14251
# [626]	validation_0-rmse:0.14250
# [627]	validation_0-rmse:0.14249
# [628]	validation_0-rmse:0.14248
# [629]	validation_0-rmse:0.14246
# [630]	validation_0-rmse:0.14245
# [631]	validation_0-rmse:0.14244
# [632]	validation_0-rmse:0.14243
# [633]	validation_0-rmse:0.14242
# [634]	validation_0-rmse:0.14240
# [635]	validation_0-rmse:0.14239
# [636]	validation_0-rmse:0.14238
# [637]	validation_0-rmse:0.14237
# [638]	validation_0-rmse:0.14237
# [639]	validation_0-rmse:0.14235
# [640]	validation_0-rmse:0.14234
# [641]	validation_0-rmse:0.14233
# [642]	validation_0-rmse:0.14232
# [643]	validation_0-rmse:0.14231
# [644]	validation_0-rmse:0.14230
# [645]	validation_0-rmse:0.14229
# [646]	validation_0-rmse:0.14228
# [647]	validation_0-rmse:0.14228
# [648]	validation_0-rmse:0.14227
# [649]	validation_0-rmse:0.14225
# [650]	validation_0-rmse:0.14224
# [651]	validation_0-rmse:0.14224
# [652]	validation_0-rmse:0.14223
# [653]	validation_0-rmse:0.14223
# [654]	validation_0-rmse:0.14221
# [655]	validation_0-rmse:0.14221
# [656]	validation_0-rmse:0.14220
# [657]	validation_0-rmse:0.14218
# [658]	validation_0-rmse:0.14218
# [659]	validation_0-rmse:0.14217
# [660]	validation_0-rmse:0.14215
# [661]	validation_0-rmse:0.14214
# [662]	validation_0-rmse:0.14213
# [663]	validation_0-rmse:0.14213
# [664]	validation_0-rmse:0.14213
# [665]	validation_0-rmse:0.14212
# [666]	validation_0-rmse:0.14211
# [667]	validation_0-rmse:0.14210
# [668]	validation_0-rmse:0.14210
# [669]	validation_0-rmse:0.14209
# [670]	validation_0-rmse:0.14208
# [671]	validation_0-rmse:0.14206
# [672]	validation_0-rmse:0.14206
# [673]	validation_0-rmse:0.14206
# [674]	validation_0-rmse:0.14205
# [675]	validation_0-rmse:0.14204
# [676]	validation_0-rmse:0.14203
# [677]	validation_0-rmse:0.14204
# [678]	validation_0-rmse:0.14203
# [679]	validation_0-rmse:0.14202
# [680]	validation_0-rmse:0.14201
# [681]	validation_0-rmse:0.14200
# [682]	validation_0-rmse:0.14199
# [683]	validation_0-rmse:0.14198
# [684]	validation_0-rmse:0.14197
# [685]	validation_0-rmse:0.14196
# [686]	validation_0-rmse:0.14194
# [687]	validation_0-rmse:0.14194
# [688]	validation_0-rmse:0.14193
# [689]	validation_0-rmse:0.14192
# [690]	validation_0-rmse:0.14191
# [691]	validation_0-rmse:0.14189
# [692]	validation_0-rmse:0.14188
# [693]	validation_0-rmse:0.14187
# [694]	validation_0-rmse:0.14185
# [695]	validation_0-rmse:0.14184
# [696]	validation_0-rmse:0.14183
# [697]	validation_0-rmse:0.14182
# [698]	validation_0-rmse:0.14181
# [699]	validation_0-rmse:0.14180
# [700]	validation_0-rmse:0.14179
# [701]	validation_0-rmse:0.14179
# [702]	validation_0-rmse:0.14179
# [703]	validation_0-rmse:0.14179
# [704]	validation_0-rmse:0.14178
# [705]	validation_0-rmse:0.14178
# [706]	validation_0-rmse:0.14177
# [707]	validation_0-rmse:0.14175
# [708]	validation_0-rmse:0.14175
# [709]	validation_0-rmse:0.14173
# [710]	validation_0-rmse:0.14172
# [711]	validation_0-rmse:0.14171
# [712]	validation_0-rmse:0.14170
# [713]	validation_0-rmse:0.14169
# [714]	validation_0-rmse:0.14168
# [715]	validation_0-rmse:0.14168
# [716]	validation_0-rmse:0.14167
# [717]	validation_0-rmse:0.14166
# [718]	validation_0-rmse:0.14165
# [719]	validation_0-rmse:0.14164
# [720]	validation_0-rmse:0.14163
# [721]	validation_0-rmse:0.14162
# [722]	validation_0-rmse:0.14161
# [723]	validation_0-rmse:0.14161
# [724]	validation_0-rmse:0.14161
# [725]	validation_0-rmse:0.14160
# [726]	validation_0-rmse:0.14160
# [727]	validation_0-rmse:0.14159
# [728]	validation_0-rmse:0.14158
# [729]	validation_0-rmse:0.14156
# [730]	validation_0-rmse:0.14156
# [731]	validation_0-rmse:0.14155
# [732]	validation_0-rmse:0.14155
# [733]	validation_0-rmse:0.14153
# [734]	validation_0-rmse:0.14152
# [735]	validation_0-rmse:0.14151
# [736]	validation_0-rmse:0.14151
# [737]	validation_0-rmse:0.14150
# [738]	validation_0-rmse:0.14149
# [739]	validation_0-rmse:0.14149
# [740]	validation_0-rmse:0.14148
# [741]	validation_0-rmse:0.14148
# [742]	validation_0-rmse:0.14147
# [743]	validation_0-rmse:0.14147
# [744]	validation_0-rmse:0.14146
# [745]	validation_0-rmse:0.14144
# [746]	validation_0-rmse:0.14144
# [747]	validation_0-rmse:0.14143
# [748]	validation_0-rmse:0.14142
# [749]	validation_0-rmse:0.14141
# [750]	validation_0-rmse:0.14141
# [751]	validation_0-rmse:0.14141
# [752]	validation_0-rmse:0.14140
# [753]	validation_0-rmse:0.14138
# [754]	validation_0-rmse:0.14138
# [755]	validation_0-rmse:0.14137
# [756]	validation_0-rmse:0.14137
# [757]	validation_0-rmse:0.14136
# [758]	validation_0-rmse:0.14136
# [759]	validation_0-rmse:0.14136
# [760]	validation_0-rmse:0.14135
# [761]	validation_0-rmse:0.14134
# [762]	validation_0-rmse:0.14134
# [763]	validation_0-rmse:0.14133
# [764]	validation_0-rmse:0.14133
# [765]	validation_0-rmse:0.14132
# [766]	validation_0-rmse:0.14131
# [767]	validation_0-rmse:0.14131
# [768]	validation_0-rmse:0.14130
# [769]	validation_0-rmse:0.14131
# [770]	validation_0-rmse:0.14131
# [771]	validation_0-rmse:0.14131
# [772]	validation_0-rmse:0.14130
# [773]	validation_0-rmse:0.14130
# [774]	validation_0-rmse:0.14130
# [775]	validation_0-rmse:0.14130
# [776]	validation_0-rmse:0.14129
# [777]	validation_0-rmse:0.14128
# [778]	validation_0-rmse:0.14127
# [779]	validation_0-rmse:0.14128
# [780]	validation_0-rmse:0.14127
# [781]	validation_0-rmse:0.14127
# [782]	validation_0-rmse:0.14127
# [783]	validation_0-rmse:0.14127
# [784]	validation_0-rmse:0.14126
# [785]	validation_0-rmse:0.14125
# [786]	validation_0-rmse:0.14124
# [787]	validation_0-rmse:0.14124
# [788]	validation_0-rmse:0.14124
# [789]	validation_0-rmse:0.14123
# [790]	validation_0-rmse:0.14123
# [791]	validation_0-rmse:0.14122
# [792]	validation_0-rmse:0.14121
# [793]	validation_0-rmse:0.14120
# [794]	validation_0-rmse:0.14119
# [795]	validation_0-rmse:0.14119
# [796]	validation_0-rmse:0.14119
# [797]	validation_0-rmse:0.14119
# [798]	validation_0-rmse:0.14118
# [799]	validation_0-rmse:0.14116
# [800]	validation_0-rmse:0.14116
# [801]	validation_0-rmse:0.14115
# [802]	validation_0-rmse:0.14114
# [803]	validation_0-rmse:0.14113
# [804]	validation_0-rmse:0.14113
# [805]	validation_0-rmse:0.14113
# [806]	validation_0-rmse:0.14113
# [807]	validation_0-rmse:0.14111
# [808]	validation_0-rmse:0.14110
# [809]	validation_0-rmse:0.14110
# [810]	validation_0-rmse:0.14109
# [811]	validation_0-rmse:0.14109
# [812]	validation_0-rmse:0.14109
# [813]	validation_0-rmse:0.14107
# [814]	validation_0-rmse:0.14107
# [815]	validation_0-rmse:0.14106
# [816]	validation_0-rmse:0.14106
# [817]	validation_0-rmse:0.14106
# [818]	validation_0-rmse:0.14106
# [819]	validation_0-rmse:0.14105
# [820]	validation_0-rmse:0.14105
# [821]	validation_0-rmse:0.14104
# [822]	validation_0-rmse:0.14105
# [823]	validation_0-rmse:0.14105
# [824]	validation_0-rmse:0.14104
# [825]	validation_0-rmse:0.14103
# [826]	validation_0-rmse:0.14103
# [827]	validation_0-rmse:0.14103
# [828]	validation_0-rmse:0.14102
# [829]	validation_0-rmse:0.14101
# [830]	validation_0-rmse:0.14100
# [831]	validation_0-rmse:0.14100
# [832]	validation_0-rmse:0.14099
# [833]	validation_0-rmse:0.14099
# [834]	validation_0-rmse:0.14099
# [835]	validation_0-rmse:0.14098
# [836]	validation_0-rmse:0.14097
# [837]	validation_0-rmse:0.14095
# [838]	validation_0-rmse:0.14096
# [839]	validation_0-rmse:0.14094
# [840]	validation_0-rmse:0.14094
# [841]	validation_0-rmse:0.14094
# [842]	validation_0-rmse:0.14093
# [843]	validation_0-rmse:0.14093
# [844]	validation_0-rmse:0.14093
# [845]	validation_0-rmse:0.14092
# [846]	validation_0-rmse:0.14091
# [847]	validation_0-rmse:0.14090
# [848]	validation_0-rmse:0.14090
# [849]	validation_0-rmse:0.14090
# [850]	validation_0-rmse:0.14089
# [851]	validation_0-rmse:0.14090
# [852]	validation_0-rmse:0.14089
# [853]	validation_0-rmse:0.14088
# [854]	validation_0-rmse:0.14087
# [855]	validation_0-rmse:0.14087
# [856]	validation_0-rmse:0.14086
# [857]	validation_0-rmse:0.14085
# [858]	validation_0-rmse:0.14085
# [859]	validation_0-rmse:0.14084
# [860]	validation_0-rmse:0.14083
# [861]	validation_0-rmse:0.14083
# [862]	validation_0-rmse:0.14083
# [863]	validation_0-rmse:0.14082
# [864]	validation_0-rmse:0.14082
# [865]	validation_0-rmse:0.14081
# [866]	validation_0-rmse:0.14081
# [867]	validation_0-rmse:0.14080
# [868]	validation_0-rmse:0.14080
# [869]	validation_0-rmse:0.14079
# [870]	validation_0-rmse:0.14080
# [871]	validation_0-rmse:0.14079
# [872]	validation_0-rmse:0.14079
# [873]	validation_0-rmse:0.14079
# [874]	validation_0-rmse:0.14078
# [875]	validation_0-rmse:0.14078
# [876]	validation_0-rmse:0.14077
# [877]	validation_0-rmse:0.14076
# [878]	validation_0-rmse:0.14075
# [879]	validation_0-rmse:0.14074
# [880]	validation_0-rmse:0.14074
# [881]	validation_0-rmse:0.14074
# [882]	validation_0-rmse:0.14073
# [883]	validation_0-rmse:0.14074
# [884]	validation_0-rmse:0.14073
# [885]	validation_0-rmse:0.14072
# [886]	validation_0-rmse:0.14072
# [887]	validation_0-rmse:0.14071
# [888]	validation_0-rmse:0.14071
# [889]	validation_0-rmse:0.14071
# [890]	validation_0-rmse:0.14069
# [891]	validation_0-rmse:0.14069
# [892]	validation_0-rmse:0.14068
# [893]	validation_0-rmse:0.14067
# [894]	validation_0-rmse:0.14066
# [895]	validation_0-rmse:0.14066
# [896]	validation_0-rmse:0.14066
# [897]	validation_0-rmse:0.14066
# [898]	validation_0-rmse:0.14066
# [899]	validation_0-rmse:0.14064
# [900]	validation_0-rmse:0.14064
# [901]	validation_0-rmse:0.14064
# [902]	validation_0-rmse:0.14063
# [903]	validation_0-rmse:0.14063
# [904]	validation_0-rmse:0.14063
# [905]	validation_0-rmse:0.14063
# [906]	validation_0-rmse:0.14064
# [907]	validation_0-rmse:0.14063
# [908]	validation_0-rmse:0.14062
# [909]	validation_0-rmse:0.14061
# [910]	validation_0-rmse:0.14060
# [911]	validation_0-rmse:0.14060
# [912]	validation_0-rmse:0.14059
# [913]	validation_0-rmse:0.14059
# [914]	validation_0-rmse:0.14059
# [915]	validation_0-rmse:0.14058
# [916]	validation_0-rmse:0.14058
# [917]	validation_0-rmse:0.14057
# [918]	validation_0-rmse:0.14057
# [919]	validation_0-rmse:0.14057
# [920]	validation_0-rmse:0.14056
# [921]	validation_0-rmse:0.14056
# [922]	validation_0-rmse:0.14055
# [923]	validation_0-rmse:0.14055
# [924]	validation_0-rmse:0.14055
# [925]	validation_0-rmse:0.14055
# [926]	validation_0-rmse:0.14053
# [927]	validation_0-rmse:0.14053
# [928]	validation_0-rmse:0.14052
# [929]	validation_0-rmse:0.14052
# [930]	validation_0-rmse:0.14051
# [931]	validation_0-rmse:0.14050
# [932]	validation_0-rmse:0.14050
# [933]	validation_0-rmse:0.14050
# [934]	validation_0-rmse:0.14050
# [935]	validation_0-rmse:0.14050
# [936]	validation_0-rmse:0.14050
# [937]	validation_0-rmse:0.14049
# [938]	validation_0-rmse:0.14049
# [939]	validation_0-rmse:0.14049
# [940]	validation_0-rmse:0.14048
# [941]	validation_0-rmse:0.14048
# [942]	validation_0-rmse:0.14047
# [943]	validation_0-rmse:0.14047
# [944]	validation_0-rmse:0.14047
# [945]	validation_0-rmse:0.14046
# [946]	validation_0-rmse:0.14046
# [947]	validation_0-rmse:0.14046
# [948]	validation_0-rmse:0.14046
# [949]	validation_0-rmse:0.14045
# [950]	validation_0-rmse:0.14044
# [951]	validation_0-rmse:0.14045
# [952]	validation_0-rmse:0.14044
# [953]	validation_0-rmse:0.14043
# [954]	validation_0-rmse:0.14043
# [955]	validation_0-rmse:0.14043
# [956]	validation_0-rmse:0.14043
# [957]	validation_0-rmse:0.14042
# [958]	validation_0-rmse:0.14042
# [959]	validation_0-rmse:0.14042
# [960]	validation_0-rmse:0.14041
# [961]	validation_0-rmse:0.14039
# [962]	validation_0-rmse:0.14039
# [963]	validation_0-rmse:0.14038
# [964]	validation_0-rmse:0.14038
# [965]	validation_0-rmse:0.14038
# [966]	validation_0-rmse:0.14037
# [967]	validation_0-rmse:0.14037
# [968]	validation_0-rmse:0.14036
# [969]	validation_0-rmse:0.14036
# [970]	validation_0-rmse:0.14036
# [971]	validation_0-rmse:0.14036
# [972]	validation_0-rmse:0.14036
# [973]	validation_0-rmse:0.14036
# [974]	validation_0-rmse:0.14035
# [975]	validation_0-rmse:0.14035
# [976]	validation_0-rmse:0.14035
# [977]	validation_0-rmse:0.14035
# [978]	validation_0-rmse:0.14034
# [979]	validation_0-rmse:0.14034
# [980]	validation_0-rmse:0.14033
# [981]	validation_0-rmse:0.14033
# [982]	validation_0-rmse:0.14033
# [983]	validation_0-rmse:0.14032
# [984]	validation_0-rmse:0.14032
# [985]	validation_0-rmse:0.14031
# [986]	validation_0-rmse:0.14031
# [987]	validation_0-rmse:0.14030
# [988]	validation_0-rmse:0.14030
# [989]	validation_0-rmse:0.14029
# [990]	validation_0-rmse:0.14029
# [991]	validation_0-rmse:0.14028
# [992]	validation_0-rmse:0.14028
# [993]	validation_0-rmse:0.14027
# [994]	validation_0-rmse:0.14027
# [995]	validation_0-rmse:0.14027
# [996]	validation_0-rmse:0.14027
# [997]	validation_0-rmse:0.14027
# [998]	validation_0-rmse:0.14026
# [999]	validation_0-rmse:0.14026
# [1000]	validation_0-rmse:0.14025
# [1001]	validation_0-rmse:0.14025
# [1002]	validation_0-rmse:0.14024
# [1003]	validation_0-rmse:0.14024
# [1004]	validation_0-rmse:0.14023
# [1005]	validation_0-rmse:0.14022
# [1006]	validation_0-rmse:0.14022
# [1007]	validation_0-rmse:0.14021
# [1008]	validation_0-rmse:0.14021
# [1009]	validation_0-rmse:0.14020
# [1010]	validation_0-rmse:0.14020
# [1011]	validation_0-rmse:0.14020
# [1012]	validation_0-rmse:0.14019
# [1013]	validation_0-rmse:0.14019
# [1014]	validation_0-rmse:0.14019
# [1015]	validation_0-rmse:0.14019
# [1016]	validation_0-rmse:0.14017
# [1017]	validation_0-rmse:0.14017
# [1018]	validation_0-rmse:0.14017
# [1019]	validation_0-rmse:0.14017
# [1020]	validation_0-rmse:0.14017
# [1021]	validation_0-rmse:0.14016
# [1022]	validation_0-rmse:0.14016
# [1023]	validation_0-rmse:0.14016
# [1024]	validation_0-rmse:0.14016
# [1025]	validation_0-rmse:0.14016
# [1026]	validation_0-rmse:0.14016
# [1027]	validation_0-rmse:0.14015
# [1028]	validation_0-rmse:0.14015
# [1029]	validation_0-rmse:0.14015
# [1030]	validation_0-rmse:0.14014
# [1031]	validation_0-rmse:0.14014
# [1032]	validation_0-rmse:0.14014
# [1033]	validation_0-rmse:0.14013
# [1034]	validation_0-rmse:0.14013
# [1035]	validation_0-rmse:0.14012
# [1036]	validation_0-rmse:0.14012
# [1037]	validation_0-rmse:0.14012
# [1038]	validation_0-rmse:0.14012
# [1039]	validation_0-rmse:0.14011
# [1040]	validation_0-rmse:0.14011
# [1041]	validation_0-rmse:0.14010
# [1042]	validation_0-rmse:0.14010
# [1043]	validation_0-rmse:0.14010
# [1044]	validation_0-rmse:0.14009
# [1045]	validation_0-rmse:0.14009
# [1046]	validation_0-rmse:0.14009
# [1047]	validation_0-rmse:0.14009
# [1048]	validation_0-rmse:0.14009
# [1049]	validation_0-rmse:0.14009
# [1050]	validation_0-rmse:0.14009
# [1051]	validation_0-rmse:0.14009
# [1052]	validation_0-rmse:0.14007
# [1053]	validation_0-rmse:0.14007
# [1054]	validation_0-rmse:0.14006
# [1055]	validation_0-rmse:0.14006
# [1056]	validation_0-rmse:0.14005
# [1057]	validation_0-rmse:0.14005
# [1058]	validation_0-rmse:0.14005
# [1059]	validation_0-rmse:0.14005
# [1060]	validation_0-rmse:0.14004
# [1061]	validation_0-rmse:0.14004
# [1062]	validation_0-rmse:0.14003
# [1063]	validation_0-rmse:0.14004
# [1064]	validation_0-rmse:0.14004
# [1065]	validation_0-rmse:0.14003
# [1066]	validation_0-rmse:0.14002
# [1067]	validation_0-rmse:0.14002
# [1068]	validation_0-rmse:0.14002
# [1069]	validation_0-rmse:0.14002
# [1070]	validation_0-rmse:0.14003
# [1071]	validation_0-rmse:0.14002
# [1072]	validation_0-rmse:0.14002
# [1073]	validation_0-rmse:0.14002
# [1074]	validation_0-rmse:0.14002
# [1075]	validation_0-rmse:0.14002
# [1076]	validation_0-rmse:0.14002
# [1077]	validation_0-rmse:0.14002
# [1078]	validation_0-rmse:0.14002
# [1079]	validation_0-rmse:0.14002
# [1080]	validation_0-rmse:0.14001
# [1081]	validation_0-rmse:0.14001
# [1082]	validation_0-rmse:0.14001
# [1083]	validation_0-rmse:0.14001
# [1084]	validation_0-rmse:0.14002
# [1085]	validation_0-rmse:0.14001
# [1086]	validation_0-rmse:0.14001
# [1087]	validation_0-rmse:0.14001
# [1088]	validation_0-rmse:0.14001
# [1089]	validation_0-rmse:0.14001
# [1090]	validation_0-rmse:0.14000
# [1091]	validation_0-rmse:0.14000
# [1092]	validation_0-rmse:0.13999
# [1093]	validation_0-rmse:0.13999
# [1094]	validation_0-rmse:0.13999
# [1095]	validation_0-rmse:0.13998
# [1096]	validation_0-rmse:0.13998
# [1097]	validation_0-rmse:0.13998
# [1098]	validation_0-rmse:0.13998
# [1099]	validation_0-rmse:0.13998
# [1100]	validation_0-rmse:0.13998
# [1101]	validation_0-rmse:0.13997
# [1102]	validation_0-rmse:0.13996
# [1103]	validation_0-rmse:0.13997
# [1104]	validation_0-rmse:0.13997
# [1105]	validation_0-rmse:0.13996
# [1106]	validation_0-rmse:0.13996
# [1107]	validation_0-rmse:0.13996
# [1108]	validation_0-rmse:0.13995
# [1109]	validation_0-rmse:0.13995
# [1110]	validation_0-rmse:0.13995
# [1111]	validation_0-rmse:0.13995
# [1112]	validation_0-rmse:0.13994
# [1113]	validation_0-rmse:0.13994
# [1114]	validation_0-rmse:0.13994
# [1115]	validation_0-rmse:0.13994
# [1116]	validation_0-rmse:0.13994
# [1117]	validation_0-rmse:0.13993
# [1118]	validation_0-rmse:0.13993
# [1119]	validation_0-rmse:0.13993
# [1120]	validation_0-rmse:0.13992
# [1121]	validation_0-rmse:0.13993
# [1122]	validation_0-rmse:0.13992
# [1123]	validation_0-rmse:0.13992
# [1124]	validation_0-rmse:0.13992
# [1125]	validation_0-rmse:0.13992
# [1126]	validation_0-rmse:0.13991
# [1127]	validation_0-rmse:0.13991
# [1128]	validation_0-rmse:0.13991
# [1129]	validation_0-rmse:0.13992
# [1130]	validation_0-rmse:0.13991
# [1131]	validation_0-rmse:0.13991
# [1132]	validation_0-rmse:0.13991
# [1133]	validation_0-rmse:0.13991
# [1134]	validation_0-rmse:0.13990
# [1135]	validation_0-rmse:0.13990
# [1136]	validation_0-rmse:0.13989
# [1137]	validation_0-rmse:0.13988
# [1138]	validation_0-rmse:0.13988
# [1139]	validation_0-rmse:0.13988
# [1140]	validation_0-rmse:0.13987
# [1141]	validation_0-rmse:0.13987
# [1142]	validation_0-rmse:0.13987
# [1143]	validation_0-rmse:0.13987
# [1144]	validation_0-rmse:0.13987
# [1145]	validation_0-rmse:0.13986
# [1146]	validation_0-rmse:0.13986
# [1147]	validation_0-rmse:0.13986
# [1148]	validation_0-rmse:0.13985
# [1149]	validation_0-rmse:0.13985
# [1150]	validation_0-rmse:0.13985
# [1151]	validation_0-rmse:0.13985
# [1152]	validation_0-rmse:0.13984
# [1153]	validation_0-rmse:0.13983
# [1154]	validation_0-rmse:0.13983
# [1155]	validation_0-rmse:0.13983
# [1156]	validation_0-rmse:0.13982
# [1157]	validation_0-rmse:0.13982
# [1158]	validation_0-rmse:0.13982
# [1159]	validation_0-rmse:0.13983
# [1160]	validation_0-rmse:0.13983
# [1161]	validation_0-rmse:0.13982
# [1162]	validation_0-rmse:0.13983
# [1163]	validation_0-rmse:0.13982
# [1164]	validation_0-rmse:0.13982
# [1165]	validation_0-rmse:0.13981
# [1166]	validation_0-rmse:0.13981
# [1167]	validation_0-rmse:0.13981
# [1168]	validation_0-rmse:0.13981
# [1169]	validation_0-rmse:0.13981
# [1170]	validation_0-rmse:0.13981
# [1171]	validation_0-rmse:0.13980
# [1172]	validation_0-rmse:0.13980
# [1173]	validation_0-rmse:0.13980
# [1174]	validation_0-rmse:0.13980
# [1175]	validation_0-rmse:0.13980
# [1176]	validation_0-rmse:0.13980
# [1177]	validation_0-rmse:0.13980
# [1178]	validation_0-rmse:0.13979
# [1179]	validation_0-rmse:0.13979
# [1180]	validation_0-rmse:0.13979
# [1181]	validation_0-rmse:0.13979
# [1182]	validation_0-rmse:0.13979
# [1183]	validation_0-rmse:0.13979
# [1184]	validation_0-rmse:0.13979
# [1185]	validation_0-rmse:0.13979
# [1186]	validation_0-rmse:0.13979
# [1187]	validation_0-rmse:0.13979
# [1188]	validation_0-rmse:0.13978
# [1189]	validation_0-rmse:0.13978
# [1190]	validation_0-rmse:0.13978
# [1191]	validation_0-rmse:0.13978
# [1192]	validation_0-rmse:0.13978
# [1193]	validation_0-rmse:0.13978
# [1194]	validation_0-rmse:0.13977
# [1195]	validation_0-rmse:0.13977
# [1196]	validation_0-rmse:0.13976
# [1197]	validation_0-rmse:0.13976
# [1198]	validation_0-rmse:0.13976
# [1199]	validation_0-rmse:0.13976
# [1200]	validation_0-rmse:0.13976
# [1201]	validation_0-rmse:0.13976
# [1202]	validation_0-rmse:0.13976
# [1203]	validation_0-rmse:0.13976
# [1204]	validation_0-rmse:0.13976
# [1205]	validation_0-rmse:0.13975
# [1206]	validation_0-rmse:0.13975
# [1207]	validation_0-rmse:0.13975
# [1208]	validation_0-rmse:0.13974
# [1209]	validation_0-rmse:0.13974
# [1210]	validation_0-rmse:0.13974
# [1211]	validation_0-rmse:0.13974
# [1212]	validation_0-rmse:0.13973
# [1213]	validation_0-rmse:0.13973
# [1214]	validation_0-rmse:0.13973
# [1215]	validation_0-rmse:0.13972
# [1216]	validation_0-rmse:0.13972
# [1217]	validation_0-rmse:0.13972
# [1218]	validation_0-rmse:0.13971
# [1219]	validation_0-rmse:0.13971
# [1220]	validation_0-rmse:0.13971
# [1221]	validation_0-rmse:0.13971
# [1222]	validation_0-rmse:0.13970
# [1223]	validation_0-rmse:0.13969
# [1224]	validation_0-rmse:0.13969
# [1225]	validation_0-rmse:0.13969
# [1226]	validation_0-rmse:0.13969
# [1227]	validation_0-rmse:0.13968
# [1228]	validation_0-rmse:0.13968
# [1229]	validation_0-rmse:0.13968
# [1230]	validation_0-rmse:0.13968
# [1231]	validation_0-rmse:0.13968
# [1232]	validation_0-rmse:0.13968
# [1233]	validation_0-rmse:0.13968
# [1234]	validation_0-rmse:0.13968
# [1235]	validation_0-rmse:0.13969
# [1236]	validation_0-rmse:0.13969
# [1237]	validation_0-rmse:0.13968
# [1238]	validation_0-rmse:0.13968
# [1239]	validation_0-rmse:0.13968
# [1240]	validation_0-rmse:0.13967
# [1241]	validation_0-rmse:0.13968
# [1242]	validation_0-rmse:0.13967
# [1243]	validation_0-rmse:0.13967
# [1244]	validation_0-rmse:0.13967
# [1245]	validation_0-rmse:0.13966
# [1246]	validation_0-rmse:0.13966
# [1247]	validation_0-rmse:0.13966
# [1248]	validation_0-rmse:0.13967
# [1249]	validation_0-rmse:0.13966
# [1250]	validation_0-rmse:0.13967
# [1251]	validation_0-rmse:0.13967
# [1252]	validation_0-rmse:0.13967
# [1253]	validation_0-rmse:0.13966
# [1254]	validation_0-rmse:0.13967
# [1255]	validation_0-rmse:0.13967
# [1256]	validation_0-rmse:0.13966
# [1257]	validation_0-rmse:0.13965
# [1258]	validation_0-rmse:0.13965
# [1259]	validation_0-rmse:0.13964
# [1260]	validation_0-rmse:0.13964
# [1261]	validation_0-rmse:0.13963
# [1262]	validation_0-rmse:0.13963
# [1263]	validation_0-rmse:0.13963
# [1264]	validation_0-rmse:0.13963
# [1265]	validation_0-rmse:0.13963
# [1266]	validation_0-rmse:0.13963
# [1267]	validation_0-rmse:0.13963
# [1268]	validation_0-rmse:0.13963
# [1269]	validation_0-rmse:0.13963
# [1270]	validation_0-rmse:0.13963
# [1271]	validation_0-rmse:0.13963
# [1272]	validation_0-rmse:0.13962
# [1273]	validation_0-rmse:0.13962
# [1274]	validation_0-rmse:0.13962
# [1275]	validation_0-rmse:0.13962
# [1276]	validation_0-rmse:0.13961
# [1277]	validation_0-rmse:0.13962
# [1278]	validation_0-rmse:0.13961
# [1279]	validation_0-rmse:0.13960
# [1280]	validation_0-rmse:0.13960
# [1281]	validation_0-rmse:0.13960
# [1282]	validation_0-rmse:0.13960
# [1283]	validation_0-rmse:0.13960
# [1284]	validation_0-rmse:0.13960
# [1285]	validation_0-rmse:0.13959
# [1286]	validation_0-rmse:0.13959
# [1287]	validation_0-rmse:0.13959
# [1288]	validation_0-rmse:0.13959
# [1289]	validation_0-rmse:0.13959
# [1290]	validation_0-rmse:0.13960
# [1291]	validation_0-rmse:0.13960
# [1292]	validation_0-rmse:0.13960
# [1293]	validation_0-rmse:0.13959
# [1294]	validation_0-rmse:0.13959
# [1295]	validation_0-rmse:0.13958
# [1296]	validation_0-rmse:0.13958
# [1297]	validation_0-rmse:0.13958
# [1298]	validation_0-rmse:0.13957
# [1299]	validation_0-rmse:0.13958
# [1300]	validation_0-rmse:0.13957
# [1301]	validation_0-rmse:0.13957
# [1302]	validation_0-rmse:0.13957
# [1303]	validation_0-rmse:0.13956
# [1304]	validation_0-rmse:0.13956
# [1305]	validation_0-rmse:0.13956
# [1306]	validation_0-rmse:0.13956
# [1307]	validation_0-rmse:0.13956
# [1308]	validation_0-rmse:0.13955
# [1309]	validation_0-rmse:0.13955
# [1310]	validation_0-rmse:0.13955
# [1311]	validation_0-rmse:0.13955
# [1312]	validation_0-rmse:0.13955
# [1313]	validation_0-rmse:0.13955
# [1314]	validation_0-rmse:0.13954
# [1315]	validation_0-rmse:0.13954
# [1316]	validation_0-rmse:0.13954
# [1317]	validation_0-rmse:0.13953
# [1318]	validation_0-rmse:0.13952
# [1319]	validation_0-rmse:0.13952
# [1320]	validation_0-rmse:0.13952
# [1321]	validation_0-rmse:0.13951
# [1322]	validation_0-rmse:0.13951
# [1323]	validation_0-rmse:0.13952
# [1324]	validation_0-rmse:0.13951
# [1325]	validation_0-rmse:0.13951
# [1326]	validation_0-rmse:0.13951
# [1327]	validation_0-rmse:0.13951
# [1328]	validation_0-rmse:0.13951
# [1329]	validation_0-rmse:0.13951
# [1330]	validation_0-rmse:0.13951
# [1331]	validation_0-rmse:0.13951
# [1332]	validation_0-rmse:0.13950
# [1333]	validation_0-rmse:0.13949
# [1334]	validation_0-rmse:0.13948
# [1335]	validation_0-rmse:0.13948
# [1336]	validation_0-rmse:0.13947
# [1337]	validation_0-rmse:0.13947
# [1338]	validation_0-rmse:0.13947
# [1339]	validation_0-rmse:0.13947
# [1340]	validation_0-rmse:0.13947
# [1341]	validation_0-rmse:0.13947
# [1342]	validation_0-rmse:0.13946
# [1343]	validation_0-rmse:0.13946
# [1344]	validation_0-rmse:0.13945
# [1345]	validation_0-rmse:0.13945
# [1346]	validation_0-rmse:0.13945
# [1347]	validation_0-rmse:0.13945
# [1348]	validation_0-rmse:0.13946
# [1349]	validation_0-rmse:0.13945
# [1350]	validation_0-rmse:0.13946
# [1351]	validation_0-rmse:0.13945
# [1352]	validation_0-rmse:0.13946
# [1353]	validation_0-rmse:0.13946
# [1354]	validation_0-rmse:0.13946
# [1355]	validation_0-rmse:0.13945
# [1356]	validation_0-rmse:0.13946
# [1357]	validation_0-rmse:0.13945
# [1358]	validation_0-rmse:0.13945
# [1359]	validation_0-rmse:0.13945
# [1360]	validation_0-rmse:0.13945
# [1361]	validation_0-rmse:0.13945
# [1362]	validation_0-rmse:0.13944
# [1363]	validation_0-rmse:0.13944
# [1364]	validation_0-rmse:0.13945
# [1365]	validation_0-rmse:0.13944
# [1366]	validation_0-rmse:0.13944
# [1367]	validation_0-rmse:0.13944
# [1368]	validation_0-rmse:0.13944
# [1369]	validation_0-rmse:0.13944
# [1370]	validation_0-rmse:0.13944
# [1371]	validation_0-rmse:0.13944
# [1372]	validation_0-rmse:0.13944
# [1373]	validation_0-rmse:0.13943
# [1374]	validation_0-rmse:0.13943
# [1375]	validation_0-rmse:0.13944
# [1376]	validation_0-rmse:0.13944
# [1377]	validation_0-rmse:0.13944
# [1378]	validation_0-rmse:0.13944
# [1379]	validation_0-rmse:0.13943
# [1380]	validation_0-rmse:0.13943
# [1381]	validation_0-rmse:0.13943
# [1382]	validation_0-rmse:0.13943
# [1383]	validation_0-rmse:0.13943
# [1384]	validation_0-rmse:0.13943
# [1385]	validation_0-rmse:0.13942
# [1386]	validation_0-rmse:0.13942
# [1387]	validation_0-rmse:0.13942
# [1388]	validation_0-rmse:0.13942
# [1389]	validation_0-rmse:0.13942
# [1390]	validation_0-rmse:0.13942
# [1391]	validation_0-rmse:0.13941
# [1392]	validation_0-rmse:0.13941
# [1393]	validation_0-rmse:0.13941
# [1394]	validation_0-rmse:0.13941
# [1395]	validation_0-rmse:0.13941
# [1396]	validation_0-rmse:0.13941
# [1397]	validation_0-rmse:0.13941
# [1398]	validation_0-rmse:0.13941
# [1399]	validation_0-rmse:0.13941
# [1400]	validation_0-rmse:0.13941
# [1401]	validation_0-rmse:0.13941
# [1402]	validation_0-rmse:0.13941
# [1403]	validation_0-rmse:0.13941
# [1404]	validation_0-rmse:0.13941
# [1405]	validation_0-rmse:0.13941
# [1406]	validation_0-rmse:0.13941
# [1407]	validation_0-rmse:0.13941
# [1408]	validation_0-rmse:0.13941
# [1409]	validation_0-rmse:0.13941
# [1410]	validation_0-rmse:0.13941
# [1411]	validation_0-rmse:0.13941
# [1412]	validation_0-rmse:0.13940
# [1413]	validation_0-rmse:0.13940
# [1414]	validation_0-rmse:0.13941
# [1415]	validation_0-rmse:0.13940
# [1416]	validation_0-rmse:0.13940
# [1417]	validation_0-rmse:0.13940
# [1418]	validation_0-rmse:0.13940
# [1419]	validation_0-rmse:0.13940
# [1420]	validation_0-rmse:0.13940
# [1421]	validation_0-rmse:0.13939
# [1422]	validation_0-rmse:0.13939
# [1423]	validation_0-rmse:0.13940
# [1424]	validation_0-rmse:0.13939
# [1425]	validation_0-rmse:0.13939
# [1426]	validation_0-rmse:0.13939
# [1427]	validation_0-rmse:0.13939
# [1428]	validation_0-rmse:0.13939
# [1429]	validation_0-rmse:0.13939
# [1430]	validation_0-rmse:0.13939
# [1431]	validation_0-rmse:0.13938
# [1432]	validation_0-rmse:0.13938
# [1433]	validation_0-rmse:0.13938
# [1434]	validation_0-rmse:0.13938
# [1435]	validation_0-rmse:0.13938
# [1436]	validation_0-rmse:0.13939
# [1437]	validation_0-rmse:0.13938
# [1438]	validation_0-rmse:0.13938
# [1439]	validation_0-rmse:0.13938
# [1440]	validation_0-rmse:0.13938
# [1441]	validation_0-rmse:0.13937
# [1442]	validation_0-rmse:0.13937
# [1443]	validation_0-rmse:0.13937
# [1444]	validation_0-rmse:0.13937
# [1445]	validation_0-rmse:0.13937
# [1446]	validation_0-rmse:0.13937
# [1447]	validation_0-rmse:0.13937
# [1448]	validation_0-rmse:0.13937
# [1449]	validation_0-rmse:0.13937
# [1450]	validation_0-rmse:0.13937
# [1451]	validation_0-rmse:0.13937
# [1452]	validation_0-rmse:0.13937
# [1453]	validation_0-rmse:0.13937
# [1454]	validation_0-rmse:0.13936
# [1455]	validation_0-rmse:0.13936
# [1456]	validation_0-rmse:0.13936
# [1457]	validation_0-rmse:0.13937
# [1458]	validation_0-rmse:0.13936
# [1459]	validation_0-rmse:0.13937
# [1460]	validation_0-rmse:0.13937
# [1461]	validation_0-rmse:0.13937
# [1462]	validation_0-rmse:0.13937
# [1463]	validation_0-rmse:0.13937
# [1464]	validation_0-rmse:0.13937
# [1465]	validation_0-rmse:0.13937
# [1466]	validation_0-rmse:0.13936
# [1467]	validation_0-rmse:0.13936
# [1468]	validation_0-rmse:0.13936
# [1469]	validation_0-rmse:0.13936
# [1470]	validation_0-rmse:0.13936
# [1471]	validation_0-rmse:0.13936
# [1472]	validation_0-rmse:0.13936
# [1473]	validation_0-rmse:0.13935
# [1474]	validation_0-rmse:0.13935
# [1475]	validation_0-rmse:0.13935
# [1476]	validation_0-rmse:0.13934
# [1477]	validation_0-rmse:0.13934
# [1478]	validation_0-rmse:0.13934
# [1479]	validation_0-rmse:0.13934
# [1480]	validation_0-rmse:0.13934
# [1481]	validation_0-rmse:0.13934
# [1482]	validation_0-rmse:0.13934
# [1483]	validation_0-rmse:0.13934
# [1484]	validation_0-rmse:0.13934
# [1485]	validation_0-rmse:0.13934
# [1486]	validation_0-rmse:0.13933
# [1487]	validation_0-rmse:0.13933
# [1488]	validation_0-rmse:0.13933
# [1489]	validation_0-rmse:0.13932
# [1490]	validation_0-rmse:0.13932
# [1491]	validation_0-rmse:0.13932
# [1492]	validation_0-rmse:0.13932
# [1493]	validation_0-rmse:0.13932
# [1494]	validation_0-rmse:0.13932
# [1495]	validation_0-rmse:0.13932
# [1496]	validation_0-rmse:0.13932
# [1497]	validation_0-rmse:0.13932
# [1498]	validation_0-rmse:0.13932
# [1499]	validation_0-rmse:0.13931
# [1500]	validation_0-rmse:0.13931
# [1501]	validation_0-rmse:0.13931
# [1502]	validation_0-rmse:0.13931
# [1503]	validation_0-rmse:0.13931
# [1504]	validation_0-rmse:0.13931
# [1505]	validation_0-rmse:0.13931
# [1506]	validation_0-rmse:0.13930
# [1507]	validation_0-rmse:0.13930
# [1508]	validation_0-rmse:0.13930
# [1509]	validation_0-rmse:0.13930
# [1510]	validation_0-rmse:0.13930
# [1511]	validation_0-rmse:0.13931
# [1512]	validation_0-rmse:0.13930
# [1513]	validation_0-rmse:0.13930
# [1514]	validation_0-rmse:0.13929
# [1515]	validation_0-rmse:0.13929
# [1516]	validation_0-rmse:0.13929
# [1517]	validation_0-rmse:0.13929
# [1518]	validation_0-rmse:0.13929
# [1519]	validation_0-rmse:0.13929
# [1520]	validation_0-rmse:0.13929
# [1521]	validation_0-rmse:0.13929
# [1522]	validation_0-rmse:0.13930
# [1523]	validation_0-rmse:0.13930
# [1524]	validation_0-rmse:0.13930
# [1525]	validation_0-rmse:0.13930
# [1526]	validation_0-rmse:0.13930
# [1527]	validation_0-rmse:0.13930
# [1528]	validation_0-rmse:0.13930
# [1529]	validation_0-rmse:0.13930
# [1530]	validation_0-rmse:0.13930
# [1531]	validation_0-rmse:0.13929
# [1532]	validation_0-rmse:0.13929
# [1533]	validation_0-rmse:0.13929
# [1534]	validation_0-rmse:0.13928
# [1535]	validation_0-rmse:0.13928
# [1536]	validation_0-rmse:0.13929
# [1537]	validation_0-rmse:0.13929
# Refit tuned model; best_iteration (if any): None

# %%
# Evaluate performance
# Raw predictions from the model (in log scale if USE_LOG_TARGET)
y_train_pred = xgb.predict(X_train_t)
y_val_pred = xgb.predict(X_val_t)
y_test_pred = xgb.predict(X_test_t)

# Convert predictions back to original scale when needed
if 'USE_LOG_TARGET' in globals() and USE_LOG_TARGET:
    y_train_eval = np.expm1(y_train_pred)
    y_val_eval = np.expm1(y_val_pred)
    y_test_eval = np.expm1(y_test_pred)
    yt_train = y_train_raw
    yt_val = y_val_raw
    yt_test = y_test_raw
else:
    y_train_eval, y_val_eval, y_test_eval = y_train_pred, y_val_pred, y_test_pred
    yt_train, yt_val, yt_test = y_train, y_val, y_test

print('Train metrics:', regression_metrics(yt_train, y_train_eval))
print('Val metrics:  ', regression_metrics(yt_val, y_val_eval))
print('Test metrics: ', regression_metrics(yt_test, y_test_eval))

plt.figure(figsize=(6, 6))
sns.scatterplot(x=yt_test, y=y_test_eval, s=12, alpha=0.5)
lims = [min(yt_test.min(), y_test_eval.min()), max(yt_test.max(), y_test_eval.max())]
plt.plot(lims, lims, 'r--', linewidth=1)
plt.xlabel('Actual rental_price')
plt.ylabel('Predicted rental_price')
plt.title('Tuned Predicted vs Actual (Test)')
plt.show()
# Out:
# Train metrics: {'RMSE': np.float64(37.78004168662246), 'MAE': 24.933387443042886, 'R2': 0.9665117824987448}
# Val metrics:   {'RMSE': np.float64(97.65752441989235), 'MAE': 61.56661507186297, 'R2': 0.7664199959205703}
# Test metrics:  {'RMSE': np.float64(103.1153918588496), 'MAE': 64.09439551863383, 'R2': 0.7540049925930608}

# %%
if DO_CV:
    model = Pipeline(steps=[('preprocessor', preprocessor), ('model', xgb)])
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    cv_scores = cross_val_score(model, X, y_raw, cv=kf, scoring='neg_root_mean_squared_error', n_jobs=-1)
    print('CV RMSE: ', (-cv_scores).mean(), '+/-', (-cv_scores).std())

# %%
# Feature importances
importances = xgb.feature_importances_
try:
    feature_names = preprocessor.get_feature_names_out()
except Exception:
    # Fallback: generic names if transformers don't expose names
    feature_names = np.asarray([f'feature_{i}' for i in range(importances.shape[0])], dtype=object)
feat_imp = pd.DataFrame({'feature': feature_names, 'importance': importances}).sort_values('importance', ascending=False)
feat_imp.head(10)

top_n = 10
plt.figure(figsize=(8, max(4, top_n * 0.4)))
sns.barplot(data=feat_imp.head(top_n), x='importance', y='feature', orient='h')
plt.title(f'Top {top_n} Feature Importances (XGBoost)')
plt.tight_layout()
plt.show()

# %%
# Optional: save top features to csv
top_features_path = save_dir / 'xgb_rental_price_top_features.csv'
feat_imp.head(10).to_csv(top_features_path, index=False)
print(f'Saved feature importances to {top_features_path}')
# Out:
# Saved feature importances to ../models/xgb_rental_price_top_features.csv

# %% [markdown]
# ## Diagnostics for Overfitting

# %%
# Residual diagnostics by data split
residuals = pd.DataFrame({
    'split': (['Train'] * len(yt_train)) + (['Validation'] * len(yt_val)) + (['Test'] * len(yt_test)),
    'actual': np.concatenate([np.asarray(yt_train), np.asarray(yt_val), np.asarray(yt_test)]),
    'predicted': np.concatenate([np.asarray(y_train_eval), np.asarray(y_val_eval), np.asarray(y_test_eval)]),
})
residuals['residual'] = residuals['actual'] - residuals['predicted']

summary = residuals.groupby('split')['residual'].agg(
    mean='mean',
    std='std',
    median='median',
    mean_abs=lambda s: s.abs().mean(),
)
print('Residual summary (original scale):')
print(summary.round(4))

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.scatterplot(data=residuals, x='predicted', y='residual', hue='split', alpha=0.5, s=15, ax=axes[0])
axes[0].axhline(0, color='k', linestyle='--', linewidth=1)
axes[0].set_title('Residuals vs Predicted')
axes[0].set_xlabel('Predicted rental_price')
axes[0].set_ylabel('Residual (actual - predicted)')

sns.histplot(
    data=residuals,
    x='residual',
    hue='split',
    element='step',
    stat='density',
    common_norm=False,
    ax=axes[1],
    alpha=0.5,
)
axes[1].axvline(0, color='k', linestyle='--', linewidth=1)
axes[1].set_title('Residual Distribution')
axes[1].set_xlabel('Residual (actual - predicted)')

plt.tight_layout()
# Out:
# Residual summary (original scale):
#               mean       std  median  mean_abs
# split
# Test        7.3688  102.8571 -1.8672   64.0944
# Train       3.3759   37.6306 -0.6414   24.9334
# Validation  4.1638   97.5823 -4.1345   61.5666
