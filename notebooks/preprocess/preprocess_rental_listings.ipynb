# %%
# reload all module before executing code
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Cleaning the Weekly Rental Data

# %%
import pandas as pd
import os, re

# %%
pd.set_option("display.max_rows", None)  # Show all rows, default is 10
pd.set_option("display.max_columns", None)  # Show all columns, default is 20

# %% [markdown]
# ## Download Data
#
# ### Scraped Domain Data

# %%
# set download path
data_path = "../../data/raw/domain/"

# list csv files, make sure they match
csv_files = [file for file in os.listdir(data_path) if re.match(r'rental_listings_\d{4}_\d{2}.csv', file)]

# %%
# list of dataframes 
df_list = []

# read each file, extract year and month from filename, add as columns
for file in csv_files:
    match = re.search(r'rental_listings_(\d{4})_(\d{2}).csv', file)
    if match:
        year = match.group(1)
        quarter = match.group(2)
        df = pd.read_csv(os.path.join(data_path, file))
        df['year'] = year
        df['quarter'] = quarter
        df_list.append(df)

# concatenate all dataframes
df = pd.concat(df_list, ignore_index=True)

# %%
print(df.iloc[-1])
# Out:
# property_id                                                   17537987.0
# url                           /5-40-sandwych-wentworth-nsw-2648-17537987
# rental_price                                               $320 per week
# bedrooms                                                             2.0
# bathrooms                                                            1.0
# car_spaces                                                           1.0
# property_type                                    Apartment / Unit / Flat
# land_area                                                            0.0
# property_features                                             2, ,1, ,1,
# suburb                                                         WENTWORTH
# postcode                                                            2648
# scraped_date                                         2025-04-25 21:10:55
# wayback_url            https://web.archive.org/web/20250425211055/htt...
# wayback_time                                            20250425211055.0
# year                                                                2025
# quarter                                                               03
# age_0_to_19                                                          NaN
# age_20_to_39                                                         NaN
# age_40_to_59                                                         NaN
# age_60_plus                                                          NaN
# agency_name                                                          NaN
# agent_name                                                           NaN
# appointment_only                                                     NaN
# avg_days_on_market                                                   NaN
# description                                                          NaN
# family_percentage                                                    NaN
# features_list                                                        NaN
# first_listed_date                                                    NaN
# full_address                                                         NaN
# image_urls                                                           NaN
# inspection_text                                                      NaN
# last_sold_date                                                       NaN
# latitude                                                             NaN
# listing_status                                                       NaN
# listing_tag                                                          NaN
# listing_url                                                          NaN
# long_term_resident                                                   NaN
# longitude                                                            NaN
# median_rent_price                                                    NaN
# median_sold_price                                                    NaN
# number_of_photos                                                     NaN
# number_sold                                                          NaN
# owner_percentage                                                     NaN
# renter_percentage                                                    NaN
# schools                                                              NaN
# single_percentage                                                    NaN
# state_abbreviation                                                   NaN
# street                                                               NaN
# street_number                                                        NaN
# structured_features                                                  NaN
# unit_number                                                          NaN
# updated_date                                                         NaN
# Name: 31267, dtype: object

# %%
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
# Out:
# Rows: 31268, Columns: 52

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31268 entries, 0 to 31267
# Data columns (total 52 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          31265 non-null  float64
#  1   url                  31268 non-null  object
#  2   rental_price         31265 non-null  object
#  3   bedrooms             30944 non-null  object
#  4   bathrooms            17067 non-null  float64
#  5   car_spaces           29156 non-null  float64
#  6   property_type        31265 non-null  object
#  7   land_area            17122 non-null  float64
#  8   property_features    31240 non-null  object
#  9   suburb               31268 non-null  object
#  10  postcode             31268 non-null  int64
#  11  scraped_date         17122 non-null  object
#  12  wayback_url          17122 non-null  object
#  13  wayback_time         17122 non-null  float64
#  14  year                 31268 non-null  object
#  15  quarter              31268 non-null  object
#  16  age_0_to_19          14143 non-null  float64
#  17  age_20_to_39         14143 non-null  float64
#  18  age_40_to_59         14143 non-null  float64
#  19  age_60_plus          14143 non-null  float64
#  20  agency_name          14143 non-null  object
#  21  agent_name           13872 non-null  object
#  22  appointment_only     13752 non-null  object
#  23  avg_days_on_market   14142 non-null  float64
#  24  description          14141 non-null  object
#  25  family_percentage    14143 non-null  float64
#  26  features_list        7994 non-null   object
#  27  first_listed_date    14143 non-null  object
#  28  full_address         14143 non-null  object
#  29  image_urls           1455 non-null   object
#  30  inspection_text      0 non-null      float64
#  31  last_sold_date       2310 non-null   object
#  32  latitude             14143 non-null  float64
#  33  listing_status       14143 non-null  object
#  34  listing_tag          164 non-null    object
#  35  listing_url          14143 non-null  object
#  36  long_term_resident   14143 non-null  float64
#  37  longitude            14143 non-null  float64
#  38  median_rent_price    14142 non-null  float64
#  39  median_sold_price    14142 non-null  float64
#  40  number_of_photos     14146 non-null  float64
#  41  number_sold          14143 non-null  float64
#  42  owner_percentage     14143 non-null  float64
#  43  renter_percentage    14143 non-null  float64
#  44  schools              14143 non-null  object
#  45  single_percentage    14143 non-null  float64
#  46  state_abbreviation   14143 non-null  object
#  47  street               14034 non-null  object
#  48  street_number        14017 non-null  object
#  49  structured_features  12677 non-null  object
#  50  unit_number          5882 non-null   object
#  51  updated_date         14143 non-null  object
# dtypes: float64(22), int64(1), object(29)
# memory usage: 12.4+ MB

# %% [markdown]
# ### Suburb CSV

# %%
# import the suburb csv as a new dataframe
suburb_df = pd.read_csv("../../data/geo/vic_suburbs_postcodes.csv")

# %%
# lowercase suburb names for both dataframes to ensure consistency
suburb_df['suburb'] = suburb_df['suburb'].str.lower()
df['suburb'] = df['suburb'].str.lower()

# %%
print(f"Rows: {suburb_df.shape[0]}, Columns: {suburb_df.shape[1]}")
# Out:
# Rows: 3186, Columns: 2

# %%
df['suburb'].nunique(), df['postcode'].nunique()
# Out:
# (1031, 512)

# %% [markdown]
# We clearly have to check the suburbs for duplicates, typos, and possible records outside of Victoria

# %% [markdown]
# # Column Standardisation
#
# Let's begin by standardising the columns
#
# This will include:
#
# - checking for inconsistent column names across files
# - rename columns to snake_case
# - drop irrelevant columns

# %%
# standardise column names to snake_case
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31268 entries, 0 to 31267
# Data columns (total 52 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          31265 non-null  float64
#  1   url                  31268 non-null  object
#  2   rental_price         31265 non-null  object
#  3   bedrooms             30944 non-null  object
#  4   bathrooms            17067 non-null  float64
#  5   car_spaces           29156 non-null  float64
#  6   property_type        31265 non-null  object
#  7   land_area            17122 non-null  float64
#  8   property_features    31240 non-null  object
#  9   suburb               31268 non-null  object
#  10  postcode             31268 non-null  int64
#  11  scraped_date         17122 non-null  object
#  12  wayback_url          17122 non-null  object
#  13  wayback_time         17122 non-null  float64
#  14  year                 31268 non-null  object
#  15  quarter              31268 non-null  object
#  16  age_0_to_19          14143 non-null  float64
#  17  age_20_to_39         14143 non-null  float64
#  18  age_40_to_59         14143 non-null  float64
#  19  age_60_plus          14143 non-null  float64
#  20  agency_name          14143 non-null  object
#  21  agent_name           13872 non-null  object
#  22  appointment_only     13752 non-null  object
#  23  avg_days_on_market   14142 non-null  float64
#  24  description          14141 non-null  object
#  25  family_percentage    14143 non-null  float64
#  26  features_list        7994 non-null   object
#  27  first_listed_date    14143 non-null  object
#  28  full_address         14143 non-null  object
#  29  image_urls           1455 non-null   object
#  30  inspection_text      0 non-null      float64
#  31  last_sold_date       2310 non-null   object
#  32  latitude             14143 non-null  float64
#  33  listing_status       14143 non-null  object
#  34  listing_tag          164 non-null    object
#  35  listing_url          14143 non-null  object
#  36  long_term_resident   14143 non-null  float64
#  37  longitude            14143 non-null  float64
#  38  median_rent_price    14142 non-null  float64
#  39  median_sold_price    14142 non-null  float64
#  40  number_of_photos     14146 non-null  float64
#  41  number_sold          14143 non-null  float64
#  42  owner_percentage     14143 non-null  float64
#  43  renter_percentage    14143 non-null  float64
#  44  schools              14143 non-null  object
#  45  single_percentage    14143 non-null  float64
#  46  state_abbreviation   14143 non-null  object
#  47  street               14034 non-null  object
#  48  street_number        14017 non-null  object
#  49  structured_features  12677 non-null  object
#  50  unit_number          5882 non-null   object
#  51  updated_date         14143 non-null  object
# dtypes: float64(22), int64(1), object(29)
# memory usage: 12.4+ MB

# %%
# only keep relevant columns
relevant_columns = [
    'property_id','rental_price', 'bedrooms', 'bathrooms', 'car_spaces',
    'property_type', 'land_area', 'property_features', 
    'suburb', 'postcode', 'year', 'quarter',
    'age_0_to_19', 'age_20_to_39', 'age_40_to_59', 'age_60_plus',
    'agency_name', 'agent_name', 'appointment_only', 'avg_days_on_market',
    'description', 'family_percentage', 'features_list', 
    'first_listed_date', 'full_address', 'last_sold_date',
    'latitude', 'longitude', 'listing_status', 'long_term_resident', 
    'median_rent_price', 'median_sold_price', 'number_sold',
    'renter_percentage', 'schools', 'single_percentage',
    'state_abbreviation', 'structured_features', 'unit_number', 'updated_date',
    'url'
]

df = df[relevant_columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31268 entries, 0 to 31267
# Data columns (total 41 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          31265 non-null  float64
#  1   rental_price         31265 non-null  object
#  2   bedrooms             30944 non-null  object
#  3   bathrooms            17067 non-null  float64
#  4   car_spaces           29156 non-null  float64
#  5   property_type        31265 non-null  object
#  6   land_area            17122 non-null  float64
#  7   property_features    31240 non-null  object
#  8   suburb               31268 non-null  object
#  9   postcode             31268 non-null  int64
#  10  year                 31268 non-null  object
#  11  quarter              31268 non-null  object
#  12  age_0_to_19          14143 non-null  float64
#  13  age_20_to_39         14143 non-null  float64
#  14  age_40_to_59         14143 non-null  float64
#  15  age_60_plus          14143 non-null  float64
#  16  agency_name          14143 non-null  object
#  17  agent_name           13872 non-null  object
#  18  appointment_only     13752 non-null  object
#  19  avg_days_on_market   14142 non-null  float64
#  20  description          14141 non-null  object
#  21  family_percentage    14143 non-null  float64
#  22  features_list        7994 non-null   object
#  23  first_listed_date    14143 non-null  object
#  24  full_address         14143 non-null  object
#  25  last_sold_date       2310 non-null   object
#  26  latitude             14143 non-null  float64
#  27  longitude            14143 non-null  float64
#  28  listing_status       14143 non-null  object
#  29  long_term_resident   14143 non-null  float64
#  30  median_rent_price    14142 non-null  float64
#  31  median_sold_price    14142 non-null  float64
#  32  number_sold          14143 non-null  float64
#  33  renter_percentage    14143 non-null  float64
#  34  schools              14143 non-null  object
#  35  single_percentage    14143 non-null  float64
#  36  state_abbreviation   14143 non-null  object
#  37  structured_features  12677 non-null  object
#  38  unit_number          5882 non-null   object
#  39  updated_date         14143 non-null  object
#  40  url                  31268 non-null  object
# dtypes: float64(18), int64(1), object(22)
# memory usage: 9.8+ MB

# %%
df['state_abbreviation'].value_counts()
# Out:
# state_abbreviation
# vic    14143
# Name: count, dtype: int64

# %% [markdown]
# ## Record Standardisation
# Let's standardise our data in the following ways:
# - stripping leading/trailing spaces
# - lowercasing
# - collapse multiple spaces
# - remove punctuation
# - standardise abbreviations
# - validate against controlled vocabularies

# %%
# create a udf to preprocess string columns
def preprocess_string_column(col):
    """
    Preprocess a string column by:
    - stripping leading/trailing spaces
    - collapsing multiple spaces
    - removing punctuation (except for hyphens and apostrophes)
    - lowercasing
    """
    if pd.isna(col):
        return col
    # handle non-string entries
    if not isinstance(col, str):
        col = str(col)
    # strip leading/trailing spaces
    col = col.strip()
    # collapse multiple spaces
    col = re.sub(r'\s+', ' ', col)
    # remove punctuation (except for hyphens and apostrophes)
    col = re.sub(r'[^\w\s\'-]', '', col)
    # lowercase
    col = col.lower()
    return col

# %%
# apply string preprocessing to columns with type object
string_columns = df.select_dtypes(include=['object']).columns.tolist()
# we need the formatting in 'property_features' for some features
string_columns.remove('property_features')  # exclude 'property_features'
for col in string_columns:
    df[col] = df[col].apply(preprocess_string_column)
    # run twice in case of special situations
    df[col] = df[col].apply(preprocess_string_column)

# %% [markdown]
# ### Suburbs

# %%
df['suburb'].nunique(), df['postcode'].nunique()
# Out:
# (1031, 512)

# %%
df['suburb'].sort_values().unique()
# Out:
# array(['abbotsford', 'aberfeldie', 'acheron', ..., 'yellingbo', 'yendon',
#        'yinnar south'], shape=(1031,), dtype=object)

# %%
suburb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3186 entries, 0 to 3185
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   postcode  3186 non-null   int64
#  1   suburb    3186 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 49.9+ KB

# %%
# which entries from suburb_df['suburb'] are not in df['suburb']
suburb_df[~suburb_df['suburb'].isin(df['suburb'])].count()
# Out:
# postcode    2129
# suburb      2129
# dtype: int64

# %% [markdown]
# ## Dealing with Missing Values
#
# Let's first inspect the missing values to see if there are any trends

# %%
df.isna().sum()
# Out:
# property_id                3
# rental_price               3
# bedrooms                 324
# bathrooms              14201
# car_spaces              2112
# property_type              3
# land_area              14146
# property_features         28
# suburb                     0
# postcode                   0
# year                       0
# quarter                    0
# age_0_to_19            17125
# age_20_to_39           17125
# age_40_to_59           17125
# age_60_plus            17125
# agency_name            17125
# agent_name             17396
# appointment_only       17516
# avg_days_on_market     17126
# description            17127
# family_percentage      17125
# features_list          23274
# first_listed_date      17125
# full_address           17125
# last_sold_date         28958
# latitude               17125
# longitude              17125
# listing_status         17125
# long_term_resident     17125
# median_rent_price      17126
# median_sold_price      17126
# number_sold            17125
# renter_percentage      17125
# schools                17125
# single_percentage      17125
# state_abbreviation     17125
# structured_features    18591
# unit_number            25386
# updated_date           17125
# url                        0
# dtype: int64

# %% [markdown]
# First of all, having rental_price is essential; drop the records without this value

# %%
# drop rows where rental_price is missing
df = df.dropna(subset=['rental_price'])

# %%
df.shape
# Out:
# (31265, 41)

# %%
df['property_id'].nunique()
# Out:
# 29333

# %% [markdown]
# We see that there are duplicate listing records for the same property. We remove these duplicates by picking the listing with the most recent (year, quarter).

# %%
# sort df by (year, quarter) descending
df = df.sort_values(by=['year', 'quarter'], ascending=False)
# drop duplicates
df = df.drop_duplicates(subset=['property_id'])
df.shape
# Out:
# (29333, 41)

# %%
# Convert the columns latitude and longitude to a Point (only if latitude and longitude are not null), call the column coordinates 
# drop latitude and longitude columns
from shapely.geometry import Point

df['coordinates'] = df[['latitude', 'longitude']].apply(lambda x: Point(x['latitude'], x['longitude']) if not pd.isna(x['latitude']) and not pd.isna(x['longitude']) else None, axis=1)
df = df.drop(columns=['latitude', 'longitude'])

# %%
# Import the GeoUtils class from utils/geo.py
from utils.geo import GeoUtils

# Initialize GeoUtils 
geoutils = GeoUtils()

# create a mask where full address is null 
mask = df['full_address'].isna()

# extracting full address from url for the wayback listings
df.loc[mask, 'full_address'] = df.loc[mask, 'url'].apply(geoutils.extract_address_from_url)
# Out:
# Warning: No OpenRouteService API key provided. Set ORS_API_KEY environment variable or pass ors_api_key parameter.

# %% [markdown]
# The geocoding API takes a very long time to run, so the results have been saved to `data/processed/domain/rental_listings_summary_cleaned.csv`. We load in the results here.

# %%
df_tmp = pd.read_csv('../../data/processed/domain/rental_listings_summary_cleaned.csv')

mask = df['coordinates'].isna()
coordinate_mapping = df_tmp.set_index('property_id')['coordinates'].to_dict()
df.loc[mask, 'coordinates'] = df.loc[mask, 'property_id'].map(coordinate_mapping)

# %%
df['coordinates'].isna().sum()
# Out:
# np.int64(3856)

# %% [markdown]
# We see that there are still listings without coordinates because the Nominatim API could not get a result. We'll save these listings into `data/raw/rental_listings_missing_coordinates.csv` for further processing with another API (OpenRouteService). Because we are limited by only 500 requests per API key per day, we have to impute these missing coordinates intermitently.

# %%
# save the listings without coordinates
# use os to make the directory if it doesn't exist
os.makedirs('../../data/raw/missing_geo/', exist_ok=True)
df[df['coordinates'].isna()].to_csv('../../data/raw/missing_geo/rental_listings_missing_coordinates.csv', index=False)

# %%
# save intermediate df result 
saved_df = df.copy()

# %%
saved_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29333 entries, 10077 to 24952
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          29333 non-null  float64
#  1   rental_price         29333 non-null  object
#  2   bedrooms             29057 non-null  object
#  3   bathrooms            15178 non-null  float64
#  4   car_spaces           27530 non-null  float64
#  5   property_type        29333 non-null  object
#  6   land_area            15190 non-null  float64
#  7   property_features    29305 non-null  object
#  8   suburb               29333 non-null  object
#  9   postcode             29333 non-null  int64
#  10  year                 29333 non-null  object
#  11  quarter              29333 non-null  object
#  12  age_0_to_19          14143 non-null  float64
#  13  age_20_to_39         14143 non-null  float64
#  14  age_40_to_59         14143 non-null  float64
#  15  age_60_plus          14143 non-null  float64
#  16  agency_name          14143 non-null  object
#  17  agent_name           13872 non-null  object
#  18  appointment_only     13752 non-null  object
#  19  avg_days_on_market   14142 non-null  float64
#  20  description          14141 non-null  object
#  21  family_percentage    14143 non-null  float64
#  22  features_list        7994 non-null   object
#  23  first_listed_date    14143 non-null  object
#  24  full_address         29333 non-null  object
#  25  last_sold_date       2310 non-null   object
#  26  listing_status       14143 non-null  object
#  27  long_term_resident   14143 non-null  float64
#  28  median_rent_price    14142 non-null  float64
#  29  median_sold_price    14142 non-null  float64
#  30  number_sold          14143 non-null  float64
#  31  renter_percentage    14143 non-null  float64
#  32  schools              14143 non-null  object
#  33  single_percentage    14143 non-null  float64
#  34  state_abbreviation   14143 non-null  object
#  35  structured_features  12677 non-null  object
#  36  unit_number          5882 non-null   object
#  37  updated_date         14143 non-null  object
#  38  url                  29333 non-null  object
#  39  coordinates          25477 non-null  object
# dtypes: float64(16), int64(1), object(23)
# memory usage: 9.2+ MB

# %% [markdown]
# ### Clean and Convert Key Fields
#
# We need to clean and convert columns to be more standardised and easier to analyse

# %% [markdown]
# Let's start with the rental_price.

# %% [markdown]
# First, let's remove '$' and ',' from the values

# %%
# remove '$' and ',' from rental_price 
df['rental_price'] = df['rental_price'].replace('[\$,]', '', regex=True).astype(str)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipykernel_942/641504744.py:2: SyntaxWarning: invalid escape sequence '\$'
#   df['rental_price'] = df['rental_price'].replace('[\$,]', '', regex=True).astype(str)

# %% [markdown]
# Convert to lower casing to remove some duplicates

# %%
df["rental_price"] = df["rental_price"].str.lower()

# %% [markdown]
# There are a number of values in which we do not want

# %%
# remove spaces in rental_price
df['rental_price'] = df['rental_price'].str.replace(' ', '')

# %%
# keep records which start with a number
df = df[df['rental_price'].str.match(r'^\d')]

# %%
print(df['rental_price'].value_counts().sort_values())
# Out:
# rental_price
# 290pw-savetimeviewour3dtourapply                1
# 140000perweek                                   1
# 480perweekavailablenow                          1
# 1700weekly                                      1
# 102000                                          1
# 88500                                           1
# 1295                                            1
# 480perweek-2086percalendarmonth                 1
# 670perweekinclutilities                         1
# 360perweek-unfurnished                          1
# 696perweek                                      1
# 335weekly                                       1
# 50                                              1
# 525perweekpw                                    1
# 870pw                                           1
# 420pw-savetimeviewour3dtourapply                1
# 450w                                            1
# 30wk                                            1
# 27perweek                                       1
# 22perweek                                       1
# 810pw3520pcm                                    1
# 50perhour                                       1
# 1750pwhigh1400pwlow250pn                        1
# 250pernight-4people                             1
# 44000pw191200pcm                                1
# 435pw1890pcm                                    1
# 49000perweek212900pcm                           1
# 360perweekpw                                    1
# 350perweek1517permonth                          1
# 330perweekfullyfurnishedutilitiesincluded       1
# 300perweek1304permonth                          1
# 323perweek                                      1
# 585pw2542pcm                                    1
# 437perweek                                      1
# 380pwavail08072022                              1
# 430permonth                                     1
# 395wk                                           1
# 335pw-savetimeviewour3dtourapply                1
# 555pw                                           1
# 580perweek2520permonth                          1
# 1199perweek                                     1
# 175                                             1
# 69000perweekpw                                  1
# 36500                                           1
# 346perweek                                      1
# 808perweek                                      1
# 415pw1803pcm                                    1
# 930                                             1
# 5560perweek                                     1
# 35500                                           1
# 425wk                                           1
# 67000pw                                         1
# 500perweeknegotiable-conditionsapply            1
# 465pw2020pcm                                    1
# 34500perweek                                    1
# 330perweek1430permonth                          1
# 390perweek1695percalendarmonth                  1
# 950week                                         1
# 107500                                          1
# 150wk                                           1
# 830weekly                                       1
# 96000                                           1
# 480perweek-furnished                            1
# 440perweek1912percalendarmonth                  1
# 470wunfurnished                                 1
# 350pw1520pcm                                    1
# 715pw3107pcm                                    1
# 460week                                         1
# 500includinglawnsmowed                          1
# 66                                              1
# 900perweekunfurnished                           1
# 360perweekfullyfurnished                        1
# 30000weekly                                     1
# 63000perweek2737pcm                             1
# 680perweek2955pcm                               1
# 970weekly                                       1
# 550andfullyfurnishedoptionatextrapw             1
# 410-fullyfurnishedroom                          1
# 810                                             1
# 315perweek-singlebed                            1
# 2550perweek                                     1
# 25500perweekpw                                  1
# 425pw1846pcm                                    1
# 690pw2998pcm                                    1
# 550perweek2390pcm                               1
# 690pw                                           1
# 500wfurnished                                   1
# 880pw                                           1
# 430perweekfullyfurnished                        1
# 1147100excgst                                   1
# 139to150                                        1
# 338perweek                                      1
# 1000perweek-2dwellings                          1
# 620000perweek                                   1
# 18perweek                                       1
# 2300                                            1
# 595perweekly                                    1
# 320perweek-fullyfurnished                       1
# 61000perweek                                    1
# 72000perweek                                    1
# 1956                                            1
# 1100-1295perweek                                1
# 970pw                                           1
# 37500perweek                                    1
# 260perweekplusoutgoings                         1
# 371perweek                                      1
# 276perweek                                      1
# 39000paoutgoings                                1
# 1380week                                        1
# 500perweek-applynow                             1
# 550pw-fullyfurnished                            1
# 630pw2737pcm                                    1
# 390pw1694pcm                                    1
# 1387calendarmonthpm                             1
# 2687calendarmonth                               1
# 1387calendarmonth                               1
# 190                                             1
# 775perweekfullyfurnished                        1
# 525perweekfumished                              1
# 450perweekoutgoings                             1
# 985                                             1
# 340pw1477pcm                                    1
# 775                                             1
# 71500                                           1
# 16000                                           1
# 410perweek410                                   1
# 506                                             1
# 55000pw239000                                   1
# 850perweekpw                                    1
# 375wk                                           1
# 46500pw                                         1
# 575pw2499                                       1
# 620perweek2687pcm                               1
# 580perweek2520pcm                               1
# 670perweek2911pcm                               1
# 600perweek2600pcm                               1
# 400andfullyfurnishedoptionatextrapw             1
# 750perweekfullyfurnished                        1
# 720perweekfurnitured                            1
# 270000                                          1
# 480undrapplication                              1
# 55000pw-peacequietawaitsyou                     1
# 1430calendarmonth                               1
# 545pw2368pcm                                    1
# 650-900                                         1
# 580000                                          1
# 630wavailablenow                                1
# 700perweek3042pcm                               1
# 480pw2086pm                                     1
# 199                                             1
# 3100perweek                                     1
# 995pw4324pcm                                    1
# 440perweek1907permonth                          1
# 590pwplus2floorsofamenities                     1
# 645pw                                           1
# 150000perweek                                   1
# 450perweek-utilitiesincluded                    1
# 650perweekincludeselectricityandwater           1
# 1350pw                                          1
# 19000                                           1
# 425perweekfullyfurnished                        1
# 1650perweekleased                               1
# 1070                                            1
# 380perweekpw                                    1
# 1795perweekfullyfurnished6monthlease            1
# 625pw2716pcm                                    1
# 56000perweek-fullyfurnished                     1
# 68000perweek-fullyfurnished                     1
# 480perweek2085pcm                               1
# 831perweek                                      1
# 605                                             1
# 675-695perweek                                  1
# 490perweek-2129percalendarmonth                 1
# 320perweek1387pcm                               1
# 650pw-furnishedleasenegotiable                  1
# 665perweek-furnished                            1
# 420wk                                           1
# 89500perweek                                    1
# 660pwplus2floorsofamenities                     1
# 750pwfurnishedwithunparalleledamenities         1
# 1955percalendermonth                            1
# 3250calendarmonth                               1
# 1734calendarmonth                               1
# 2037calendarmonth                               1
# 480pw2085pcm                                    1
# 140permonth                                     1
# 54500perweek                                    1
# 3164calendarmonth                               1
# 545wk                                           1
# 230weekly                                       1
# 50000weekly                                     1
# 17500weekly                                     1
# 210000                                          1
# 84000pw                                         1
# 980pw4258pcmpw                                  1
# 570pm2477pcm                                    1
# 800perweekfullyfurnished                        1
# 835                                             1
# 705pw                                           1
# 430perweekwaterincluded                         1
# 10000perweek                                    1
# 555                                             1
# 390perweek1690pcm                               1
# 1190                                            1
# 850perweekincludinggardenmaintenance            1
# 365perweeknewprice                              1
# 35000pw                                         1
# 59500perweek                                    1
# 850perweekpoolmaintenanceincluded               1
# 730pw3172pcm                                    1
# 1999pw1564pcm                                   1
# 64500                                           1
# 301perweek                                      1
# 288                                             1
# 250perweekincludingbills                        1
# 77percalendarmonth                              1
# 1415perweek                                     1
# 51500pw                                         1
# 27500                                           1
# 805pw                                           1
# 610pw                                           1
# 125000perweek                                   1
# 560perweek-includesallbills                     1
# 1280                                            1
# 78500                                           1
# 495perweekwithac                                1
# 165000                                          1
# 1095pw4758pcm                                   1
# 2295perweek                                     1
# 1680pw                                          1
# 600pw-greatfamilyhome                           1
# 1780perweek                                     1
# 1095pw                                          1
# 55000perweekpw                                  1
# 745wk                                           1
# 5000pw                                          1
# 650perwek                                       1
# 415pw                                           1
# 910pw-stay1mth                                  1
# 819pw-stay1mth                                  1
# 450perweek1955pcm                               1
# 450perweek-furnished                            1
# 30000pw                                         1
# 2514calendarmonth                               1
# 2470calendarmonth                               1
# 1647calendarmonth                               1
# 2102calendarmonth                               1
# 380perweekincludespowerwater                    1
# 405                                             1
# 680perweek2947pcm                               1
# 205000                                          1
# 179000                                          1
# 350pwfurnished                                  1
# 3250perweek                                     1
# 114500                                          1
# 158000                                          1
# 420pw1825pm                                     1
# 400wk                                           1
# 320wk                                           1
# 65000perweekincludinggardener                   1
# 1560calendarmonth                               1
# 560perweek2433percalendarmonth                  1
# 585pw                                           1
# 430perweek-1868percalendarmonth                 1
# 500pwunderapplication                           1
# 800pwavail280225                                1
# 1733perweek                                     1
# 554perweek                                      1
# 85000pw                                         1
# 145000pw                                        1
# 1048perweek                                     1
# 880perweekpw                                    1
# 2485perweek                                     1
# 875pw                                           1
# 255000                                          1
# 935pw                                           1
# 2253calendarmonth                               1
# 1075perweek4671pcm                              1
# 580wk                                           1
# 72000pw                                         1
# 801perweek                                      1
# 5750perweek                                     1
# 575perweekpartiallyfurnished                    1
# 1950pcmincludinggst                             1
# 465week                                         1
# 52000perannumplusgst                            1
# 1561perweek                                     1
# 600onhold                                       1
# 1650weekly                                      1
# 49500-fullyfurnishedpw                          1
# 67500pw                                         1
# 1595                                            1
# 850perweek-bookforaprivateinspection            1
# 808500perweek                                   1
# 1140perweek                                     1
# 570-fullyfurnished                              1
# 56500pw245500pcm                                1
# 699wk                                           1
# 800-850perweek                                  1
# 68500perweek                                    1
# 1180wkfullyfurnished                            1
# 51500                                           1
# 720week                                         1
# 325weekac1412pcm                                1
# 2300weekly                                      1
# 795pw-whitegoodsincluded                        1
# 58000perweek-furnished                          1
# 150000pw                                        1
# 41500perweek                                    1
# 638perweek                                      1
# 1334perweek                                     1
# 722perweek                                      1
# 550pw2390pm                                     1
# 459                                             1
# 1520percalendarmonth                            1
# 82000pw                                         1
# 45500perweek                                    1
# 790perweekbillsincluded                         1
# 475perweek2064pcm                               1
# 855weekly                                       1
# 325permonthinitialbond                          1
# 900includesbillsperweek                         1
# 1392perweek                                     1
# 569perweek                                      1
# 874perweek                                      1
# 470wk                                           1
# 400-420pw                                       1
# 1300weekly                                      1
# 450wavailablenow                                1
# 400pwgardenmaintinc                             1
# 3700perweek                                     1
# 1315perweek                                     1
# 180wk                                           1
# 1800                                            1
# 74500                                           1
# 219perweek                                      1
# 1250pw5432pcm                                   1
# 225pwfurnished                                  1
# 650perweek-waterincluded                        1
# 350perweek-waterincluded                        1
# 425perweekly                                    1
# 48000perweekpw                                  1
# 310perweek-6monthleaseonly                      1
# 380negperweek                                   1
# 460perweek-fullyfurnished                       1
# 605weekly                                       1
# 919weekly                                       1
# 2050perweek                                     1
# 530perweek2297percalendarmonth                  1
# 1529pwfurnished                                 1
# 330perweekinclutilities                         1
# 1517calendarmonth                               1
# 650perweekfullyfurnished                        1
# 1740perweek                                     1
# 635                                             1
# 1900weekly                                      1
# 564perweek                                      1
# 513perweek                                      1
# 412perweek                                      1
# 25000paavailablenow                             1
# 986perweek                                      1
# 62500pw                                         1
# 5302303                                         1
# 500perweek2173percalendarmonth                  1
# 700-fullyfurnished                              1
# 775pw3368pcm                                    1
# 850pw3693pcm                                    1
# 175-270weekperbed                               1
# 720incbillsperweek                              1
# 470perweek-2042percalendarmonth                 1
# 31000weekly                                     1
# 39500pw                                         1
# 2477perweek                                     1
# 54500pw-underapplication                        1
# 582                                             1
# 630perweek-fullyfurnished-inclinternet          1
# 1160pw8wksrentfree                              1
# 196perweek                                      1
# 867perweek                                      1
# 2835perweek                                     1
# 1360perweek                                     1
# 551perweek                                      1
# 1156perweek                                     1
# 1585perweek                                     1
# 350pw1521                                       1
# 167500                                          1
# 1183pw-stay1mth                                 1
# 1400week                                        1
# 673perweek                                      1
# 1435perweek                                     1
# 950weekly                                       1
# 430pw1868pm                                     1
# 250pwfurnishedbillinclude                       1
# 845                                             1
# 2000                                            1
# 1150                                            1
# 1990perweek                                     1
# 420pwpartialfurnished                           1
# 705weekly                                       1
# 600fullyfurnished                               1
# 425includinglawnmowing                          1
# 500pwincreaseto590pwinoctober                   1
# 560perweekpw                                    1
# 20000perweek                                    1
# 440pw1911pcm                                    1
# 480pw2080pcm                                    1
# 648perweek                                      1
# 877perweek                                      1
# 880perweeksuccessfulleased                      1
# 77000perweek                                    1
# 530perweek-includes6kwsolarpvsystem             1
# 575perweek2499percalendarmonth                  1
# 33000perweek143400                              1
# 649                                             1
# 24500perweek                                    1
# 1300pw                                          1
# 1420perweek                                     1
# 1215perweek                                     1
# 5000perweek                                     1
# 1490perweek                                     1
# 1895perweek                                     1
# 460perweek-underapplication                     1
# 1095                                            1
# 730pw                                           1
# 1400pw                                          1
# 250wallbillsincludedinrent                      1
# 250pwutilitiesincluded                          1
# 1340perweek                                     1
# 1445perweek                                     1
# 1870perweek                                     1
# 399perweek                                      1
# 833perweek                                      1
# 950pw5700pcm                                    1
# 695perweekfurnished                             1
# 585weekly                                       1
# 707                                             1
# 66000pw                                         1
# 640pw2781pcm                                    1
# 110000perweek                                   1
# 1865perweek                                     1
# 45000weekly                                     1
# 994perweek                                      1
# 1042perweek                                     1
# 1035perweek                                     1
# 905perweek                                      1
# 455weekly                                       1
# 460perweekgardenmaintincluded                   1
# 750perweekfurnished                             1
# 12500pw                                         1
# 70000weekly                                     1
# 119500perweek                                   1
# 169500                                          1
# 675pwfurnished                                  1
# 2300pw9994pcm                                   1
# 800perweekpw                                    1
# 565pw                                           1
# 55000perweek-fullyfurnished                     1
# 73500                                           1
# 660permonth                                     1
# 230or280perweekincludingallbills                1
# 650tojuly2025                                   1
# 1345perweek                                     1
# 1085perweek                                     1
# 1058perweek                                     1
# 457perweek                                      1
# 330wk1430pcm                                    1
# 330pw1430pcm                                    1
# 500pw2167pcm                                    1
# 630perweekpw                                    1
# 425pw184672pcm                                  1
# 320pwunderapplication                           1
# 60pw                                            1
# 960weekly                                       1
# 710pwbrandnewstudio                             1
# 540pw2340pcm                                    1
# 310perweekincludinglawnsandgardens              1
# 437                                             1
# 270perweekallinclusive                          1
# 1640perweek                                     1
# 2086perweek                                     1
# 139000                                          1
# 659perweek                                      1
# 392perweek                                      1
# 595000perweek                                   1
# 1564perweek                                     1
# 1000pw12or3monthlease                           1
# 722                                             1
# 1116perweek                                     1
# 490wk                                           1
# 420perweek1825percalendarmonth                  1
# 400perweek1738percalendarmonth                  1
# 410perweek1782percalendarmonth                  1
# 850partlyfurnished                              1
# 44500                                           1
# 325perweekfurnished                             1
# 850wunfurnished                                 1
# 1265perweek                                     1
# 936perweek                                      1
# 5866perweek                                     1
# 89900                                           1
# 323                                             1
# 369perweek                                      1
# 414perweek                                      1
# 430perweek1868pcm                               1
# 570perweek2477permonth                          1
# 138000                                          1
# 685pw                                           1
# 600perweek2600percalendarmonth                  1
# 530perweek2297pcm                               1
# 725pw                                           1
# 745pw                                           1
# 535perweek2325pcm                               1
# 104000                                          1
# 975pw                                           1
# 1090                                            1
# 499pw                                           1
# 675pwfullyfurnished                             1
# 102500                                          1
# 2980perweek                                     1
# 950perweek-includeswaterusage                   1
# 114000                                          1
# 742perweek                                      1
# 850perweek3684pcm                               1
# 200week                                         1
# 345pw1499pm                                     1
# 980perweek-furnished                            1
# 1000perweekfurnished                            1
# 650underapplication                             1
# 78000perweekfullyfurnishedselfcontained         1
# 85                                              1
# 350perweekincludingwater                        1
# 2260calendarmonth                               1
# 650aweekgardeningwifiincluded                   1
# 530perweekfullyfurnished                        1
# 570perweekfullyfurnished                        1
# 122000                                          1
# 889perweek                                      1
# 78000perweek-fullyfurnished                     1
# 182000calendarmonth                             1
# 2297calendarmonth                               1
# 2600calendarmonth                               1
# 2384percalandarmonth                            1
# 600pweek                                        1
# 2346percalendermonth                            1
# 3850                                            1
# 578perweek                                      1
# 750perweeknotfurnished                          1
# 790pw                                           1
# 180                                             1
# 72500pw                                         1
# 849weekly                                       1
# 600furnished                                    1
# 1250pwfurnished                                 1
# 450perweekfurnished                             1
# 350perweekfurnished                             1
# 3010perweek                                     1
# 330pw1434pm                                     1
# 80                                              1
# 2540perweek                                     1
# 1154perweek                                     1
# 885weekly                                       1
# 169perweek                                      1
# 3850perweek                                     1
# 335                                             1
# 470perweek2042percalendarmonth                  1
# 356perweek                                      1
# 774perweek                                      1
# 3900perweek                                     1
# 290000                                          1
# 960                                             1
# 88000                                           1
# 430week1864pcmwaterbillsincluded                1
# 545perweek2362pcm                               1
# 690perweek2990pcm                               1
# 1100-furnishedpw                                1
# 410pweek                                        1
# 320weekac1390pcm                                1
# 689perweek                                      1
# 48000weekly                                     1
# 1090pwfurnished                                 1
# 1980                                            1
# 43000pw                                         1
# 480perweek2080percalendarmonth                  1
# 220perweekplusoutgoings                         1
# 1170perweek                                     1
# 940                                             1
# 76500                                           1
# 1275perweek5525permonth                         1
# 350perweekincludingoutgoings                    1
# 353                                             1
# 600perweek2607percalendarmonth                  1
# 500perweek2172pcm                               1
# 624                                             1
# 2500pw                                          1
# 1000perweekbothhomesfurniture                   1
# 600pw2608pcm                                    1
# 560perweek2427pcm                               1
# 550pwfurnished                                  1
# 440outgoings                                    1
# 777perweek                                      1
# 835pw                                           1
# 630andfullyfurnishedoptionatextrapw             1
# 520weekavailablenow                             1
# 600weekavailablenow                             1
# 705                                             1
# 949perweek                                      1
# 2950perweek                                     1
# 59000pw                                         1
# 1299perweek                                     1
# 470perweek-fullyfurnished                       1
# 678perweek                                      1
# 285wk                                           1
# 1200pw-stay1mth                                 1
# 500wk                                           1
# 1565perweek                                     1
# 505                                             1
# 225                                             1
# 69pw                                            1
# 655pwbonus1monthfree                            1
# 35perweek                                       1
# 62                                              1
# 620wifiand1monthfreerent                        1
# 570perweekpw                                    1
# 599pw                                           1
# 1030perweek                                     1
# 520-perweek-fullyfurnished                      1
# 3450perweek                                     1
# 980pw                                           1
# 83000pw                                         1
# 52500pw                                         1
# 416                                             1
# 84500perweek                                    1
# 46perweek                                       1
# 215perweek                                      1
# 670perweek6monthslease                          1
# 940pw                                           1
# 1785perweek                                     1
# 2750perweek                                     1
# 170to240                                        1
# 2412perweek                                     1
# 760perweekwifiincluded                          1
# 760perweek3302pcm                               1
# 510perweek2210pcm                               1
# 620wk                                           1
# 560perweek2433pcm                               1
# 780perweek3389-pcm                              1
# 550pw-freshlypainted                            1
# 320perweek1390permonth                          1
# 1220perweek                                     1
# 1330perweek                                     1
# 160pw695pcm                                     1
# 741perweek                                      1
# 520perweek2260pcm                               1
# 81000                                           1
# 290pwutilitiesincluded                          1
# 738                                             1
# 1850                                            1
# 300weekacincreaseto330fromjuly2025              1
# 3501521                                         1
# 43000pw186800pcm                                1
# 36000pw                                         1
# 2730perweek                                     1
# 1029perweek                                     1
# 838perweek                                      1
# 825pw3585pcm                                    1
# 1499perweek                                     1
# 1085pw4715pcm                                   1
# 40pw173pcm                                      1
# 697perweek                                      1
# 878perweek                                      1
# 1551perweek                                     1
# 728perweek                                      1
# 895pw                                           1
# 589pw                                           1
# 589                                             1
# 270pw1173pcm                                    1
# 710pwbonus1monthfree                            1
# 1603perweek                                     1
# 750week                                         1
# 3302perweek                                     1
# 680andfullyfurnishedoptionatextrapw             1
# 995pwnegotiable                                 1
# 530perweekinclgaswaterinternet                  1
# 495pwinclgaswater                               1
# 60000pw                                         1
# 265weekly                                       1
# 380wk                                           1
# 1700perweekfullyfurnished                       1
# 450pwavail70425                                 1
# 130                                             1
# 550pwincutilities                               1
# 1270                                            1
# 29400perweek                                    1
# 535weekly                                       1
# 1025                                            1
# 1120pw-stay1mth                                 1
# 1400pw6084pcm                                   1
# 626perweek                                      1
# 580pw-ground-floorapartment                     1
# 660weekly                                       1
# 1250                                            1
# 2253perweek                                     1
# 588perweek                                      1
# 730unlimitedwifiand1monthfreerent               1
# 709pwfurnished                                  1
# 64000perweek-fullyfurnished                     1
# 67000perweek-fullyfurnished                     1
# 820perweek-fullyfurnished                       1
# 1738perweek                                     1
# 125to190percalendarmonth                        1
# 625wk                                           1
# 1580perweek                                     1
# 81perweek                                       1
# 290weekly                                       1
# 3701608pcm                                      1
# 240weekly                                       1
# 765                                             1
# 420pw1825pcmpw                                  1
# 82000perweek-fullyfurnished                     1
# 33perweek                                       1
# 936pwbonus2monthfree                            1
# 950wifiand1monthfreerent                        1
# 19                                              1
# 150                                             1
# 850week                                         1
# 1880perweek                                     1
# 350perweekincludingutilities                    1
# 850perweekgardenerincluded                      1
# 828perweek                                      1
# 822pwbonus2monthsfree                           1
# 250weeklypw                                     1
# 350perweekgardeningincluded                     1
# 340weekfullyfurnished                           1
# 1550weekly                                      1
# 90500                                           1
# 600pwfurnished                                  1
# 36perweek                                       1
# 300perweekgardenmaintenanceincluded             1
# 470perweekincludingutilities                    1
# 809to889                                        1
# 580pw2521pcm                                    1
# 1100pw4780pcm                                   1
# 82000perweekinclpoolservicing                   1
# 550pw2173pcm                                    1
# 61000perweekfullyfurnished                      1
# 315weekly                                       1
# 958perweek                                      1
# 1375pw5975pcm                                   1
# 415weekly                                       1
# 285pw                                           1
# 480pw-savetimeviewour3dtourapply                1
# 47500perweel                                    1
# 1253perweek                                     1
# 265                                             1
# 1090weekly                                      1
# 500000                                          1
# 350-fullyfurnished                              1
# 945pw-savetimeviewour3dtourapply                1
# 36500perweek                                    1
# 315perweekpw                                    1
# 112500                                          1
# 35500perweek                                    1
# 75wcarpark                                      1
# 40perweek                                       1
# 1599perweek                                     1
# 1975perweek                                     1
# 979perweek                                      1
# 1039perweek                                     1
# 385pw1673pcm                                    1
# 435to450                                        1
# 185pwincutilitieswifi                           1
# 530fullyfurnished                               1
# 480perweekapplicationpending                    1
# 520perweek2260permonth                          1
# 55000perweekor62500pwwithpaddock                1
# 285                                             1
# 440perweek-unfurnished                          1
# 465perweekpw                                    1
# 32000pw                                         1
# 15000                                           1
# 535pw2325pcm                                    1
# 104873pcm                                       1
# 980pw4259pcm                                    1
# 410pw1782pcm                                    1
# 42000pw182500pcm                                1
# 57perweek                                       1
# 150permonth                                     1
# 74perweek                                       1
# 750perweekpw                                    1
# 615weekly                                       1
# 119500                                          1
# 890weekly                                       1
# 350000                                          1
# 1050pwstay1mth                                  1
# 1200pwfurnished                                 1
# 250month                                        1
# 495perweekfurnished                             1
# 509perweek                                      1
# 525perweek2281pcm                               1
# 450perweek1955percalendarmonthpm                1
# 1647percalendermonth                            1
# 3980perweek                                     1
# 1540perweek                                     1
# 471perweek                                      1
# 70                                              1
# 825weekly                                       1
# 400perweekincllawnmaintenance                   1
# 475perweek-fullyfurnished                       1
# 33000perweekpw                                  1
# 410perweekpw                                    1
# 34500pw                                         1
# 184                                             1
# 195000                                          1
# 76000perweek                                    1
# 420perweekfullyfurnished                        1
# 152100percalendarmonth                          1
# 550pwavailnow                                   1
# 380perweek1651percalendarmonth                  1
# 25000                                           1
# 385weekly                                       1
# 3750perweek                                     1
# 1100pw                                          1
# 35004                                           1
# 450pwbond1950                                   1
# 4702042                                         1
# 198000perweek                                   1
# 895perweek-furnished                            1
# 370pwavailnow                                   1
# 360pwavailnow                                   1
# 350pwavail80822                                 1
# 23000perweek                                    1
# 360pwavail280722                                1
# 270weekly                                       1
# 600pwwinterrates                                1
# 460perweek1999percalendarmonth                  1
# 310perweek1347permonth                          1
# 395-perweek                                     1
# 305                                             1
# 52000perweekpw                                  1
# 405weekly                                       1
# 260pwincgst                                     1
# 1020                                            1
# 455wk                                           1
# 265wk                                           1
# 4151803                                         1
# 465pw2021pcm                                    1
# 1weekrentonowner                                1
# 730wavailablenow                                1
# 44500perweek                                    1
# 33500perweek                                    1
# 265pw                                           1
# 40000weekly                                     1
# 405pw1760pcm                                    1
# 419perweek                                      2
# 549perweek                                      2
# 1230perweek                                     2
# 420week                                         2
# 205perweek                                      2
# 700perweekfurnished                             2
# 74500perweek                                    2
# 127500                                          2
# 65perweek                                       2
# 650perweek-fullyfurnished                       2
# 1000pw4345pcm                                   2
# 345pw1499pcm                                    2
# 600week                                         2
# 620pw2694pcm                                    2
# 1355perweek                                     2
# 910                                             2
# 150perweek                                      2
# 546perweek                                      2
# 185perweek                                      2
# 390pw1695pcm                                    2
# 780pw                                           2
# 64000perweek                                    2
# 840                                             2
# 480perweek2080pcm                               2
# 630perweek2730pcm                               2
# 1100weekly                                      2
# 73000pw                                         2
# 435weekly                                       2
# 710pw                                           2
# 69500pw                                         2
# 580perweek2514pcm                               2
# 550perweekpw                                    2
# 855perweek                                      2
# 260                                             2
# 375weekly                                       2
# 430perweekpw                                    2
# 380perweek1651pcm                               2
# 455                                             2
# 1500pwhigh1050pwlow                             2
# 69500perweek                                    2
# 775weekly                                       2
# 520perweek2260percalendarmonth                  2
# 261                                             2
# 300permonth                                     2
# 60                                              2
# 1400weekly                                      2
# 2250perweek                                     2
# 2600perweek                                     2
# 68500                                           2
# 455pw                                           2
# 665                                             2
# 350wk                                           2
# 615                                             2
# 51500perweek                                    2
# 130000pw                                        2
# 80000pw                                         2
# 119000                                          2
# 745pw3237pcm                                    2
# 850pw3694pcm                                    2
# 535pw                                           2
# 460pw1999pm                                     2
# 445pw1934pcm                                    2
# 990                                             2
# 347700percalendarmonth                          2
# 870weekly                                       2
# 385pw                                           2
# 230                                             2
# 970                                             2
# 53500                                           2
# 550week                                         2
# 676                                             2
# 1155perweek                                     2
# 1380perweek                                     2
# 69perweek                                       2
# 325                                             2
# 47500pw                                         2
# 56500perweek                                    2
# 1400pwfurnished                                 2
# 1005perweek                                     2
# 1200pw                                          2
# 155000                                          2
# 590pw2564pcm                                    2
# 68000perweek                                    2
# 47000pw                                         2
# 52000pw                                         2
# 42500pw                                         2
# 1120perweek                                     2
# 615pw                                           2
# 630pw2738pcm                                    2
# 500perweek2173pcm                               2
# 570pw2477pcm                                    2
# 1690perweek                                     2
# 220                                             2
# 1150pw                                          2
# 62500perweek                                    2
# 695weekly                                       2
# 3000perweek                                     2
# 400perweekpw                                    2
# 109500                                          2
# 1105perweek                                     2
# 1079perweek                                     2
# 875pw3802pcm                                    2
# 375pw1629pcm                                    2
# 300perweekincludingbills                        2
# 47500perweek                                    2
# 195pw                                           2
# ...
# 125000                                         12
# 470weekly                                      12
# 89500                                          12
# 44000perweek                                   12
# 690                                            12
# 99500                                          12
# 100000                                         12
# 39500                                          12
# 1750perweek                                    12
# 630pw                                          12
# 59000                                          12
# 240perweek                                     12
# 475weekly                                      12
# 69500                                          13
# 75000perweek                                   13
# 735perweek                                     13
# 745perweek                                     13
# 680pw                                          13
# 30000perweek                                   13
# 465                                            13
# 105000                                         13
# 785perweek                                     13
# 505perweek                                     13
# 930perweek                                     13
# 57500                                          13
# 555perweek                                     13
# 1550perweek                                    13
# 590weekly                                      14
# 440weekly                                      14
# 610                                            14
# 715perweek                                     14
# 650pw2824pcm                                   14
# 340pw                                          14
# 1000                                           14
# 78000                                          14
# 510weekly                                      14
# 475pw                                          14
# 410pw                                          14
# 50perweek                                      14
# 695                                            14
# 810perweek                                     15
# 65000perweek                                   15
# 325perweek                                     15
# 38000                                          15
# 39000perweek                                   15
# 345perweek                                     15
# 67500                                          15
# 450pw1955pcm                                   15
# 335perweek                                     15
# 67000                                          15
# 295perweek                                     16
# 2500perweek                                    16
# 575                                            16
# 395                                            16
# 43000perweek                                   16
# 52500                                          16
# 36000perweek                                   16
# 540pw                                          16
# 62500                                          16
# 320pw                                          16
# 310                                            16
# 1295perweek                                    16
# 550pw2390pcm                                   16
# 72000                                          17
# 80000                                          17
# 460weekly                                      17
# 720                                            17
# 560pw                                          17
# 500pw2173pcm                                   17
# 220perweek                                     17
# 520weekly                                      17
# 750weekly                                      17
# 480weekly                                      17
# 44000                                          18
# 580pw                                          18
# 470pw                                          18
# 350weekly                                      18
# 700weekly                                      18
# 650weekly                                      18
# 475                                            18
# 900                                            18
# 47500                                          18
# 670                                            18
# 38000perweek                                   18
# 750pw                                          19
# 95000                                          19
# 52000perweek                                   19
# 120000                                         19
# 920perweek                                     19
# 925perweek                                     19
# 200perweek                                     19
# 63000                                          19
# 46000perweek                                   19
# 380weekly                                      19
# 525                                            20
# 420weekly                                      20
# 645perweek                                     20
# 315perweek                                     20
# 39000                                          20
# 56000                                          20
# 36000                                          20
# 230perweek                                     20
# 49500                                          20
# 57000                                          20
# 665perweek                                     20
# 320                                            20
# 700pw                                          21
# 49000                                          21
# 370pw                                          21
# 680                                            21
# 1450perweek                                    21
# 975perweek                                     21
# 48000perweek                                   21
# 360pw                                          22
# 460pw                                          22
# 35000                                          22
# 625                                            22
# 260perweek                                     22
# 400weekly                                      22
# 46000                                          22
# 500weekly                                      22
# 2000perweek                                    22
# 510                                            23
# 68000                                          23
# 425                                            23
# 355perweek                                     23
# 55000perweek                                   23
# 455perweek                                     23
# 635perweek                                     23
# 62000                                          24
# 35000perweek                                   24
# 53000                                          24
# 980perweek                                     24
# 495                                            24
# 685perweek                                     24
# 350pw                                          24
# 340                                            24
# 270perweek                                     24
# 390pw                                          24
# 445perweek                                     25
# 330                                            25
# 870perweek                                     25
# 440pw                                          25
# 630                                            25
# 300                                            26
# 850                                            26
# 800                                            26
# 520pw                                          26
# 42000perweek                                   26
# 825perweek                                     26
# 840perweek                                     27
# 50000perweek                                   27
# 90000                                          27
# 59500                                          27
# 1800perweek                                    27
# 280perweek                                     28
# 40000perweek                                   28
# 860perweek                                     28
# 47000                                          28
# 990perweek                                     28
# 365perweek                                     28
# 890perweek                                     30
# 420pw                                          30
# 1600perweek                                    31
# 590                                            31
# 430pw                                          31
# 42000                                          31
# 570                                            32
# 480pw                                          32
# 110000                                         32
# 290perweek                                     32
# 60perweek                                      32
# 380pw                                          33
# 415perweek                                     33
# 490                                            34
# 410                                            34
# 600weekly                                      34
# 450weekly                                      34
# 540                                            35
# 620                                            35
# 400pw                                          35
# 43000                                          35
# 880perweek                                     36
# 40000                                          36
# 650pw                                          36
# 1400perweek                                    36
# 58000                                          37
# 48000                                          37
# 995perweek                                     37
# 310perweek                                     38
# 550weekly                                      39
# 70000                                          39
# 390                                            39
# 435perweek                                     39
# 600pw                                          39
# 560                                            39
# 360                                            40
# 45000perweek                                   40
# 1350perweek                                    41
# 615perweek                                     41
# 385perweek                                     41
# 545perweek                                     41
# 250perweek                                     41
# 875perweek                                     41
# 52000                                          42
# 750                                            43
# 830perweek                                     43
# 530                                            43
# 85000                                          46
# 565perweek                                     47
# 500pw                                          48
# 370                                            49
# 580                                            50
# 75000                                          50
# 450pw                                          51
# 1150perweek                                    51
# 460                                            52
# 440                                            52
# 350                                            52
# 895perweek                                     52
# 465perweek                                     52
# 710perweek                                     52
# 380                                            53
# 430                                            53
# 585perweek                                     53
# 1500perweek                                    54
# 760perweek                                     54
# 60000                                          54
# 775perweek                                     56
# 770perweek                                     56
# 1300perweek                                    57
# 535perweek                                     58
# 375perweek                                     58
# 515perweek                                     59
# 520                                            59
# 700                                            60
# 820perweek                                     61
# 740perweek                                     61
# 1250perweek                                    62
# 550pw                                          63
# 485perweek                                     64
# 725perweek                                     65
# 470                                            66
# 790perweek                                     68
# 420                                            71
# 1050perweek                                    74
# 480                                            74
# 425perweek                                     76
# 795perweek                                     77
# 50000                                          78
# 65000                                          78
# 45000                                          79
# 330perweek                                     82
# 320perweek                                     87
# 55000                                          89
# 650                                            90
# 395perweek                                     92
# 300perweek                                     95
# 1000perweek                                    96
# 340perweek                                     97
# 400                                           105
# 730perweek                                    107
# 600                                           107
# 690perweek                                    109
# 695perweek                                    114
# 780perweek                                    115
# 1200perweek                                   126
# 360perweek                                    127
# 370perweek                                    128
# 500                                           129
# 950perweek                                    129
# 1100perweek                                   132
# 640perweek                                    134
# 660perweek                                    134
# 675perweek                                    135
# 670perweek                                    137
# 550                                           137
# 595perweek                                    143
# 900perweek                                    144
# 610perweek                                    145
# 625perweek                                    149
# 450                                           151
# 475perweek                                    156
# 390perweek                                    157
# 410perweek                                    169
# 720perweek                                    180
# 495perweek                                    182
# 575perweek                                    185
# 525perweek                                    199
# 350perweek                                    214
# 380perweek                                    221
# 680perweek                                    237
# 510perweek                                    238
# 590perweek                                    249
# 630perweek                                    263
# 850perweek                                    266
# 490perweek                                    287
# 800perweek                                    287
# 470perweek                                    292
# 440perweek                                    294
# 430perweek                                    301
# 570perweek                                    318
# 540perweek                                    347
# 620perweek                                    351
# 420perweek                                    368
# 460perweek                                    370
# 560perweek                                    377
# 400perweek                                    428
# 700perweek                                    466
# 530perweek                                    478
# 750perweek                                    491
# 480perweek                                    503
# 580perweek                                    539
# 520perweek                                    564
# 450perweek                                    791
# 600perweek                                    817
# 650perweek                                    821
# 500perweek                                    904
# 550perweek                                   1098
# Name: count, dtype: int64

# %%
# extract numeric value from rental_price (based on the first number found)
df['price_value'] = df["rental_price"].str.extract(r"(\d+(?:\.\d+)?)").astype(float)

# %% [markdown]
# We also need a column to see if the rent is by weekly or monthly payments

# %%
freq_keywords = [
    'pw', 'perweek', 'weekly', 'p/w', 'wk', 'p.w.',
    '/wk', '/w', '/week', 'p.w',
    'permonth', 'pm', 'calendar', 'monthly', 'calender',
    'percalendarmonth', 'percalendermonth'
    ]

# %%
# Extract frequency keyword after the number
df["price_frequency"] = df["rental_price"].str.extract(r"(\d+(?:\.\d+)?)+(" + "|".join(freq_keywords) + ")", expand=False)[1]

# %%
# Map known patterns to standardized categories
df["price_frequency"] = df["price_frequency"].map({
    "pw": "weekly",
    "p.w.": "weekly",
    "perweek": "weekly",
    "weekly": "weekly",
    "p/w": "weekly",
    "wk": "weekly",
    "p.w": "weekly",
    "/wk": "weekly",
    "/w": "weekly",
    "/week": "weekly",
    "pm": "monthly",
    "permonth": "monthly",
    "calendar": "monthly",
    "calender": "monthly",
    "monthly": "monthly",
    "percalendarmonth": "monthly",
    "percalendermonth": "monthly"
})

# %%
# If price is purely numeric (digits and full stops), assume weekly
numeric_mask = df["rental_price"].str.match(r"^[\d\.]+$")
df.loc[numeric_mask & df["price_frequency"].isna(), "price_frequency"] = "weekly"

# Assign 'unknown' to unmatched entries
df["price_frequency"] = df["price_frequency"].fillna("unknown")

# Convert to categorical type
df["price_frequency"] = pd.Categorical(df["price_frequency"], categories=["weekly", "monthly", "unknown"])

# %%
df['price_frequency'].value_counts()
# Out:
# price_frequency
# weekly     28766
# unknown       87
# monthly       66
# Name: count, dtype: int64

# %%
df[df['price_frequency'] == 'unknown']['rental_price'].value_counts().sort_values()
# Out:
# rental_price
# 25000paavailablenow                    1
# 950week                                1
# 250month                               1
# 850week                                1
# 75wcarpark                             1
# 650tojuly2025                          1
# 250wallbillsincludedinrent             1
# 1380week                               1
# 325weekac1412pcm                       1
# 39000paoutgoings                       1
# 52000perannumplusgst                   1
# 720incbillsperweek                     1
# 750week                                1
# 170to240                               1
# 1400week                               1
# 570-fullyfurnished                     1
# 900includesbillsperweek                1
# 2384percalandarmonth                   1
# 520-perweek-fullyfurnished             1
# 340weekfullyfurnished                  1
# 809to889                               1
# 680andfullyfurnishedoptionatextrapw    1
# 600onhold                              1
# 1950pcmincludinggst                    1
# 950wifiand1monthfreerent               1
# 1147100excgst                          1
# 650aweekgardeningwifiincluded          1
# 320weekac1390pcm                       1
# 300weekacincreaseto330fromjuly2025     1
# 440outgoings                           1
# 620wifiand1monthfreerent               1
# 465week                                1
# 139to150                               1
# 600fullyfurnished                      1
# 430week1864pcmwaterbillsincluded       1
# 450wavailablenow                       1
# 175-270weekperbed                      1
# 425includinglawnmowing                 1
# 630andfullyfurnishedoptionatextrapw    1
# 650underapplication                    1
# 200week                                1
# 520weekavailablenow                    1
# 600weekavailablenow                    1
# 850wunfurnished                        1
# 600furnished                           1
# 850partlyfurnished                     1
# 1100-furnishedpw                       1
# 730unlimitedwifiand1monthfreerent      1
# 700-fullyfurnished                     1
# 650perwek                              1
# 400andfullyfurnishedoptionatextrapw    1
# 480undrapplication                     1
# 550andfullyfurnishedoptionatextrapw    1
# 410-fullyfurnishedroom                 1
# 720week                                1
# 49500-fullyfurnishedpw                 1
# 470wunfurnished                        1
# 630wavailablenow                       1
# 47500perweel                           1
# 460week                                1
# 500includinglawnsmowed                 1
# 650-900                                1
# 500wfurnished                          1
# 380negperweek                          1
# 250pernight-4people                    1
# 530fullyfurnished                      1
# 104873pcm                              1
# 1weekrentonowner                       1
# 730wavailablenow                       1
# 395-perweek                            1
# 450w                                   1
# 350-fullyfurnished                     1
# 435to450                               1
# 50perhour                              1
# 3701608pcm                             1
# 550week                                2
# 630week                                2
# 600week                                2
# 49500fortheseason                      2
# 420week                                2
# 560w                                   2
# Name: count, dtype: int64

# %%
# drop unknown price_frequency
df = df[df['price_frequency'] != 'unknown']

# %% [markdown]
# Now that we have a column for the actual price and a column for frequency, let's now calculate the weekly price and replace the rental price with that

# %%
# Create weekly_rent based on price_frequency
df["weekly_rent"] = df.apply(
    lambda row: row["price_value"] if row["price_frequency"] == "weekly"
    else row["price_value"] / 4 if row["price_frequency"] == "monthly"
    else None,
    axis=1
)

# Drop original columns
df = df.drop(columns=["rental_price", "price_value", "price_frequency"])

# %%
df["weekly_rent"].describe()
# Out:
# count    2.883200e+04
# mean     6.924642e+03
# std      5.663043e+04
# min      1.800000e+01
# 25%      4.700000e+02
# 50%      5.700000e+02
# 75%      7.300000e+02
# max      5.302303e+06
# Name: weekly_rent, dtype: float64

# %% [markdown]
# Let's first deal with the outliers using IQR

# %%
import numpy as np
import math as m

# Removing the outliers
def removeOutliers(dataframe, columns):
    """
    Detects and treats outliers using IQR for multiple variables in a DataFrame.
    :param dataframe: The input DataFrame
    :param columns: A list of columns to apply IQR outlier treatment
    :param n: number of records in the dataframe
    :param factor: The IQR factor to use for detecting outliers
    :return: The processed DataFrame with outliers treated
    """

    # calculate the factor based on the number of records
    factor = m.sqrt(np.log(len(dataframe))) - 0.5

    # iterate through each column to treat outliers
    for col in columns:
        # calculate Q1, Q3, and IQR
        Q3 = np.quantile(dataframe[col], 0.75)
        Q1 = np.quantile(dataframe[col], 0.25)
        IQR = Q3 - Q1

        print("IQR value for column %s is: %s" % (col, IQR))

        # determine the lower and upper range for outliers
        lower_range = Q1 - factor * IQR
        upper_range = Q3 + factor * IQR
        
        # filter dataframe to keep only rows within the IQR range
        dataframe = dataframe[(dataframe[col] >= lower_range) & (dataframe[col] <= upper_range)]
        print("After treating outliers, shape of data is: ", dataframe.shape)
    
    return dataframe

# %%
df = removeOutliers(df, ['weekly_rent'])
# Out:
# IQR value for column weekly_rent is: 260.0
# After treating outliers, shape of data is:  (25714, 40)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# Create histogram
plt.figure(figsize=(10, 6))
sns.histplot(df["weekly_rent"], bins=50, kde=True)

# Add labels and title
plt.xlabel("Weekly Rent Price (AUD)")
plt.ylabel("Count")
plt.title("Distribution of Weekly Rent Prices")
# Out:
# Text(0.5, 1.0, 'Distribution of Weekly Rent Prices')

# %%
# save intermediate df result
saved_df = df.copy()

# %%
saved_df.shape
# Out:
# (25714, 40)

# %% [markdown]
# ## Cleaning Property Features
#
# In order to answer question 2: Forecasting Rent Growth for suburbs, we need to match our scraped data's categories with provided ones from the ABS website.
#
# The ABS dataset is aggregated by number of bedrooms and property type(1-3 for flats and 1-4 for houses), as well as a separate sheet for the grand total median over suburbs.
#
# We will match that formatting with our scraped data by creating a new dataframe with each suburb as a record, and type of property + number of bedrooms for its columns. Each entry will be the median price of that combination.

# %% [markdown]
# ### Number of Bedrooms

# %%
# find records where 'bedrooms' is missing and 'property_features' doesn't have digits
missing_bedrooms_features = df[df['bedrooms'].isnull() & ~df['property_features'].str.contains('\d', na=False)]

# drop rows where bedrooms is missing and 'property_features' doesn't have digits
df = df.drop(missing_bedrooms_features.index)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_942/3890117457.py:2: SyntaxWarning: invalid escape sequence '\d'
#   missing_bedrooms_features = df[df['bedrooms'].isnull() & ~df['property_features'].str.contains('\d', na=False)]

# %%
# drop rows where property_features that do not start with a digit and bedrooms is missing
df_no_digit = df[df['property_features'].str.match(r'^\D', na=False)]
df_no_digit = df_no_digit[df_no_digit['bedrooms'].isnull()]
df = df.drop(df_no_digit.index)

# %% [markdown]
# WARNING: something weird going on here.

# %%
# see if 'bedrooms' matches the first number in 'property_features'
bedroom_pattern = r'\b(\d+),'
df['extracted_bedrooms'] = df['property_features'].str.extract(bedroom_pattern, flags=re.IGNORECASE)[0].astype(float)

# remove records where 'bedrooms' is missing and 'extracted_bedrooms' is also missing
df = df[~(df['bedrooms'].isnull() & df['extracted_bedrooms'].isnull())]

# %%
df.head()
# Out:
#        property_id bedrooms  bathrooms  car_spaces        property_type  \
# 10077   17732837.0        3        NaN         2.0            townhouse
# 10078   17744154.0        2        NaN         2.0  apartment unit flat
# 10079   17750349.0        1        NaN         1.0  apartment unit flat
# 10080   17739910.0        2        NaN         1.0            townhouse
# 10081   17751219.0        2        NaN         1.0                house
#
#        land_area property_features      suburb  postcode  year quarter  \
# 10077        NaN        3, ,2, ,2,  abbotsford      3067  2025      09
# 10078        NaN        2, ,2, ,1,  abbotsford      3067  2025      09
# 10079        NaN        1, ,1, ,1,  abbotsford      3067  2025      09
# 10080        NaN        2, ,1, ,1,  abbotsford      3067  2025      09
# 10081        NaN        2, ,1, ,−,  abbotsford      3067  2025      09
#
#        age_0_to_19  age_20_to_39  age_40_to_59  age_60_plus  \
# 10077     0.142523      0.500000      0.226636     0.130841
# 10078     0.084168      0.640712      0.200222     0.074898
# 10079     0.123570      0.334096      0.235698     0.306636
# 10080     0.174757      0.508091      0.220065     0.097087
# 10081     0.170111      0.400636      0.275040     0.154213
#
#                            agency_name       agent_name appointment_only  \
# 10077             rt edgar - northside  lily passarelli            false
# 10078        fletchers projects rental      joyee jiang            false
# 10079                       rentbetter              NaN             true
# 10080        miles real estate ivanhoe      carly tomat            false
# 10081  jellis craig richmond surrounds   nathan roberts            false
#
#        avg_days_on_market                                        description  \
# 10077                60.0  just freshly painted throughout with new winpl...
# 10078                69.0  perfectly positioned in the heart of abbotsfor...
# 10079                85.0  property id 399933 quote when calling apply he...
# 10080                32.0  first inspections hoping to be set for saturda...
# 10081                32.0  discover this spacious and beautifully appoint...
#
#        family_percentage                                      features_list  \
# 10077           0.530435  split system air consplit system heatinginterc...
# 10078           0.496448                                                NaN
# 10079           0.406250  air conditioningbalcony deckbuilt-in wardrobes...
# 10080           0.449219  air conditioningoutdoor entertainment areabuil...
# 10081           0.438492  air conditioninggarden courtyardfully fencedbu...
#
#           first_listed_date                                full_address  \
# 10077   2025-08-26t16142051      14 federation lane abbotsford vic 3067
# 10078  2025-09-02t174523157  106609 victoria street abbotsford vic 3067
# 10079  2025-09-06t225353913                         abbotsford vic 3067
# 10080   2025-09-01t10375424       42 princes street abbotsford vic 3067
# 10081   2025-09-08t12314526              45 park st abbotsford vic 3067
#
#       last_sold_date   listing_status  long_term_resident  median_rent_price  \
# 10077            NaN             live            0.422096              900.0
# 10078            NaN             live            0.441558              660.0
# 10079            NaN             live            0.491228              510.0
# 10080            NaN  recentlyupdated            0.558935              725.0
# 10081            NaN              new            0.471483              725.0
#
#        median_sold_price  number_sold  renter_percentage  \
# 10077          1350000.0         34.0           0.410405
# 10078           580000.0        187.0           0.737643
# 10079           393000.0        141.0           0.585526
# 10080          1100000.0         42.0           0.504425
# 10081          1100000.0         42.0           0.392857
#
#                                                  schools  single_percentage  \
# 10077  'clifton hill primary school' 'government' 'pr...           0.469565
# 10078  'yarra primary school' 'government' 'primary' ...           0.503552
# 10079  'sophia mundi steiner school' 'private' 'combi...           0.593750
# 10080  'abbotsford primary school' 'government' 'prim...           0.550781
# 10081  'abbotsford primary school' 'government' 'prim...           0.561508
#
#       state_abbreviation                                structured_features  \
# 10077                vic  'name' 'bath' 'category' 'indoor' 'source' 'su...
# 10078                vic  'name' 'gas' 'category' 'indoor' 'source' 'sug...
# 10079                vic  'name' 'internal laundry' 'category' 'indoor' ...
# 10080                vic  'name' 'internal laundry' 'category' 'indoor' ...
# 10081                vic  'name' 'gas' 'category' 'indoor' 'source' 'sug...
#
#       unit_number          updated_date  \
# 10077         NaN   2025-09-03t10121796
# 10078         106   2025-09-02t17452316
# 10079         NaN  2025-09-06t225353917
# 10080           4  2025-09-11t170052007
# 10081         NaN  2025-09-11t092517693
#
#                                                      url  \
# 10077  httpswwwdomaincomau14-federation-lane-abbotsfo...
# 10078  httpswwwdomaincomau106-609-victoria-street-abb...
# 10079    httpswwwdomaincomauabbotsford-vic-3067-17750349
# 10080  httpswwwdomaincomau4-2-princes-street-abbotsfo...
# 10081  httpswwwdomaincomau45-park-st-abbotsford-vic-3...
#
#                                   coordinates  weekly_rent  extracted_bedrooms
# 10077          POINT (-37.796893 144.9961565)        880.0                 3.0
# 10078         POINT (-37.8110653 145.0076834)        750.0                 2.0
# 10079  POINT (-37.80210950000001 145.0019064)        630.0                 1.0
# 10080          POINT (-37.8092053 144.999856)        650.0                 2.0
# 10081         POINT (-37.8080424 144.9939399)        750.0                 2.0

# %%
# remove records where 'extracted_bedrooms' is missing
# all these records are acreage or land
df = df[~df['extracted_bedrooms'].isnull()]

# %%
# convert 'extracted_bedrooms' to int
df['extracted_bedrooms'] = df['extracted_bedrooms'].astype(int)
df['bedrooms'] = df['bedrooms'].astype(int)

# %%
# how many records have mismatched bedrooms and extracted_bedrooms
df[df['bedrooms'] != df['extracted_bedrooms']].shape[0]
# Out:
# 11751

# %%
# fill missing bedrooms with extracted_bedrooms
df['bedrooms'].fillna(df['extracted_bedrooms'], inplace=True)
# Out:
# /tmp/ipykernel_942/1743008181.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bedrooms'].fillna(df['extracted_bedrooms'], inplace=True)

# %%
# how many records with missing bedrooms now
df['bedrooms'].isnull().sum()
# Out:
# np.int64(0)

# %%
# drop 'extracted_bedrooms' column
df = df.drop(columns=['extracted_bedrooms'])

# %% [markdown]
# ### Property Type

# %% [markdown]
# Let's begin by seeing what property types we are given

# %%
df['property_type'].value_counts()
# Out:
# property_type
# house                          13794
# apartment unit flat             8701
# townhouse                       2554
# studio                           233
# villa                             65
# new apartments off the plan       52
# acreage semi-rural                14
# semi-detached                     14
# new house land                    12
# terrace                           11
# duplex                            10
# block of units                     7
# carspace                           3
# rural                              3
# vacant land                        2
# penthouse                          1
# Name: count, dtype: int64

# %%
df['property_type'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# We need to match non house or flat properties to either house or flat
#
# We also need to drop property types which are not 'renter-friendly', or fall out of the two categories' range

# %% [markdown]
# The following will be mapped to **House**
# - House
# - Townhouse
# - Villa
# - New House & Land
# - Semi-Detached
# - Terrace
# - Duplex
#
# The following will be mapped to **Flat**
# - Apartment / Unit / Flat
# - Studio
# - New Apartments / Off the Plan
# - Penthouse
#
# The following will be dropped
# - Vacant Land
# - Carspace
# - Block of Units
# - Acreage / Semi-rural
# - Rural

# %% [markdown]
# Let's begin with cleaning property_type

# %%
# convert 'property_type' to lowercase and strip spaces
df['property_type'] = df['property_type'].str.lower()

# %%
# create a mapping dictionary
property_type_mapping = {
    "house": ["house", "new house land", "townhouse", "villa", "semi-detached", "terrace", "duplex", ],
    "flat": ["apartment unit flat", "studio", "new apartments off the plan", "penthouse"],
    "other": ["vacant land", "carspace", "block of units", "acreage semi-rural", "rural"]
}

# %%
# create a new column 'house_flat_other' based on the mapping
df["house_flat_other"] = df["property_type"].apply(
    lambda x: next((key for key, values in property_type_mapping.items() if x in values), "unknown")
)

# %%
df['house_flat_other'].value_counts()
# Out:
# house_flat_other
# house    16460
# flat      8987
# other       29
# Name: count, dtype: int64

# %% [markdown]
# ### Combine and Create New Dataframe

# %% [markdown]
# We now want to create and save a new dataframe for each bedroom and property type combo.
#
# Within each csv:
# - records will be suburb
# - columns will be year and quarter in chronological order
# - value will be the median rent

# %% [markdown]
# We will do this using pivoted median aggregation

# %%
# first convert 'quarter' to numeric
df['quarter'] = pd.to_numeric(df['quarter'], errors='coerce')

# turn 'quarter' into 1, 2, 3, 4
df['quarter'] = ((df['quarter'] - 1) // 3 + 1).astype(int)

# %%
import pandas as pd

# Step 1: Create 'bedroom_type' and 'year_quarter' columns
df["bedroom_type"] = df["bedrooms"].astype(str) + " bedroom " + df["house_flat_other"]
df["year_quarter"] = df["year"].astype(str) + "_Q" + (df["quarter"]).astype(str)

# Step 2: Loop through each bedroom_type
for btype in df["bedroom_type"].unique():
    subset = df[df["bedroom_type"] == btype]

    # Step 3: Group and aggregate median rent
    grouped = subset.groupby(["suburb", "year_quarter"])["weekly_rent"].median().reset_index()

    # Step 4: Pivot to wide format
    pivoted = grouped.pivot(index="suburb", columns="year_quarter", values="weekly_rent")

    # Step 5: Save to CSV
    os.makedirs("../../data/curated/rent_growth/", exist_ok=True)
    filepath = os.path.join("../../data/curated/rent_growth/", f"{btype}.csv")
    pivoted.to_csv(filepath)

# %% [markdown]
# # NOTE TO US!
#
# Continue preprocessing here!

# %% [markdown]
# Let's have a look at listing status as well, as if they are active, it suggests that the price may not be desirable, therefore the property may not be rented out at this price.

# %%
# what values are in 'listing_status'?
df['listing_status'].value_counts()
# Out:
# listing_status
# live               9199
# recentlyupdated    2416
# new                1766
# deposittaken         89
# leased               18
# Name: count, dtype: int64
