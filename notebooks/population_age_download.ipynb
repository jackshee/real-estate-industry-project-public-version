# %% [markdown]
# # Download for 2021 census demographic by postcode

# %%
import requests
import os
import pandas as pd
from urllib.request import urlretrieve
from urllib.error import HTTPError, URLError

# %%
# Ensure the folders are set up - from data download notebook
def create_data_folder(output_dir):
    """
    Create folders for each stage of the ETL pipeline
    :param output_dir: The base directory where the folders will be created
    """
    # set output directory
    import os
    
    # check if data directory exists, if not create it
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # create folders for each stage of the ETL pipeline
    for stage in ['landing', 'raw', 'curated', 'analysis']:
        stage_path = os.path.join(output_dir, stage)
        if not os.path.exists(stage_path):
            os.makedirs(stage_path)

# %%
# puts the landing, raw, curated into data
create_data_folder('../data')

# %%
# create the directory for the landing demographic data if it doesn't exist
population_by_postcode_directory = '../data/landing/population_by_postcode'
os.makedirs(population_by_postcode_directory, exist_ok=True)

# %%
# open the vic_suburbs_postcodes
postcodes_df = pd.read_csv("../data/geo/vic_suburbs_postcodes.csv")

# %%
# URL template for moving annual rent by suburb
used_postcodes = []
for postcode in postcodes_df["postcode"]:
    AREA_CODE = f"POA{postcode}"
    URL_TEMPLATE = f"https://abs.gov.au/census/find-census-data/community-profiles/2021/{AREA_CODE}/download/GCP_{AREA_CODE}.xlsx"
    
    # generate output file path
    output_file_path = f"{population_by_postcode_directory}/{AREA_CODE}_population.xlsx"
    
    # check if output file already exists
    if not os.path.exists(output_file_path):
        # download postcode data with exception handling
        try:
            urlretrieve(URL_TEMPLATE, output_file_path)
            print(f"✅ File downloaded and saved to {output_file_path}")
            used_postcodes.append(postcode)
        except Exception as e:
            print(f"❌ Unexpected error for postcode {postcode}: {e}")

    else:
        print(f"File already exists at {output_file_path}")
# Out:
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3000_population.xlsx
# ❌ Unexpected error for postcode 3001: HTTP Error 504: Gateway Time-out
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3002_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3003_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3004_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3004_population.xlsx
# ❌ Unexpected error for postcode 3005: HTTP Error 504: Gateway Time-out
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3006_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3006_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3008_population.xlsx
# ❌ Unexpected error for postcode 3010: HTTP Error 504: Gateway Time-out
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3011_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3011_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3011_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3012_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3012_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3012_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3012_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3012_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3012_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3013_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3013_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3015_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3015_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3015_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3016_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3016_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3018_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3018_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3019_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3019_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3019_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3020_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3020_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3020_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3020_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3020_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3021_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3021_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3021_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3021_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3022_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3022_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3023_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3023_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3023_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3023_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3023_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3023_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3023_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3024_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3024_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3024_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3025_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3025_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3025_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3026_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3027_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3028_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3028_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3028_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3029_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3029_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3029_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3030_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3030_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3030_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3030_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3030_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3030_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3031_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3031_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3032_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3032_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3032_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3032_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3033_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3034_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3036_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3036_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3037_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3037_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3037_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3037_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3037_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3038_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3038_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3038_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3038_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3039_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3040_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3040_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3040_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3041_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3041_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3041_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3041_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3042_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3042_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3042_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3043_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3043_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3043_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3044_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3044_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3045_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3046_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3046_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3046_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3047_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3047_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3047_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3048_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3048_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3049_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3049_population.xlsx
# ❌ Unexpected error for postcode 3050: HTTP Error 504: Gateway Time-out
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3051_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3051_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3052_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3052_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3053_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3053_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3054_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3054_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3055_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3055_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3055_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3055_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3056_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3056_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3056_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3057_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3057_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3057_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3058_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3058_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3058_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3058_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3058_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3059_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3060_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3060_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3060_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3061_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3062_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3063_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3063_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3064_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3064_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3064_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3064_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3064_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3065_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3066_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3066_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3067_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3068_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3068_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3070_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3070_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3071_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3072_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3072_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3072_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3072_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3072_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3072_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3072_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3073_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3073_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3073_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3073_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3073_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3074_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3075_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3075_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3076_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3076_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3078_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3078_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3079_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3079_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3079_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3081_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3081_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3081_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3081_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3082_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3083_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3083_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3083_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3084_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3084_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3084_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3084_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3084_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3085_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3085_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3085_population.xlsx
# ❌ Unexpected error for postcode 3086: HTTP Error 504: Gateway Time-out
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3087_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3087_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3088_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3088_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3088_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3089_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3090_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3091_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3093_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3094_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3095_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3095_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3095_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3096_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3097_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3097_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3097_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3099_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3099_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3099_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3099_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3099_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3101_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3101_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3102_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3103_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3103_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3104_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3104_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3105_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3105_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3106_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3107_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3108_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3109_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3109_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3109_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3109_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3111_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3113_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3113_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3114_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3115_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3116_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3121_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3121_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3121_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3121_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3121_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3121_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3121_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3122_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3122_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3122_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3122_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3122_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3123_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3123_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3124_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3124_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3124_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3124_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3124_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3124_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3125_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3125_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3125_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3126_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3126_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3127_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3127_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3127_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3128_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3128_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3128_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3128_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3128_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3129_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3129_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3129_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3130_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3130_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3130_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3130_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3131_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3131_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3131_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3132_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3132_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3132_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3133_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3133_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3134_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3134_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3134_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3134_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3134_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3135_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3135_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3135_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3136_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3136_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3136_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3136_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3137_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3137_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3138_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3139_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3139_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3139_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3139_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3139_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3139_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3139_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3139_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3139_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3139_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3140_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3141_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3141_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3141_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3142_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3142_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3143_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3143_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3144_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3144_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3144_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3145_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3145_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3145_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3145_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3145_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3145_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3146_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3147_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3147_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3148_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3148_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3148_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3148_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3149_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3149_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3149_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3150_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3150_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3150_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3151_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3151_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3152_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3152_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3152_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3152_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3153_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3153_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3154_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3155_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3156_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3156_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3156_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3156_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3156_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3158_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3159_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3159_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3160_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3160_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3160_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3160_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3161_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3161_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3162_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3162_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3162_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3163_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3163_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3163_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3163_population.xlsx
# ❌ Unexpected error for postcode 3164: HTTP Error 504: Gateway Time-out
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3165_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3165_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3166_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3166_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3166_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3166_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3167_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3168_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3168_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3169_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3169_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3170_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3170_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3171_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3171_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3172_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3172_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3173_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3174_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3174_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3174_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3175_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3175_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3175_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3175_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3175_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3175_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3175_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3177_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3177_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3178_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3179_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3180_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3181_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3181_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3181_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3182_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3182_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3182_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3183_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3183_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3184_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3184_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3185_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3185_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3185_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3186_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3186_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3186_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3186_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3187_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3187_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3188_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3188_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3188_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3189_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3189_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3189_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3190_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3191_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3192_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3192_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3192_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3192_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3193_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3193_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3193_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3193_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3194_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3194_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3194_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3195_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3195_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3195_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3195_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3195_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3195_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3195_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3196_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3196_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3196_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3196_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3197_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3197_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3198_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3198_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3199_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3199_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3199_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3199_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3199_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3199_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3200_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3200_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3201_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3202_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3204_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3204_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3204_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3204_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3205_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3205_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3206_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3206_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3207_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3207_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3211_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3212_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3212_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3212_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3214_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3214_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3214_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3215_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3215_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3215_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3215_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3215_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3215_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3215_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3216_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3216_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3216_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3216_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3216_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3216_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3216_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3216_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3216_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3217_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3218_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3218_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3218_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3219_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3219_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3219_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3219_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3219_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3219_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3220_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3220_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3220_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3220_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3221_population.xlsx
# ...
# File already exists at ../data/landing/population_by_postcode/POA3945_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3946_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3950_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3950_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3950_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3950_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3950_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3951_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3951_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3951_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3951_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3951_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3951_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3951_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3951_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3953_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3954_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3956_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3956_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3956_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3956_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3956_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3956_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3956_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3956_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3956_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3957_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3958_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3959_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3959_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3959_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3960_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3962_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3962_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3962_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3962_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3962_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3964_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3965_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3966_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3966_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3966_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3967_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3971_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3975_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3975_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3976_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3977_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3977_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3977_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3977_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3977_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3977_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3977_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3977_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3977_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3977_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3977_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3978_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3978_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3978_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3979_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3979_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3979_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3980_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3980_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3980_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3981_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3981_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3981_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3981_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3981_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3981_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3981_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3984_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3987_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3988_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3988_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3988_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3988_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3990_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3991_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3992_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3992_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3992_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3992_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3995_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3995_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3995_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3995_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3995_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3995_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3995_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3995_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3995_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3995_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3995_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3995_population.xlsx
# ✅ File downloaded and saved to ../data/landing/population_by_postcode/POA3996_population.xlsx
# File already exists at ../data/landing/population_by_postcode/POA3996_population.xlsx
# ❌ Unexpected error for postcode 8001: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8002: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8004: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8005: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8006: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8009: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8010: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8011: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8045: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8051: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8060: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8061: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8066: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8069: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8070: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8071: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8102: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8103: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8107: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8108: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8111: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8120: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8205: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8383: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8386: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8388: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8390: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8393: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8394: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8396: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8399: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8576: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8627: HTTP Error 404: Not Found
# ❌ Unexpected error for postcode 8873: HTTP Error 404: Not Found

# %% [markdown]
# # open and format the excel sheets into flat csvs
#
#
# Only doing for selected sheets - can add more

# %%
selected_sheets = ["G02", "G04", "G17", "G33", "G34", 
                   "G36", "G40", "G49", "G50", "G56", "G60", "G62"]
# so far only made csvs for the median data - G02 and population breakdown - G04

# %%
def excel_to_csv(file_path, selected_sheets, AREA_CODE):
    # creates flat csvs for the data stored in multisheet excel documents
    for sheet in selected_sheets:
        df = pd.read_excel(file_path, sheet_name=sheet, header=None)
        if sheet == "G02":
            
            # Left side table (col 0 = name, col 1 = value)
            left = df[[0, 1]].dropna().rename(columns={0: "Statistic", 1: "Value"})
            
            # Right side table (col 3 = name, col 4 = value)
            right = df[[3, 4]].dropna().rename(columns={3: "Statistic", 4: "Value"})
            
            # Combine both
            g02_cleaned = pd.concat([left, right], ignore_index=True)
            # add sheet identifier
            g02_cleaned["Sheet"] = sheet
            #print(g02_cleaned)

            # save the csv if it doesnt already exisit
            if not os.path.exists(f"../data/landing/population_by_postcode/{AREA_CODE}_median_stats.csv"):
                g02_cleaned.to_csv(f"../data/landing/population_by_postcode/{AREA_CODE}_median_stats.csv", index=False)
        elif sheet == "G04":
            # Find where "Age (years):" appears → start of table
            start_row = df.index[df.iloc[:,0].astype(str).str.contains("Age", na=False)].tolist()[0] + 1
            
            # Slice everything below that row
            table = df.iloc[start_row:, :]
            
            # Define the 3 blocks of columns (start_col, end_col)
            blocks = [(0, 3), (5, 8), (10, 13)]
            
            persons_dfs = []
            for start, end in blocks:
                temp = table.iloc[:, start:end+1].copy()
                temp.columns = ["Age group", "Males", "Females", "Persons"]
            
                # Drop rows where both Age group and Persons are empty
                temp = temp.dropna(subset=["Age group", "Persons"], how="any")
            
                # Keep only the relevant columns
                persons_dfs.append(temp[["Age group", "Persons"]])
            
            # Combine all blocks vertically
            persons_only = pd.concat(persons_dfs, ignore_index=True)

            # Reset index
            g04_cleaned = persons_only.reset_index(drop=True)

            # save the csv if it does not already exisit
            #if not os.path.exists(f"../data/landing/population_by_postcode/{AREA_CODE}_population_breakdown.csv"):
               # g04_cleaned.to_csv(f"../data/landing/population_by_postcode/{AREA_CODE}_population_breakdown.csv", 
                          #         index=False)
            g04_cleaned.to_csv(f"../data/landing/population_by_postcode/{AREA_CODE}_population_breakdown.csv", 
                               index=False)

# %%
for postcode in used_postcodes:
    AREA_CODE = f"POA{postcode}"
    file_path = f"{population_by_postcode_directory}/{AREA_CODE}_population.xlsx"
    excel_to_csv(file_path, selected_sheets, AREA_CODE)
