# %% [markdown]
# # Download for 2021 census demographic by suburb

# %%
import requests
import os
import re
import pandas as pd
import glob

from urllib.request import urlretrieve
from urllib.error import HTTPError, URLError

# %%
# Ensure the folders are set up - from data download notebook
def create_data_folder(output_dir):
    """
    Create folders for each stage of the ETL pipeline
    :param output_dir: The base directory where the folders will be created
    """
    # set output directory
    import os
    
    # check if data directory exists, if not create it
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # create folders for each stage of the ETL pipeline
    for stage in ['landing', 'raw', 'curated', 'analysis']:
        stage_path = os.path.join(output_dir, stage)
        if not os.path.exists(stage_path):
            os.makedirs(stage_path)

# %%
# puts the landing, raw, curated into data
create_data_folder('../data')

# %% [markdown]
# # SAL codes
# 20001 - 22944

# %%
# create the directory for the landing demographic data if it doesn't exist
population_by_suburb_directory = '../data/landing/population_by_suburb'
os.makedirs(population_by_suburb_directory, exist_ok=True)

# %%
# store SAL codes for suburbs that do not have data available
no_data = []
for i in range(20001, 22945):
    SAL_CODE = f"SAL{i}"
    URL_TEMPLATE = f"https://abs.gov.au/census/find-census-data/community-profiles/2021/{SAL_CODE}/download/GCP_{SAL_CODE}.xlsx"
    # generate output file path
    output_file_path = f"{population_by_suburb_directory}/{SAL_CODE}_population.xlsx"
    
    # check if output file already exists
    if not os.path.exists(output_file_path):
        # download postcode data with exception handling
        try:
            urlretrieve(URL_TEMPLATE, output_file_path)
            #print(f"✅ File downloaded and saved to {output_file_path}")
        except Exception as e:
            print(f"❌ Unexpected error for SAL {i}: {e}")
            # some Suburbs have no data available
            no_data.append(i)
    else:
        print(f"File already exists at {output_file_path}")
# Out:
# ❌ Unexpected error for SAL 20001: HTTP Error 504: Gateway Time-out
# File already exists at ../data/landing/population_by_suburb/SAL20002_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20003_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20004_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20005_population.xlsx
# ❌ Unexpected error for SAL 20006: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20007_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20008_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20009_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20010_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20011_population.xlsx
# ❌ Unexpected error for SAL 20012: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20013_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20014_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20015_population.xlsx
# ❌ Unexpected error for SAL 20016: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20017_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20018_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20019_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20020_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20021_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20022_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20023_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20024_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20025_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20026_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20027_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20028_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20029_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20030_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20031_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20032_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20033_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20034_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20035_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20036_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20037_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20038_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20039_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20040_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20041_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20042_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20043_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20044_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20045_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20046_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20047_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20048_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20049_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20050_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20051_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20052_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20053_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20054_population.xlsx
# ❌ Unexpected error for SAL 20055: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20056_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20057_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20058_population.xlsx
# ❌ Unexpected error for SAL 20059: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 20060: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20061_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20062_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20063_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20064_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20065_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20066_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20067_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20068_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20069_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20070_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20071_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20072_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20073_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20074_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20075_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20076_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20077_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20078_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20079_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20080_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20081_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20082_population.xlsx
# ❌ Unexpected error for SAL 20083: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 20084: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20085_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20086_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20087_population.xlsx
# ❌ Unexpected error for SAL 20088: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20089_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20090_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20091_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20092_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20093_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20094_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20095_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20096_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20097_population.xlsx
# ❌ Unexpected error for SAL 20098: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20099_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20100_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20101_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20102_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20103_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20104_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20105_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20106_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20107_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20108_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20109_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20110_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20111_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20112_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20113_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20114_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20115_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20116_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20117_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20118_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20119_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20120_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20121_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20122_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20123_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20124_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20125_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20126_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20127_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20128_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20129_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20130_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20131_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20132_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20133_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20134_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20135_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20136_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20137_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20138_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20139_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20140_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20141_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20142_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20143_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20144_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20145_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20146_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20147_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20148_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20149_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20150_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20151_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20152_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20153_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20154_population.xlsx
# ❌ Unexpected error for SAL 20155: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20156_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20157_population.xlsx
# ❌ Unexpected error for SAL 20158: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20159_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20160_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20161_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20162_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20163_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20164_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20165_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20166_population.xlsx
# ❌ Unexpected error for SAL 20167: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20168_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20169_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20170_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20171_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20172_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20173_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20174_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20175_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20176_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20177_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20178_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20179_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20180_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20181_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20182_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20183_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20184_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20185_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20186_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20187_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20188_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20189_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20190_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20191_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20192_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20193_population.xlsx
# ❌ Unexpected error for SAL 20194: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20195_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20196_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20197_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20198_population.xlsx
# ❌ Unexpected error for SAL 20199: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20200_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20201_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20202_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20203_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20204_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20205_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20206_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20207_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20208_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20209_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20210_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20211_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20212_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20213_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20214_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20215_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20216_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20217_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20218_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20219_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20220_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20221_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20222_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20223_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20224_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20225_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20226_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20227_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20228_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20229_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20230_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20231_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20232_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20233_population.xlsx
# ❌ Unexpected error for SAL 20234: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20235_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20236_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20237_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20238_population.xlsx
# ❌ Unexpected error for SAL 20239: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20240_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20241_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20242_population.xlsx
# ❌ Unexpected error for SAL 20243: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20244_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20245_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20246_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20247_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20248_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20249_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20250_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20251_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20252_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20253_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20254_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20255_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20256_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20257_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20258_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20259_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20260_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20261_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20262_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20263_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20264_population.xlsx
# ❌ Unexpected error for SAL 20265: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20266_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20267_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20268_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20269_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20270_population.xlsx
# ❌ Unexpected error for SAL 20271: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20272_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20273_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20274_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20275_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20276_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20277_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20278_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20279_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20280_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20281_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20282_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20283_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20284_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20285_population.xlsx
# ❌ Unexpected error for SAL 20286: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 20287: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20288_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20289_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20290_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20291_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20292_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20293_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20294_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20295_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20296_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20297_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20298_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20299_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20300_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20301_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20302_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20303_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20304_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20305_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20306_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20307_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20308_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20309_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20310_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20311_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20312_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20313_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20314_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20315_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20316_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20317_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20318_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20319_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20320_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20321_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20322_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20323_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20324_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20325_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20326_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20327_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20328_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20329_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20330_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20331_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20332_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20333_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20334_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20335_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20336_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20337_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20338_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20339_population.xlsx
# ❌ Unexpected error for SAL 20340: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20341_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20342_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20343_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20344_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20345_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20346_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20347_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20348_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20349_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20350_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20351_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20352_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20353_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20354_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20355_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20356_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20357_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20358_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20359_population.xlsx
# ❌ Unexpected error for SAL 20360: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20361_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20362_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20363_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20364_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20365_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20366_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20367_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20368_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20369_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20370_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20371_population.xlsx
# ❌ Unexpected error for SAL 20372: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20373_population.xlsx
# ❌ Unexpected error for SAL 20374: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20375_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20376_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20377_population.xlsx
# ❌ Unexpected error for SAL 20378: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 20379: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20380_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20381_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20382_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20383_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20384_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20385_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20386_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20387_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20388_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20389_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20390_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20391_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20392_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20393_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20394_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20395_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20396_population.xlsx
# ❌ Unexpected error for SAL 20397: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20398_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20399_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20400_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20401_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20402_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20403_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20404_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20405_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20406_population.xlsx
# ❌ Unexpected error for SAL 20407: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20408_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20409_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20410_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20411_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20412_population.xlsx
# ❌ Unexpected error for SAL 20413: HTTP Error 504: Gateway Time-out
# File already exists at ../data/landing/population_by_suburb/SAL20414_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20415_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20416_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20417_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20418_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20419_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20420_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20421_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20422_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20423_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20424_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20425_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20426_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20427_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20428_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20429_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20430_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20431_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20432_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20433_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20434_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20435_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20436_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20437_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20438_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20439_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20440_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20441_population.xlsx
# ❌ Unexpected error for SAL 20442: HTTP Error 504: Gateway Time-out
# File already exists at ../data/landing/population_by_suburb/SAL20443_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20444_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20445_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20446_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20447_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20448_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20449_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20450_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20451_population.xlsx
# ❌ Unexpected error for SAL 20452: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20453_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20454_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20455_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20456_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20457_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20458_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20459_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20460_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20461_population.xlsx
# ❌ Unexpected error for SAL 20462: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20463_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20464_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20465_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20466_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20467_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20468_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20469_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20470_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20471_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20472_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20473_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20474_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20475_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20476_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20477_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20478_population.xlsx
# ❌ Unexpected error for SAL 20479: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20480_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20481_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20482_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20483_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20484_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20485_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20486_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20487_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20488_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20489_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20490_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20491_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20492_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20493_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20494_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20495_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20496_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20497_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20498_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20499_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20500_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20501_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20502_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20503_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20504_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20505_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20506_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20507_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20508_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20509_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20510_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20511_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20512_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20513_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20514_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20515_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20516_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20517_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20518_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20519_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20520_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20521_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20522_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20523_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20524_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20525_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20526_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20527_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20528_population.xlsx
# ❌ Unexpected error for SAL 20529: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 20530: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20531_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20532_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20533_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20534_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20535_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20536_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20537_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20538_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20539_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20540_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20541_population.xlsx
# ❌ Unexpected error for SAL 20542: HTTP Error 504: Gateway Time-out
# File already exists at ../data/landing/population_by_suburb/SAL20543_population.xlsx
# ❌ Unexpected error for SAL 20544: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20545_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20546_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20547_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20548_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20549_population.xlsx
# ❌ Unexpected error for SAL 20550: HTTP Error 504: Gateway Time-out
# File already exists at ../data/landing/population_by_suburb/SAL20551_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20552_population.xlsx
# ❌ Unexpected error for SAL 20553: HTTP Error 504: Gateway Time-out
# File already exists at ../data/landing/population_by_suburb/SAL20554_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20555_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20556_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20557_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20558_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20559_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20560_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20561_population.xlsx
# ❌ Unexpected error for SAL 20562: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL20563_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20564_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20565_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20566_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20567_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20568_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20569_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20570_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20571_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20572_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20573_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20574_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20575_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL20576_population.xlsx
# ...
# File already exists at ../data/landing/population_by_suburb/SAL21326_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21327_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21328_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21329_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21330_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21331_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21332_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21333_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21334_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21335_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21336_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21337_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21338_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21339_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21340_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21341_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21342_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21343_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21344_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21345_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21346_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21347_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21348_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21349_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21350_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21351_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21352_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21353_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21354_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21355_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21356_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21357_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21358_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21359_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21360_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21361_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21362_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21363_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21364_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21365_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21366_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21367_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21368_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21369_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21370_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21371_population.xlsx
# ❌ Unexpected error for SAL 21372: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL21373_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21374_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21375_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21376_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21377_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21378_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21379_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21380_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21381_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21382_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21383_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21384_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21385_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21386_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21387_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21388_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21389_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21390_population.xlsx
# ❌ Unexpected error for SAL 21391: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL21392_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21393_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21394_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21395_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21396_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21397_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21398_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21399_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21400_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21401_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21402_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21403_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21404_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21405_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21406_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21407_population.xlsx
# ❌ Unexpected error for SAL 21408: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21409: HTTP Error 404: Not Found
# File already exists at ../data/landing/population_by_suburb/SAL21410_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21411_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21412_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21413_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21414_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21415_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21416_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21417_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21418_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21419_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21420_population.xlsx
# File already exists at ../data/landing/population_by_suburb/SAL21421_population.xlsx
# ❌ Unexpected error for SAL 21422: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21423: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21431: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21432: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21433: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21445: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21446: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21448: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21478: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21494: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21498: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21499: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21518: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21525: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21598: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21600: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21607: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21610: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21616: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21638: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21666: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21699: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21700: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21704: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21720: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21730: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21747: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21752: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21764: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21766: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21768: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21773: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21777: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21785: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21789: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21811: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21812: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21876: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21905: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21913: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21945: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21987: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21990: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 21995: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22003: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22004: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22063: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22076: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22089: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22090: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22116: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22132: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22157: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22162: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22166: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22167: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22168: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22189: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22196: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22200: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22205: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22218: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22231: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22237: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22259: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22267: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22273: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22300: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22324: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22358: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22363: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22368: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22390: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22402: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22406: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22407: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22411: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22416: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22434: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22435: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22442: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22492: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22495: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22505: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22515: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22524: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22527: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22539: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22542: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22549: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22556: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22557: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22560: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22561: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22590: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22595: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22609: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22641: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22642: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22652: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22654: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22658: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22659: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22660: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22677: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22679: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22682: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22694: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22725: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22731: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22747: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22790: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22796: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22806: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22809: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22810: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22817: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22827: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22828: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22849: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22865: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22866: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22867: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22868: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22871: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22872: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22878: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22895: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22905: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22923: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22936: HTTP Error 404: Not Found
# ❌ Unexpected error for SAL 22944: HTTP Error 404: Not Found

# %% [markdown]
# # create csv downloads for sheets of interest

# %%
selected_sheets = ["G02", "G04", "G17", "G33", 
                   "G36", "G49", "G60"]

# %%
# function to extract the suburb name from the localities excel spreadsheet
def extract_suburb_name(excel_data):
    # suburb info is always in row 2, first column
    cell_value = str(df.iloc[1, 0])
    
    # regex: capture everything before (SALxxxxx)
    match = re.search(r"(.+?)\s+\(SAL\d+\)", cell_value)
    if match:
        suburb = match.group(1).strip()
        
        return suburb

# %%
def excel_to_csv(file_path, selected_sheets, SAL_CODE, suburb):
    # creates flat csvs for the data stored in multisheet excel documents
    for sheet in selected_sheets:
        df = pd.read_excel(file_path, sheet_name=sheet, header=None)
        if sheet == "G02":
            
            # Left side table (col 0 = name, col 1 = value)
            left = df[[0, 1]].dropna().rename(columns={0: "Statistic", 1: "Value"})
            
            # Right side table (col 3 = name, col 4 = value)
            right = df[[3, 4]].dropna().rename(columns={3: "Statistic", 4: "Value"})
            
            # Combine both
            g02_cleaned = pd.concat([left, right], ignore_index=True)
            # add sheet identifier
            g02_cleaned["Suburb"] = suburb
            #print(g02_cleaned)

            # save the csv if it doesnt already exisit
            if not os.path.exists(f"../data/landing/population_by_suburb/{SAL_CODE}_median_stats.csv"):
                g02_cleaned.to_csv(f"../data/landing/population_by_suburb/{SAL_CODE}_median_stats.csv", index=False)
        elif sheet == "G04":
            # Find where "Age (years):" appears → start of table
            start_row = df.index[df.iloc[:,0].astype(str).str.contains("Age", na=False)].tolist()[0] + 1
            
            # Slice everything below that row
            table = df.iloc[start_row:, :]
            
            # Define the 3 blocks of columns (start_col, end_col)
            blocks = [(0, 3), (5, 8), (10, 13)]
            
            persons_dfs = []
            for start, end in blocks:
                temp = table.iloc[:, start:end+1].copy()
                temp.columns = ["Age group", "Males", "Females", "Persons"]
            
                # Drop rows where both Age group and Persons are empty
                temp = temp.dropna(subset=["Age group", "Persons"], how="any")
            
                # Keep only the relevant columns
                persons_dfs.append(temp[["Age group", "Persons"]])
            
            # Combine all blocks vertically
            persons_only = pd.concat(persons_dfs, ignore_index=True)

            # Reset index
            g04_cleaned = persons_only.reset_index(drop=True)
        
            # add sheet identifier
            g04_cleaned["Suburb"] = suburb
            # save the csv if it does not already exisit
            if not os.path.exists(f"../data/landing/population_by_suburb/{SAL_CODE}_population_breakdown.csv"):
                g04_cleaned.to_csv(f"../data/landing/population_by_suburb/{SAL_CODE}_population_breakdown.csv", 
                                   index=False)
        elif sheet == "G17":
            start_row = df.index[df.iloc[:,1].astype(str).str.contains("PERSONS", na=False)].tolist()[0] + 1
            end_row = df.index[df.iloc[:,0].astype(str).str.contains("This table", na=False)].tolist()[0] - 1
            # Slice everything between these rows
            g17_cleaned = df.iloc[start_row + 1:end_row, :]
            g17_cleaned.columns = ["Price Range", "15-19", "20-24", "25-34", "35-44", "45-54", "55-64", 
                             "65-74", "75-84", "85+", "Total"]
            # drop empty row
            g17_cleaned = g17_cleaned.dropna(subset = ["Price Range"])

            # add suburb name
            g17_cleaned["Suburb"] = suburb
            # save the csv if it does not already exisit
            if not os.path.exists(f"../data/landing/population_by_suburb/{SAL_CODE}_personal_income.csv"):
                g17_cleaned.to_csv(f"../data/landing/population_by_suburb/{SAL_CODE}_personal_income.csv", 
                                   index=False)
        elif sheet == "G33":
            start_row = df.index[df.iloc[:,0].astype(str).str.contains("Negative", na=False)].tolist()[0] + 1
            end_row = df.index[df.iloc[:,0].astype(str).str.contains("Total", na=False)].tolist()[0] + 1

            # Slice everything between these rows
            g33_cleaned = df.iloc[start_row + 1:end_row, :]
            g33_cleaned.columns = ["Income", "Family Households", "Non-family Households", "Total"]

            # drop empty rows
            g33_cleaned = g33_cleaned.dropna(subset = ["Income"])
            # add suburb name
            g33_cleaned["Suburb"] = suburb

            # save the csv if it does not already exisit
            if not os.path.exists(f"../data/landing/population_by_suburb/{SAL_CODE}_household_income.csv"):
                g33_cleaned.to_csv(f"../data/landing/population_by_suburb/{SAL_CODE}_household_income.csv", 
                                   index=False)
        elif sheet == "G36":
            # Find the start and end of the table
            start_idx = df[df[0].str.contains("Occupied private dwellings", na=False)].index[0]
            end_idx = df[df[0].str.contains("Total private dwellings", na=False)].index[0]
            
            # Extract only the table rows
            table_df = df.iloc[start_idx:end_idx + 1, :3]  # first 3 columns (Description, Dwellings, Persons)
            
            # Set proper column names
            table_df.columns = ["Dwelling Type", "Dwellings", "Persons"]
            
            # Remove empty rows
            table_df = table_df.dropna(subset=["Dwelling Type"])

            # Drop "Occupied private dwellings:" header row
            table_df = table_df.drop(table_df[table_df["Dwelling Type"] == 
                                     "Occupied private dwellings:"].index).reset_index(drop=True)
            
            current_section = None
            new_labels = []
            
            # Define the "global totals" that should not be prefixed
            global_totals = [
                "Total occupied private dwellings",
                "Unoccupied private dwellings",
                "Total private dwellings",
                "Dwelling structure not stated"
            ]
            
            for val in table_df["Dwelling Type"]:
                if pd.isna(val):
                    new_labels.append(val)
                elif isinstance(val, str) and val.endswith(":"):
                    # Section header
                    current_section = val.replace(":", "")
                    new_labels.append(None)
                elif val == "Total":
                    # Totals inside a section
                    new_labels.append(f"{current_section} - Total")
                elif val in global_totals:
                    # Reset section for these
                    current_section = None
                    new_labels.append(val)
                else:
                    # Normal row
                    if current_section:
                        new_labels.append(f"{current_section} - {val}")
                    else:
                        new_labels.append(val)
            
            table_df["Dwelling Type"] = new_labels
            g36_cleaned = table_df.dropna(subset=["Dwelling Type"]).reset_index(drop=True)
            g36_cleaned["Suburb"] = suburb
             # save the csv if it does not already exisit
            if not os.path.exists(f"../data/landing/population_by_suburb/{SAL_CODE}_dwelling_structure.csv"):
                g36_cleaned.to_csv(f"../data/landing/population_by_suburb/{SAL_CODE}_dwelling_structure.csv", 
                                   index=False)

            
        
        elif sheet == "G49":
            start_row = df.index[df.iloc[:,1].astype(str).str.contains("PERSONS", na=False)].tolist()[0] + 1
            end_row = df.index[df.iloc[:,0].astype(str).str.contains("This table", na=False)].tolist()[0] - 1
            # Slice everything between these rows
            g49_cleaned = df.iloc[start_row + 1:end_row, :]
            g49_cleaned.columns = ["Highest Education Level", "15-24", "25-34", "35-44", "45-54", "55-64", 
                             "65-74", "75-84", "85+", "Total"]
            # drop empty row
            g49_cleaned = g49_cleaned.dropna(subset = ["Highest Education Level"]).reset_index(drop = True)
            # drop certificate header and total rows
            g49_cleaned = g49_cleaned.drop([4, 8])
            
            # add suburb name
            g49_cleaned["Suburb"] = suburb

            # save the csv if it does not already exisit
            if not os.path.exists(f"../data/landing/population_by_suburb/{SAL_CODE}_education_level.csv"):
                g49_cleaned.to_csv(f"../data/landing/population_by_suburb/{SAL_CODE}_education_level.csv", 
                                   index=False)

        elif sheet == "G60":
            start_row = df.index[df.iloc[:,1].astype(str).str.contains("PERSONS", na=False)].tolist()[0] + 1
            end_row = df.index[df.iloc[:,0].astype(str).str.contains("This table", na=False)].tolist()[0] - 1
            # Slice everything between these rows
            g60_cleaned = df.iloc[start_row + 1:end_row, :]
            g60_cleaned.columns = ["Age", "Managers", "Proffesionals", "Trades workers", "Community workers", 
                                   "Administrative Workers", "Sales Workers", "Drivers", "Labourers",
                                   "Not Stated" ,"Total"]
            # drop empty row
            g60_cleaned = g60_cleaned.dropna(subset = ["Age"]).reset_index(drop = True)
            
            # add suburb name
            g60_cleaned["Suburb"] = suburb
            # save the csv if it does not already exisit
            if not os.path.exists(f"../data/landing/population_by_suburb/{SAL_CODE}_job_type.csv"):
                g60_cleaned.to_csv(f"../data/landing/population_by_suburb/{SAL_CODE}_job_type.csv", 
                                   index=False)

# %%
for i in range(20001, 22945):
    if i not in no_data:
        
        SAL_CODE = f"SAL{i}"
        file_path = f"{population_by_suburb_directory}/{SAL_CODE}_population.xlsx"
        
        # retrieve the suburb name
        df = pd.read_excel(file_path, sheet_name="G02", header=None)
        suburb = extract_suburb_name(df)
        # download the associated csvs

        excel_to_csv(file_path, selected_sheets, SAL_CODE, suburb)

# %% [markdown]
# # merge csvs to create 7 LARGE csvs

# %%
# median stats
all_files = glob.glob("../data/landing/population_by_suburb/*_median_stats.csv")

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
if not os.path.exists(f"../data/landing/median_stats.csv"):
                df.to_csv(f"../data/landing/median_stats.csv", 
                                   index=False)


# population breakdown
all_files = glob.glob("../data/landing/population_by_suburb/*_population_breakdown.csv")

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
if not os.path.exists(f"../data/landing/population_breakdown.csv"):
                df.to_csv(f"../data/landing/population_breakdown.csv", 
                                   index=False)

# income - personal
all_files = glob.glob("../data/landing/population_by_suburb/*_personal_income.csv")

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
if not os.path.exists(f"../data/landing/personal_income.csv"):
                df.to_csv(f"../data/landing/personal_income.csv", 
                                   index=False)

# household income
all_files = glob.glob("../data/landing/population_by_suburb/*_household_income.csv")

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
if not os.path.exists(f"../data/landing/household_income.csv"):
                df.to_csv(f"../data/landing/household_income.csv", 
                                   index=False)

# dwelling distribution and structure
all_files = glob.glob("../data/landing/population_by_suburb/*_dwelling_structure.csv")

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
if not os.path.exists(f"../data/landing/dwelling_structure.csv"):
                df.to_csv(f"../data/landing/dwelling_structure.csv", 
                                   index=False)


# job type
all_files = glob.glob("../data/landing/population_by_suburb/*_job_type.csv")

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
if not os.path.exists(f"../data/landing/job_type.csv"):
                df.to_csv(f"../data/landing/job_type.csv", 
                                   index=False)


# education level
all_files = glob.glob("../data/landing/population_by_suburb/*_education_level.csv")

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
if not os.path.exists(f"../data/landing/education_level.csv"):
                df.to_csv(f"../data/landing/education_level.csv", 
                                   index=False)
